# %% [markdown]
# # EE-411 Lottery Ticket Hypothesis - Experiment Resnet-18 + Iterative + Random Init + Learning Rate = 0.01 + 3 Trials
#
# **Author:** Tianrui (Jerry)
# **Model:** ResNet 18
# **Dataset:** [CIFAR-10]
# **Date:** [2026.01.13]
#
# ---
#
# ## Instructions
#
# 1. **Define your model** in the "Model Definition" section
# 2. **Train baseline model** to get initial performance
# 3. **Run pruning experiments** using the shared pruning algorithms
# 4. **Visualize and analyze** your results
# 5. **Save your results** to the `results/` folder
#
# ## Quick Links
#
# - [Paper](https://arxiv.org/abs/1803.03635): "The Lottery Ticket Hypothesis"
# - [Shared Code](../../shared/): Training utils and pruning algorithms
# - [Results](../../results/): Save checkpoints and figures here

# %% [markdown]
# ## Setup Run ID

# %%
import os
import time
from datetime import datetime

# 1. Generate a unique Run ID (Model + Timestamp)
# e.g., "resnet20_20231027_153045"
model_name = "resnet20_iterative_random_init_LR_0.01_3_trials"  # Or "resnet18"
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
run_id = f"{model_name}_{timestamp}"

# 2. Create specific directories for THIS run
# Instead of dumping everything in 'results/', we make a subfolder
base_dir = "../../results"
run_dir = os.path.join(base_dir, run_id)
ckpt_dir = os.path.join(run_dir, "checkpoints")
fig_dir = os.path.join(run_dir, "figures")

os.makedirs(ckpt_dir, exist_ok=True)
os.makedirs(fig_dir, exist_ok=True)

print(f"Experiment Initialized: {run_id}")
print(f"Results will be saved to: {run_dir}")
# Out:
# Experiment Initialized: resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930
# Results will be saved to: ../../results/resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
sys.path.append('../..')  # Add project root to path

import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset, random_split
import matplotlib.pyplot as plt
from tqdm import tqdm

# Import shared utilities
from shared.training_utils import fit, predict, set_seed, plot_loss
from shared.pruning import (
    iterative_pruning,
    one_shot_pruning,
    one_shot_pruning_efficient,
    random_reinit_pruning,
    get_pruning_config,
    count_parameters,
    evaluate_model,
    apply_mask,
    create_global_mask
)

# Fix random seeds for reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# ## 2. Data Loading
#
# ### For CIFAR-10 (Conv-2, Conv-4, Conv-6, ResNet-18)

# %%
# CIFAR-10 Data Loading


# Define transforms
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  # New ! Crucial for CIFAR-10 
    transforms.RandomHorizontalFlip(),     # New ! Crucial for generalization 
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])


# ============================================================================
# 2. Download and Load Datasets (Twice!)
# ============================================================================

# transform_train
train_set_augmented = torchvision.datasets.CIFAR10(
    root='../../data', 
    train=True, 
    download=True, 
    transform=transform_train  # <--- Augmented data
)

# transform_test
train_set_clean = torchvision.datasets.CIFAR10(
    root='../../data', 
    train=True, 
    download=True, 
    transform=transform_test   # <--- Clean data
)

test_dataset = torchvision.datasets.CIFAR10(
    root='../../data', 
    train=False, 
    download=True, 
    transform=transform_test
)



# ============================================================================
# 3. Split Train/Val using Indices
# ============================================================================
# Make sure it's able to reproduce the same split every time
num_train = len(train_set_augmented) # 50000
indices = list(range(num_train))
split = 45000
seed = 42 

np.random.seed(seed)
np.random.shuffle(indices)

train_idx = indices[:split]
val_idx = indices[split:]

# train_dataset
train_dataset = Subset(train_set_augmented, train_idx)
# val_dataset construction using clean data
val_dataset   = Subset(train_set_clean, val_idx)


# ============================================================================
# 4. Create Data Loaders
# ============================================================================
# Create data loaders
# batch_size = 60  # From paper
batch_size = 128  # Paper uses 128 for ResNet-18

train_loader = DataLoader(
    train_dataset, 
    batch_size=batch_size, 
    shuffle=True,
    num_workers=2
)

val_loader = DataLoader(
    val_dataset, 
    batch_size=batch_size, 
    shuffle=False,
    num_workers=2
)

test_loader = DataLoader(
    test_dataset, 
    batch_size=batch_size, 
    shuffle=False,
    num_workers=2
)

# ============================================================================
# 5. Verify & Config Check
# ============================================================================

print(f"Train: {len(train_dataset)} samples")
print(f"Val:   {len(val_dataset)} samples")
print(f"Test:  {len(test_dataset)} samples")
print(f"Batches per epoch: {len(train_loader)}")

# Automatic Epochs Recommendation
iterations_needed = 30000
steps_per_epoch = len(train_loader)
recommended_epochs = int(np.ceil(iterations_needed / steps_per_epoch))

print(f"\n[Config Check]")
print(f"To reach {iterations_needed} iterations with batch size {batch_size}:")
print(f"You should set EPOCHS >= {recommended_epochs}")
# Out:
# Train: 45000 samples
# Val:   5000 samples
# Test:  10000 samples
# Batches per epoch: 352
#
# [Config Check]
# To reach 30000 iterations with batch size 128:
# You should set EPOCHS >= 86

# %% [markdown]
# ## 3. Model Definition
#
# **TODO: Define your model here**

# %%
# ResNet18 for CIFAR-10
import copy
import torch
import torch.nn as nn
# from torchvision.models import resnet18
import torch.nn.functional as F
import torch.nn.init as init



# # ResNet-20 for CIFAR-10 (Kaiming He, used in the paper)
# def _weights_init(m):
#     """
#     Kaiming Initialization (He Initialization) as used in the paper.
#     """
#     if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
#         init.kaiming_normal_(m.weight)

def _weights_init(m):
    """
    Paper uses Gaussian Glorot (Xavier Normal) initialization.
    """
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        # Gaussian Glorot (Xavier Normal) is used in the paper
        init.xavier_normal_(m.weight)
        # If there is bias, typically initialized to 0 (though ResNet's Conv usually doesn't have bias)
        if m.bias is not None:
            init.constant_(m.bias, 0)

            

class LambdaLayer(nn.Module):
    def __init__(self, lambd):
        super(LambdaLayer, self).__init__()
        self.lambd = lambd

    def forward(self, x):
        return self.lambd(x)

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.downsample = nn.Sequential() # named as "downsample" as pruning.py
        if stride != 1 or in_planes != planes:
            # Paper Option A: Zero-padding for shortcut
            self.downsample = LambdaLayer(lambda x:
                                        F.pad(x[:, :, ::2, ::2], (0, 0, 0, 0, planes//4, planes//4), "constant", 0))

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.downsample(x)
        out = F.relu(out)
        return out

class ResNet20_CIFAR10(nn.Module):
    def __init__(self):
        super(ResNet20_CIFAR10, self).__init__()
        self.in_planes = 16
        
        # ResNet-20: 3 layers * 3 blocks * 2 convs + 1st conv + 1 linear = 20 layers
        num_blocks = [3, 3, 3] 

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        
        self.layer1 = self._make_layer(BasicBlock, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(BasicBlock, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(BasicBlock, 64, num_blocks[2], stride=2)
        
        self.linear = nn.Linear(64, 10)
        
        # Apply initialization
        self.apply(_weights_init)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out



# Create model instance
# model = ResNet18_CIFAR10().to(device)
model = ResNet20_CIFAR10().to(device)
initial_weights_state = copy.deepcopy(model.state_dict())
init_weights_path = os.path.join(ckpt_dir, f"initial_weights_theta0_{run_id}.pth")
torch.save(initial_weights_state, init_weights_path)
print(f"Initial weights saved to: {init_weights_path}")

# Print model info
total_params = count_parameters(model)
print(f"Model: ResNet20_CIFAR10")
print(f"Total parameters: {total_params:,}")
print(f"\nModel architecture:")
print(model)
# Out:
# Initial weights saved to: ../../results/resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930/checkpoints/initial_weights_theta0_resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930.pth
# Model: ResNet20_CIFAR10
# Total parameters: 269,722
#
# Model architecture:
# ResNet20_CIFAR10(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): LambdaLayer()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): LambdaLayer()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#   )
#   (linear): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ## 4. Baseline Training
#
# Train the unpruned model to establish baseline performance.

# %%
# Training configuration (from paper)
# Adjust these based on your model!
     
learning_rate = 0.1 # Paper recommends 0.1 (or 0.03 with warmup)
epochs = 86  

# Optimizer
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

optimizer = torch.optim.SGD(
    model.parameters(), 
    lr=learning_rate,             # Paper recommends 0.1 for constant, or 0.03 with warmup
    momentum=0.9, 
    weight_decay=1e-4   # Helps prevent overfitting
)

# Paper: Divide LR by 10 at 20k and 25k iterations
# 20,000 / 352 ≈ 57 epochs
# 25,000 / 352 ≈ 71 epochs
scheduler = torch.optim.lr_scheduler.MultiStepLR(
    optimizer, 
    milestones=[57, 71], 
    gamma=0.01
)

# --- Dynamic Print ---
optimizer_name = optimizer.__class__.__name__
current_lr = optimizer.param_groups[0]['lr']

print(f"Training configuration:")
print(f"  Optimizer: {optimizer_name}") # Dynamic!
print(f"  Learning rate: {learning_rate}")
print(f"  Epochs: {epochs}")
print(f"  Batch size: {batch_size}")
print(f"\nStarting training...\n")

test_loss, test_accuracy = predict(model, test_loader, device)
# Out:
# Training configuration:
#   Optimizer: SGD
#   Learning rate: 0.1
#   Epochs: 86
#   Batch size: 128
#
# Starting training...
#
# Test set: Avg. loss: 2.8741, Accuracy: 1049/10000 (10%)

# %%
# # Train using shared training_utils
# losses = fit(
#     model=model,
#     train_dataloader=train_loader,
#     optimizer=optimizer,
#     epochs=epochs,
#     device=device,
#     scheduler=scheduler  # New! Don't forget to pass the scheduler!
# )

# # Evaluate on test set
# test_loss, test_accuracy = predict(model, test_loader, device)

# print(f"\n{'='*60}")
# print(f"Baseline Results")
# print(f"{'='*60}")
# print(f"Test Accuracy: {test_accuracy:.2f}%")
# print(f"Test Loss: {test_loss:.4f}")

# %% [markdown]
# ### Visualize Training

# %%
# iterations_per_epoch = len(train_loader)
# # ================= Drawing Figure 1: X-axis = Epochs =================

# plt.figure(figsize=(10, 5))
# plt.plot(losses, linewidth=2)
# plt.xlabel('Epoch', fontsize=12)
# plt.ylabel('Training Loss', fontsize=12)
# plt.title(f'Baseline Training Loss ({model_name})', fontsize=14)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()

# # Save with run_id
# loss_fig_path = os.path.join(fig_dir, f"baseline_loss_{run_id}.png")
# plt.savefig(loss_fig_path, dpi=150)
# plt.show()

# print(f"Loss figure saved to: {loss_fig_path}")

# # ================= Drawing Figure 2: X-axis = Iterations =================
# iterations_x = [i * iterations_per_epoch for i in range(1, len(losses) + 1)]

# plt.figure(figsize=(10, 5))
# plt.plot(iterations_x, losses, linewidth=2, color='red', linestyle='--', label='Train Loss')
# plt.xlabel('Iterations', fontsize=12)
# plt.ylabel('Training Loss', fontsize=12)
# plt.title(f'Baseline Training Loss vs Iterations ({model_name})', fontsize=14)
# plt.grid(True, alpha=0.3)
# plt.legend()
# plt.tight_layout()

# # Save Iteration Figure
# loss_fig_path_iter = os.path.join(fig_dir, f"baseline_loss_iter_{run_id}.png")
# plt.savefig(loss_fig_path_iter, dpi=150)
# plt.show()
# print(f"Iteration-based loss figure saved to: {loss_fig_path_iter}")
# Out:
# Loss figure saved to: ../../results/resnet20_one_shot_original_init_20260110_215316/figures/baseline_loss_resnet20_one_shot_original_init_20260110_215316.png
# Iteration-based loss figure saved to: ../../results/resnet20_one_shot_original_init_20260110_215316/figures/baseline_loss_iter_resnet20_one_shot_original_init_20260110_215316.png

# %% [markdown]
# ### Save Baseline Model

# %%
# # --- Save Baseline Model ---
# # Save with the unique run_id in the filename
# baseline_path = os.path.join(ckpt_dir, f"baseline_{run_id}.pth")

# torch.save({
#     'model_state_dict': model.state_dict(),
#     'optimizer_state_dict': optimizer.state_dict(),
#     'test_accuracy': test_accuracy,
#     'test_loss': test_loss,
#     'epochs': epochs,
#     'config': {
#         'optimizer': optimizer_name,
#         'lr': current_lr
#     }
# }, baseline_path)

# print(f"Baseline model saved to: {baseline_path}")
# Out:
# Baseline model saved to: ../../results/resnet20_one_shot_original_init_20260110_215316/checkpoints/baseline_resnet20_one_shot_original_init_20260110_215316.pth

# %% [markdown]
# ## 5. Pruning Experiments

# %% [markdown]
# ### 5.1 Iterative Pruning
#
# Run the main pruning experiment from the paper.

# %%
# Get pruning configuration for your model
# Options: 'lenet', 'conv2', 'conv4', 'conv6', 'resnet18', 'resnet20'

pruning_config = get_pruning_config('resnet18')

print("Pruning Configuration:")
for key, value in pruning_config.items():
    print(f"  {key}: {value}")
# Out:
# Pruning Configuration:
#   prune_rate_conv: 0.2
#   prune_rate_fc: 0.0
#   pruning_strategy: global
#   description: ResNet-18 for CIFAR-10

# %%
# --- Seed Configuration for Trials ---
SEEDS = [42, 43, 44]
lr = 0.01
epochs_per_round = 86  # ~30k iterations

# --- Data Preparation Function (Re-usable for every seed) ---
def get_dataloaders(seed):
    """Re-creates dataloaders with specific seed-based shuffling"""
    
    # Define transforms
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    # Load Datasets
    train_set_augmented = torchvision.datasets.CIFAR10(root='../../data', train=True, download=True, transform=transform_train)
    train_set_clean = torchvision.datasets.CIFAR10(root='../../data', train=True, download=True, transform=transform_test)
    test_dataset = torchvision.datasets.CIFAR10(root='../../data', train=False, download=True, transform=transform_test)

    # Split Train/Val (Dependent on Seed)
    num_train = len(train_set_augmented)
    indices = list(range(num_train))
    split = 45000
    
    # Temporarily set numpy seed for split consistency within this function call
    rng = np.random.RandomState(seed) 
    rng.shuffle(indices)

    train_idx = indices[:split]
    val_idx = indices[split:]

    train_dataset = Subset(train_set_augmented, train_idx)
    val_dataset = Subset(train_set_clean, val_idx)

    # Create Loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
    
    return train_loader, val_loader, test_loader

# %%
# ============================================================================
# PHASE 1: Iterative Pruning (Winning Tickets)
# ============================================================================
print(f"\n{'='*40}")
print("PHASE 1: Iterative Pruning Experiments")
print(f"{'='*40}")

all_trials_iterative = []

for trial_idx, seed in enumerate(SEEDS):
    print(f"\n>>> Starting Iterative Trial {trial_idx + 1}/{len(SEEDS)} | Seed {seed}")
    
    # 1. Set seed for reproducibility
    set_seed(seed)
    
    # 2. Prepare Data & Model
    train_loader, val_loader, test_loader = get_dataloaders(seed)
    model = ResNet20_CIFAR10().to(device)
    
    # 3. Run Iterative Pruning
    iter_results = iterative_pruning(
        model=model,
        train_loader=train_loader,
        test_loader=test_loader,
        val_loader=val_loader,
        optimizer_class=torch.optim.SGD,
        optimizer_kwargs={'lr': lr, 'momentum': 0.9, 'weight_decay': 1e-4},
        device=device,
        config=pruning_config,
        epochs_per_round=epochs_per_round,
        n_rounds=15,
        verbose=True
    )
    
    all_trials_iterative.append(iter_results)

# 4. Save Iterative Results immediately
iterative_save_path = os.path.join(ckpt_dir, f"iterative_results_{run_id}.pth")
torch.save({
    'trials': all_trials_iterative,
    'seeds': SEEDS,
    'config': pruning_config,
    'lr': lr
}, iterative_save_path)
print(f"Saved Iterative results to: {iterative_save_path}")
# Out:
# ========================================
# PHASE 1: Iterative Pruning Experiments
# ========================================
#
# >>> Starting Iterative Trial 1/3 | Seed 42
#
# Seed set to: 42
# ======================================================================
# Starting Iterative Pruning
# Initial parameters: 269,722
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# ======================================================================
#
# ======================================================================
# Round 1/15
# ======================================================================
# Scheduler enabled: MultiStepLR at epochs 57 and 71
# Epoch 01 | Train Loss: 1.6403 | Val Loss: 1.4626 | Val Acc: 49.58% | Test Acc: 50.49%
# Epoch 02 | Train Loss: 1.1975 | Val Loss: 1.1229 | Val Acc: 60.32% | Test Acc: 60.50%
# Epoch 03 | Train Loss: 1.0085 | Val Loss: 1.1393 | Val Acc: 60.16% | Test Acc: 60.13%
# Epoch 04 | Train Loss: 0.8799 | Val Loss: 0.9606 | Val Acc: 67.86% | Test Acc: 68.26%
# Epoch 05 | Train Loss: 0.7946 | Val Loss: 0.9286 | Val Acc: 68.76% | Test Acc: 68.78%
# Epoch 06 | Train Loss: 0.7229 | Val Loss: 0.9568 | Val Acc: 68.86% | Test Acc: 68.94%
# Epoch 07 | Train Loss: 0.6707 | Val Loss: 0.7245 | Val Acc: 75.46% | Test Acc: 76.02%
# Epoch 08 | Train Loss: 0.6271 | Val Loss: 0.8423 | Val Acc: 72.56% | Test Acc: 72.48%
# Epoch 09 | Train Loss: 0.5923 | Val Loss: 0.6932 | Val Acc: 77.16% | Test Acc: 77.04%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 66.21it/s]
# Epoch 10 | Train Loss: 0.5614 | Val Loss: 0.7820 | Val Acc: 75.32% | Test Acc: 75.36%
# Epoch 11 | Train Loss: 0.5417 | Val Loss: 0.6394 | Val Acc: 78.14% | Test Acc: 78.64%
# Epoch 12 | Train Loss: 0.5123 | Val Loss: 0.6995 | Val Acc: 77.56% | Test Acc: 77.76%
# Epoch 13 | Train Loss: 0.4978 | Val Loss: 0.6267 | Val Acc: 80.22% | Test Acc: 80.09%
# Epoch 14 | Train Loss: 0.4759 | Val Loss: 0.5934 | Val Acc: 81.18% | Test Acc: 81.08%
# Epoch 15 | Train Loss: 0.4555 | Val Loss: 0.6479 | Val Acc: 78.94% | Test Acc: 79.31%
# Epoch 16 | Train Loss: 0.4443 | Val Loss: 0.6078 | Val Acc: 79.98% | Test Acc: 80.53%
# Epoch 17 | Train Loss: 0.4305 | Val Loss: 0.6563 | Val Acc: 79.64% | Test Acc: 80.09%
# Epoch 18 | Train Loss: 0.4214 | Val Loss: 0.6849 | Val Acc: 78.52% | Test Acc: 78.20%
# Epoch 19 | Train Loss: 0.4030 | Val Loss: 0.5449 | Val Acc: 82.12% | Test Acc: 82.76%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 64.25it/s]
# Epoch 20 | Train Loss: 0.3913 | Val Loss: 0.5277 | Val Acc: 82.66% | Test Acc: 83.32%
# Epoch 21 | Train Loss: 0.3856 | Val Loss: 0.6951 | Val Acc: 78.26% | Test Acc: 79.24%
# Epoch 22 | Train Loss: 0.3747 | Val Loss: 0.6648 | Val Acc: 80.18% | Test Acc: 80.07%
# Epoch 23 | Train Loss: 0.3617 | Val Loss: 0.5107 | Val Acc: 83.36% | Test Acc: 83.39%
# Epoch 24 | Train Loss: 0.3540 | Val Loss: 0.5493 | Val Acc: 82.50% | Test Acc: 83.00%
# Epoch 25 | Train Loss: 0.3484 | Val Loss: 0.5336 | Val Acc: 82.24% | Test Acc: 83.00%
# Epoch 26 | Train Loss: 0.3364 | Val Loss: 0.6383 | Val Acc: 79.94% | Test Acc: 79.88%
# Epoch 27 | Train Loss: 0.3281 | Val Loss: 0.4774 | Val Acc: 84.86% | Test Acc: 84.75%
# Epoch 28 | Train Loss: 0.3263 | Val Loss: 0.5760 | Val Acc: 82.26% | Test Acc: 82.53%
# Epoch 29 | Train Loss: 0.3198 | Val Loss: 0.5134 | Val Acc: 83.42% | Test Acc: 83.87%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 62.01it/s]
# Epoch 30 | Train Loss: 0.3086 | Val Loss: 0.5709 | Val Acc: 81.54% | Test Acc: 82.07%
# Epoch 31 | Train Loss: 0.3061 | Val Loss: 0.4616 | Val Acc: 85.44% | Test Acc: 85.44%
# Epoch 32 | Train Loss: 0.2930 | Val Loss: 0.4559 | Val Acc: 85.30% | Test Acc: 85.02%
# Epoch 33 | Train Loss: 0.2914 | Val Loss: 0.4386 | Val Acc: 86.30% | Test Acc: 86.11%
# Epoch 34 | Train Loss: 0.2877 | Val Loss: 0.5408 | Val Acc: 83.28% | Test Acc: 83.51%
# Epoch 35 | Train Loss: 0.2791 | Val Loss: 0.4852 | Val Acc: 84.86% | Test Acc: 85.26%
# Epoch 36 | Train Loss: 0.2675 | Val Loss: 0.4968 | Val Acc: 84.84% | Test Acc: 84.77%
# Epoch 37 | Train Loss: 0.2701 | Val Loss: 0.5040 | Val Acc: 84.94% | Test Acc: 84.43%
# Epoch 38 | Train Loss: 0.2652 | Val Loss: 0.5102 | Val Acc: 84.20% | Test Acc: 84.72%
# Epoch 39 | Train Loss: 0.2635 | Val Loss: 0.5118 | Val Acc: 84.40% | Test Acc: 84.72%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 64.46it/s]
# Epoch 40 | Train Loss: 0.2609 | Val Loss: 0.5643 | Val Acc: 84.20% | Test Acc: 83.27%
# Epoch 41 | Train Loss: 0.2522 | Val Loss: 0.5468 | Val Acc: 83.34% | Test Acc: 83.59%
# Epoch 42 | Train Loss: 0.2456 | Val Loss: 0.4592 | Val Acc: 86.12% | Test Acc: 85.79%
# Epoch 43 | Train Loss: 0.2425 | Val Loss: 0.4763 | Val Acc: 85.82% | Test Acc: 85.54%
# Epoch 44 | Train Loss: 0.2401 | Val Loss: 0.4954 | Val Acc: 84.66% | Test Acc: 84.81%
# Epoch 45 | Train Loss: 0.2369 | Val Loss: 0.5285 | Val Acc: 83.90% | Test Acc: 84.28%
# Epoch 46 | Train Loss: 0.2296 | Val Loss: 0.4764 | Val Acc: 85.32% | Test Acc: 85.72%
# Epoch 47 | Train Loss: 0.2279 | Val Loss: 0.4401 | Val Acc: 86.54% | Test Acc: 86.60%
# Epoch 48 | Train Loss: 0.2235 | Val Loss: 0.4940 | Val Acc: 85.26% | Test Acc: 85.70%
# Epoch 49 | Train Loss: 0.2220 | Val Loss: 0.4516 | Val Acc: 86.42% | Test Acc: 86.02%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 61.36it/s]
# Epoch 50 | Train Loss: 0.2162 | Val Loss: 0.5172 | Val Acc: 84.78% | Test Acc: 85.30%
# Epoch 51 | Train Loss: 0.2144 | Val Loss: 0.4942 | Val Acc: 85.34% | Test Acc: 85.34%
# Epoch 52 | Train Loss: 0.2057 | Val Loss: 0.5287 | Val Acc: 84.68% | Test Acc: 84.85%
# Epoch 53 | Train Loss: 0.2073 | Val Loss: 0.4577 | Val Acc: 86.82% | Test Acc: 86.20%
# Epoch 54 | Train Loss: 0.1980 | Val Loss: 0.5857 | Val Acc: 83.96% | Test Acc: 84.48%
# Epoch 55 | Train Loss: 0.1981 | Val Loss: 0.5284 | Val Acc: 84.46% | Test Acc: 85.11%
# Epoch 56 | Train Loss: 0.1981 | Val Loss: 0.4393 | Val Acc: 86.96% | Test Acc: 86.56%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.1906 | Val Loss: 0.4431 | Val Acc: 86.90% | Test Acc: 86.94%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1408 | Val Loss: 0.3723 | Val Acc: 88.28% | Test Acc: 88.94%
# Epoch 59 | Train Loss: 0.1260 | Val Loss: 0.3783 | Val Acc: 88.36% | Test Acc: 88.78%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 68.61it/s]
# Epoch 60 | Train Loss: 0.1214 | Val Loss: 0.3723 | Val Acc: 88.34% | Test Acc: 88.89%
# Epoch 61 | Train Loss: 0.1165 | Val Loss: 0.3738 | Val Acc: 88.54% | Test Acc: 88.87%
# Epoch 62 | Train Loss: 0.1131 | Val Loss: 0.3760 | Val Acc: 88.64% | Test Acc: 88.98%
# Epoch 63 | Train Loss: 0.1143 | Val Loss: 0.3774 | Val Acc: 88.62% | Test Acc: 89.07%
# Epoch 64 | Train Loss: 0.1125 | Val Loss: 0.3780 | Val Acc: 88.36% | Test Acc: 89.19%
# Epoch 65 | Train Loss: 0.1078 | Val Loss: 0.3816 | Val Acc: 88.40% | Test Acc: 88.99%
# Epoch 66 | Train Loss: 0.1054 | Val Loss: 0.3829 | Val Acc: 88.42% | Test Acc: 89.10%
# Epoch 67 | Train Loss: 0.1026 | Val Loss: 0.3793 | Val Acc: 88.40% | Test Acc: 89.21%
#    [Tracker] 🚩 Early Stop Condition at Iter 23936 (Epoch 68, Test Acc: 89.03%)
# Epoch 68 | Train Loss: 0.1046 | Val Loss: 0.3815 | Val Acc: 88.48% | Test Acc: 89.03%
# Epoch 69 | Train Loss: 0.1041 | Val Loss: 0.3799 | Val Acc: 88.24% | Test Acc: 89.09%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 66.56it/s]
# Epoch 70 | Train Loss: 0.1020 | Val Loss: 0.3789 | Val Acc: 88.54% | Test Acc: 88.98%
# Epoch 71 | Train Loss: 0.1023 | Val Loss: 0.3872 | Val Acc: 88.40% | Test Acc: 88.85%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.0982 | Val Loss: 0.3836 | Val Acc: 88.38% | Test Acc: 89.12%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.0968 | Val Loss: 0.3791 | Val Acc: 88.58% | Test Acc: 89.15%
# Epoch 74 | Train Loss: 0.0959 | Val Loss: 0.3813 | Val Acc: 88.56% | Test Acc: 89.09%
# Epoch 75 | Train Loss: 0.0949 | Val Loss: 0.3839 | Val Acc: 88.60% | Test Acc: 89.17%
# Epoch 76 | Train Loss: 0.0953 | Val Loss: 0.3836 | Val Acc: 88.64% | Test Acc: 89.18%
# Epoch 77 | Train Loss: 0.0956 | Val Loss: 0.3811 | Val Acc: 88.52% | Test Acc: 89.20%
# Epoch 78 | Train Loss: 0.0944 | Val Loss: 0.3823 | Val Acc: 88.56% | Test Acc: 89.28%
# Epoch 79 | Train Loss: 0.0947 | Val Loss: 0.3819 | Val Acc: 88.60% | Test Acc: 89.03%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 63.23it/s]
# Epoch 80 | Train Loss: 0.0940 | Val Loss: 0.3810 | Val Acc: 88.58% | Test Acc: 89.15%
# Epoch 81 | Train Loss: 0.0941 | Val Loss: 0.3843 | Val Acc: 88.44% | Test Acc: 89.07%
# Epoch 82 | Train Loss: 0.0935 | Val Loss: 0.3812 | Val Acc: 88.64% | Test Acc: 89.22%
# Epoch 83 | Train Loss: 0.0917 | Val Loss: 0.3862 | Val Acc: 88.46% | Test Acc: 89.14%
# Epoch 84 | Train Loss: 0.0914 | Val Loss: 0.3837 | Val Acc: 88.60% | Test Acc: 89.10%
# Epoch 85 | Train Loss: 0.0921 | Val Loss: 0.3824 | Val Acc: 88.60% | Test Acc: 89.08%
# Epoch 86 | Train Loss: 0.0934 | Val Loss: 0.3858 | Val Acc: 88.54% | Test Acc: 89.10%
#
# Round 1 Results:
#   Test Accuracy: 89.10%
#   Remaining Parameters: 216,183.0 (80.15%)
#
# ======================================================================
# Round 2/15
# ======================================================================
# Scheduler enabled: MultiStepLR at epochs 57 and 71
# Epoch 01 | Train Loss: 1.5384 | Val Loss: 1.8682 | Val Acc: 42.40% | Test Acc: 42.81%
# Epoch 02 | Train Loss: 1.1080 | Val Loss: 1.3670 | Val Acc: 56.10% | Test Acc: 55.57%
# Epoch 03 | Train Loss: 0.9062 | Val Loss: 0.9122 | Val Acc: 69.06% | Test Acc: 69.81%
# Epoch 04 | Train Loss: 0.7863 | Val Loss: 0.8194 | Val Acc: 71.82% | Test Acc: 73.32%
# Epoch 05 | Train Loss: 0.6963 | Val Loss: 0.7349 | Val Acc: 74.32% | Test Acc: 74.74%
# Epoch 06 | Train Loss: 0.6492 | Val Loss: 0.8608 | Val Acc: 72.64% | Test Acc: 72.47%
# Epoch 07 | Train Loss: 0.6019 | Val Loss: 0.7842 | Val Acc: 74.28% | Test Acc: 75.02%
# Epoch 08 | Train Loss: 0.5621 | Val Loss: 0.7367 | Val Acc: 75.34% | Test Acc: 75.14%
# Epoch 09 | Train Loss: 0.5391 | Val Loss: 0.8346 | Val Acc: 73.66% | Test Acc: 73.92%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 66.55it/s]
# Epoch 10 | Train Loss: 0.5139 | Val Loss: 0.6723 | Val Acc: 77.62% | Test Acc: 77.32%
# Epoch 11 | Train Loss: 0.4898 | Val Loss: 0.6062 | Val Acc: 80.46% | Test Acc: 80.20%
# Epoch 12 | Train Loss: 0.4697 | Val Loss: 0.5816 | Val Acc: 80.76% | Test Acc: 81.15%
# Epoch 13 | Train Loss: 0.4504 | Val Loss: 0.5783 | Val Acc: 80.76% | Test Acc: 81.00%
# Epoch 14 | Train Loss: 0.4377 | Val Loss: 0.5203 | Val Acc: 83.20% | Test Acc: 82.69%
# Epoch 15 | Train Loss: 0.4222 | Val Loss: 0.6468 | Val Acc: 79.60% | Test Acc: 79.68%
# Epoch 16 | Train Loss: 0.4083 | Val Loss: 0.5971 | Val Acc: 81.28% | Test Acc: 81.49%
# Epoch 17 | Train Loss: 0.3926 | Val Loss: 0.5619 | Val Acc: 81.88% | Test Acc: 82.11%
# Epoch 18 | Train Loss: 0.3884 | Val Loss: 0.5278 | Val Acc: 82.80% | Test Acc: 83.17%
# Epoch 19 | Train Loss: 0.3707 | Val Loss: 0.5462 | Val Acc: 82.74% | Test Acc: 82.73%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 60.33it/s]
# Epoch 20 | Train Loss: 0.3645 | Val Loss: 0.5020 | Val Acc: 83.92% | Test Acc: 83.59%
# Epoch 21 | Train Loss: 0.3532 | Val Loss: 0.5732 | Val Acc: 81.96% | Test Acc: 82.42%
# Epoch 22 | Train Loss: 0.3456 | Val Loss: 0.6308 | Val Acc: 80.86% | Test Acc: 80.78%
# Epoch 23 | Train Loss: 0.3358 | Val Loss: 0.4910 | Val Acc: 84.50% | Test Acc: 84.26%
# Epoch 24 | Train Loss: 0.3286 | Val Loss: 0.4573 | Val Acc: 85.12% | Test Acc: 85.19%
# Epoch 25 | Train Loss: 0.3173 | Val Loss: 0.5502 | Val Acc: 82.78% | Test Acc: 82.39%
# Epoch 26 | Train Loss: 0.3130 | Val Loss: 0.4495 | Val Acc: 85.52% | Test Acc: 85.74%
# Epoch 27 | Train Loss: 0.3042 | Val Loss: 0.4904 | Val Acc: 85.08% | Test Acc: 84.69%
# Epoch 28 | Train Loss: 0.3009 | Val Loss: 0.5122 | Val Acc: 84.02% | Test Acc: 84.10%
# Epoch 29 | Train Loss: 0.2912 | Val Loss: 0.5393 | Val Acc: 83.74% | Test Acc: 83.85%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 61.65it/s]
# Epoch 30 | Train Loss: 0.2862 | Val Loss: 0.4638 | Val Acc: 85.28% | Test Acc: 85.54%
# Epoch 31 | Train Loss: 0.2858 | Val Loss: 0.4769 | Val Acc: 84.78% | Test Acc: 85.05%
# Epoch 32 | Train Loss: 0.2752 | Val Loss: 0.4768 | Val Acc: 84.96% | Test Acc: 85.30%
# Epoch 33 | Train Loss: 0.2681 | Val Loss: 0.4695 | Val Acc: 85.08% | Test Acc: 85.61%
# Epoch 34 | Train Loss: 0.2644 | Val Loss: 0.4840 | Val Acc: 85.46% | Test Acc: 85.28%
# Epoch 35 | Train Loss: 0.2619 | Val Loss: 0.4926 | Val Acc: 85.12% | Test Acc: 85.09%
# Epoch 36 | Train Loss: 0.2569 | Val Loss: 0.4733 | Val Acc: 85.92% | Test Acc: 85.38%
# Epoch 37 | Train Loss: 0.2520 | Val Loss: 0.4425 | Val Acc: 85.98% | Test Acc: 86.35%
# Epoch 38 | Train Loss: 0.2491 | Val Loss: 0.4891 | Val Acc: 84.96% | Test Acc: 85.29%
# Epoch 39 | Train Loss: 0.2435 | Val Loss: 0.4689 | Val Acc: 86.14% | Test Acc: 85.45%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 67.55it/s]
# Epoch 40 | Train Loss: 0.2359 | Val Loss: 0.4447 | Val Acc: 86.84% | Test Acc: 86.13%
# Epoch 41 | Train Loss: 0.2346 | Val Loss: 0.4720 | Val Acc: 85.78% | Test Acc: 85.52%
# Epoch 42 | Train Loss: 0.2336 | Val Loss: 0.5638 | Val Acc: 83.78% | Test Acc: 83.55%
# Epoch 43 | Train Loss: 0.2257 | Val Loss: 0.4510 | Val Acc: 86.00% | Test Acc: 86.08%
# Epoch 44 | Train Loss: 0.2286 | Val Loss: 0.4143 | Val Acc: 87.34% | Test Acc: 86.87%
# Epoch 45 | Train Loss: 0.2181 | Val Loss: 0.4505 | Val Acc: 86.72% | Test Acc: 86.98%
# Epoch 46 | Train Loss: 0.2138 | Val Loss: 0.4575 | Val Acc: 86.10% | Test Acc: 85.93%
# Epoch 47 | Train Loss: 0.2111 | Val Loss: 0.4679 | Val Acc: 86.00% | Test Acc: 86.10%
# Epoch 48 | Train Loss: 0.2085 | Val Loss: 0.4753 | Val Acc: 86.40% | Test Acc: 86.12%
# Epoch 49 | Train Loss: 0.2045 | Val Loss: 0.5106 | Val Acc: 85.44% | Test Acc: 85.65%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 69.35it/s]
# Epoch 50 | Train Loss: 0.1997 | Val Loss: 0.4876 | Val Acc: 85.72% | Test Acc: 85.74%
# Epoch 51 | Train Loss: 0.2040 | Val Loss: 0.4480 | Val Acc: 86.86% | Test Acc: 87.21%
# Epoch 52 | Train Loss: 0.1978 | Val Loss: 0.4450 | Val Acc: 86.60% | Test Acc: 86.74%
# Epoch 53 | Train Loss: 0.1926 | Val Loss: 0.4840 | Val Acc: 86.24% | Test Acc: 86.24%
# Epoch 54 | Train Loss: 0.1900 | Val Loss: 0.4789 | Val Acc: 86.08% | Test Acc: 86.45%
# Epoch 55 | Train Loss: 0.1907 | Val Loss: 0.4880 | Val Acc: 85.90% | Test Acc: 86.63%
# Epoch 56 | Train Loss: 0.1901 | Val Loss: 0.5697 | Val Acc: 84.18% | Test Acc: 84.48%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.1894 | Val Loss: 0.5014 | Val Acc: 86.26% | Test Acc: 86.22%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1404 | Val Loss: 0.3754 | Val Acc: 88.88% | Test Acc: 88.79%
# Epoch 59 | Train Loss: 0.1219 | Val Loss: 0.3733 | Val Acc: 89.12% | Test Acc: 88.83%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 61.10it/s]
# Epoch 60 | Train Loss: 0.1153 | Val Loss: 0.3776 | Val Acc: 89.08% | Test Acc: 88.92%
# Epoch 61 | Train Loss: 0.1144 | Val Loss: 0.3776 | Val Acc: 89.28% | Test Acc: 89.04%
# Epoch 62 | Train Loss: 0.1101 | Val Loss: 0.3782 | Val Acc: 89.16% | Test Acc: 89.20%
# Epoch 63 | Train Loss: 0.1093 | Val Loss: 0.3758 | Val Acc: 89.22% | Test Acc: 89.22%
# Epoch 64 | Train Loss: 0.1071 | Val Loss: 0.3819 | Val Acc: 89.04% | Test Acc: 89.04%
# Epoch 65 | Train Loss: 0.1035 | Val Loss: 0.3836 | Val Acc: 89.08% | Test Acc: 89.23%
# Epoch 66 | Train Loss: 0.1004 | Val Loss: 0.3797 | Val Acc: 89.04% | Test Acc: 89.27%
# Epoch 67 | Train Loss: 0.0995 | Val Loss: 0.3856 | Val Acc: 89.24% | Test Acc: 89.16%
# Epoch 68 | Train Loss: 0.1011 | Val Loss: 0.3877 | Val Acc: 88.96% | Test Acc: 89.16%
#    [Tracker] 🚩 Early Stop Condition at Iter 24288 (Epoch 69, Test Acc: 89.27%)
# Epoch 69 | Train Loss: 0.0991 | Val Loss: 0.3817 | Val Acc: 89.42% | Test Acc: 89.27%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 67.03it/s]
# Epoch 70 | Train Loss: 0.0975 | Val Loss: 0.3852 | Val Acc: 89.30% | Test Acc: 89.01%
# Epoch 71 | Train Loss: 0.0973 | Val Loss: 0.3839 | Val Acc: 89.14% | Test Acc: 89.10%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.0939 | Val Loss: 0.3851 | Val Acc: 89.20% | Test Acc: 89.11%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.0929 | Val Loss: 0.3833 | Val Acc: 89.20% | Test Acc: 89.01%
# Epoch 74 | Train Loss: 0.0916 | Val Loss: 0.3814 | Val Acc: 89.34% | Test Acc: 89.08%
# Epoch 75 | Train Loss: 0.0930 | Val Loss: 0.3819 | Val Acc: 89.24% | Test Acc: 89.12%
# Epoch 76 | Train Loss: 0.0896 | Val Loss: 0.3848 | Val Acc: 89.32% | Test Acc: 89.17%
# Epoch 77 | Train Loss: 0.0901 | Val Loss: 0.3869 | Val Acc: 89.16% | Test Acc: 89.13%
# Epoch 78 | Train Loss: 0.0894 | Val Loss: 0.3855 | Val Acc: 89.20% | Test Acc: 89.12%
# Epoch 79 | Train Loss: 0.0911 | Val Loss: 0.3867 | Val Acc: 89.16% | Test Acc: 89.08%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 66.75it/s]
# Epoch 80 | Train Loss: 0.0920 | Val Loss: 0.3869 | Val Acc: 89.20% | Test Acc: 89.17%
# Epoch 81 | Train Loss: 0.0889 | Val Loss: 0.3834 | Val Acc: 89.42% | Test Acc: 89.10%
# Epoch 82 | Train Loss: 0.0896 | Val Loss: 0.3844 | Val Acc: 89.30% | Test Acc: 89.15%
# Epoch 83 | Train Loss: 0.0886 | Val Loss: 0.3843 | Val Acc: 89.22% | Test Acc: 89.14%
# Epoch 84 | Train Loss: 0.0898 | Val Loss: 0.3820 | Val Acc: 89.26% | Test Acc: 89.20%
# Epoch 85 | Train Loss: 0.0893 | Val Loss: 0.3861 | Val Acc: 89.26% | Test Acc: 89.13%
# Epoch 86 | Train Loss: 0.0912 | Val Loss: 0.3856 | Val Acc: 89.26% | Test Acc: 89.25%
#
# Round 2 Results:
#   Test Accuracy: 89.25%
#   Remaining Parameters: 173,351.0 (64.27%)
#
# ======================================================================
# Round 3/15
# ======================================================================
# Scheduler enabled: MultiStepLR at epochs 57 and 71
# Epoch 01 | Train Loss: 1.4474 | Val Loss: 1.5160 | Val Acc: 49.20% | Test Acc: 48.99%
# Epoch 02 | Train Loss: 0.9647 | Val Loss: 0.9694 | Val Acc: 67.04% | Test Acc: 67.37%
# Epoch 03 | Train Loss: 0.7688 | Val Loss: 0.9653 | Val Acc: 68.30% | Test Acc: 68.62%
# Epoch 04 | Train Loss: 0.6668 | Val Loss: 0.8783 | Val Acc: 71.74% | Test Acc: 71.71%
# Epoch 05 | Train Loss: 0.6029 | Val Loss: 0.7522 | Val Acc: 75.12% | Test Acc: 74.97%
# Epoch 06 | Train Loss: 0.5602 | Val Loss: 0.6697 | Val Acc: 78.18% | Test Acc: 78.72%
# Epoch 07 | Train Loss: 0.5214 | Val Loss: 0.6066 | Val Acc: 79.48% | Test Acc: 79.54%
# Epoch 08 | Train Loss: 0.4893 | Val Loss: 0.5688 | Val Acc: 81.36% | Test Acc: 81.20%
# Epoch 09 | Train Loss: 0.4634 | Val Loss: 0.5909 | Val Acc: 80.78% | Test Acc: 81.20%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 65.43it/s]
# Epoch 10 | Train Loss: 0.4401 | Val Loss: 0.5403 | Val Acc: 82.44% | Test Acc: 81.88%
# Epoch 11 | Train Loss: 0.4210 | Val Loss: 0.6433 | Val Acc: 79.34% | Test Acc: 79.63%
# Epoch 12 | Train Loss: 0.4099 | Val Loss: 0.5657 | Val Acc: 81.66% | Test Acc: 82.06%
# Epoch 13 | Train Loss: 0.3887 | Val Loss: 0.5216 | Val Acc: 83.70% | Test Acc: 83.43%
# Epoch 14 | Train Loss: 0.3743 | Val Loss: 0.5787 | Val Acc: 81.72% | Test Acc: 82.05%
# Epoch 15 | Train Loss: 0.3627 | Val Loss: 0.5547 | Val Acc: 82.76% | Test Acc: 81.96%
# Epoch 16 | Train Loss: 0.3486 | Val Loss: 0.5903 | Val Acc: 81.80% | Test Acc: 81.25%
# Epoch 17 | Train Loss: 0.3436 | Val Loss: 0.4533 | Val Acc: 85.42% | Test Acc: 85.05%
# Epoch 18 | Train Loss: 0.3278 | Val Loss: 0.5030 | Val Acc: 83.90% | Test Acc: 83.79%
# Epoch 19 | Train Loss: 0.3236 | Val Loss: 0.4717 | Val Acc: 84.88% | Test Acc: 84.76%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 62.00it/s]
# Epoch 20 | Train Loss: 0.3140 | Val Loss: 0.4639 | Val Acc: 85.40% | Test Acc: 85.30%
# Epoch 21 | Train Loss: 0.3044 | Val Loss: 0.5258 | Val Acc: 83.78% | Test Acc: 84.21%
# Epoch 22 | Train Loss: 0.2988 | Val Loss: 0.4717 | Val Acc: 85.10% | Test Acc: 84.83%
# Epoch 23 | Train Loss: 0.2856 | Val Loss: 0.5035 | Val Acc: 84.32% | Test Acc: 84.30%
# Epoch 24 | Train Loss: 0.2820 | Val Loss: 0.4922 | Val Acc: 85.42% | Test Acc: 85.39%
# Epoch 25 | Train Loss: 0.2785 | Val Loss: 0.4682 | Val Acc: 84.92% | Test Acc: 84.90%
# Epoch 26 | Train Loss: 0.2711 | Val Loss: 0.4685 | Val Acc: 85.76% | Test Acc: 85.66%
# Epoch 27 | Train Loss: 0.2661 | Val Loss: 0.5317 | Val Acc: 84.72% | Test Acc: 84.53%
# Epoch 28 | Train Loss: 0.2600 | Val Loss: 0.4602 | Val Acc: 86.00% | Test Acc: 85.92%
# Epoch 29 | Train Loss: 0.2552 | Val Loss: 0.4757 | Val Acc: 85.32% | Test Acc: 84.78%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 65.01it/s]
# Epoch 30 | Train Loss: 0.2505 | Val Loss: 0.4767 | Val Acc: 85.92% | Test Acc: 85.35%
# Epoch 31 | Train Loss: 0.2441 | Val Loss: 0.4779 | Val Acc: 85.52% | Test Acc: 85.33%
# Epoch 32 | Train Loss: 0.2417 | Val Loss: 0.4852 | Val Acc: 85.32% | Test Acc: 85.98%
# Epoch 33 | Train Loss: 0.2370 | Val Loss: 0.5102 | Val Acc: 85.30% | Test Acc: 85.10%
# Epoch 34 | Train Loss: 0.2315 | Val Loss: 0.4605 | Val Acc: 86.40% | Test Acc: 86.37%
# Epoch 35 | Train Loss: 0.2303 | Val Loss: 0.4697 | Val Acc: 86.16% | Test Acc: 85.90%
# Epoch 36 | Train Loss: 0.2233 | Val Loss: 0.4967 | Val Acc: 85.70% | Test Acc: 85.92%
# Epoch 37 | Train Loss: 0.2199 | Val Loss: 0.4703 | Val Acc: 86.40% | Test Acc: 85.52%
# Epoch 38 | Train Loss: 0.2152 | Val Loss: 0.4807 | Val Acc: 86.40% | Test Acc: 85.63%
# Epoch 39 | Train Loss: 0.2198 | Val Loss: 0.4244 | Val Acc: 87.30% | Test Acc: 87.20%
# Epoch 40/86: 100%|██████████| 352/352 [00:06<00:00, 57.35it/s]
# Epoch 40 | Train Loss: 0.2110 | Val Loss: 0.4718 | Val Acc: 86.06% | Test Acc: 86.13%
# Epoch 41 | Train Loss: 0.2078 | Val Loss: 0.4664 | Val Acc: 86.42% | Test Acc: 86.31%
# Epoch 42 | Train Loss: 0.2035 | Val Loss: 0.4669 | Val Acc: 86.30% | Test Acc: 86.37%
# Epoch 43 | Train Loss: 0.1985 | Val Loss: 0.4267 | Val Acc: 87.26% | Test Acc: 87.02%
# Epoch 44 | Train Loss: 0.1961 | Val Loss: 0.4584 | Val Acc: 86.98% | Test Acc: 86.31%
# Epoch 45 | Train Loss: 0.1924 | Val Loss: 0.4601 | Val Acc: 86.72% | Test Acc: 86.33%
# Epoch 46 | Train Loss: 0.1893 | Val Loss: 0.4754 | Val Acc: 86.90% | Test Acc: 85.83%
# Epoch 47 | Train Loss: 0.1906 | Val Loss: 0.4620 | Val Acc: 86.66% | Test Acc: 86.41%
# Epoch 48 | Train Loss: 0.1879 | Val Loss: 0.4453 | Val Acc: 86.92% | Test Acc: 86.80%
# Epoch 49 | Train Loss: 0.1848 | Val Loss: 0.4453 | Val Acc: 86.76% | Test Acc: 86.94%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 65.09it/s]
# Epoch 50 | Train Loss: 0.1817 | Val Loss: 0.4574 | Val Acc: 86.78% | Test Acc: 86.77%
# Epoch 51 | Train Loss: 0.1780 | Val Loss: 0.4815 | Val Acc: 86.10% | Test Acc: 85.98%
# Epoch 52 | Train Loss: 0.1726 | Val Loss: 0.4949 | Val Acc: 86.32% | Test Acc: 86.07%
# Epoch 53 | Train Loss: 0.1777 | Val Loss: 0.4696 | Val Acc: 86.86% | Test Acc: 86.39%
# Epoch 54 | Train Loss: 0.1768 | Val Loss: 0.4250 | Val Acc: 87.82% | Test Acc: 87.46%
# Epoch 55 | Train Loss: 0.1706 | Val Loss: 0.4976 | Val Acc: 86.62% | Test Acc: 85.92%
# Epoch 56 | Train Loss: 0.1704 | Val Loss: 0.4431 | Val Acc: 87.34% | Test Acc: 87.04%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.1660 | Val Loss: 0.4131 | Val Acc: 88.20% | Test Acc: 87.77%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1190 | Val Loss: 0.3555 | Val Acc: 89.50% | Test Acc: 89.19%
# Epoch 59 | Train Loss: 0.1078 | Val Loss: 0.3568 | Val Acc: 89.48% | Test Acc: 89.24%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 61.02it/s]
# Epoch 60 | Train Loss: 0.1034 | Val Loss: 0.3607 | Val Acc: 89.28% | Test Acc: 89.35%
# Epoch 61 | Train Loss: 0.0991 | Val Loss: 0.3536 | Val Acc: 89.60% | Test Acc: 89.23%
# Epoch 62 | Train Loss: 0.0952 | Val Loss: 0.3592 | Val Acc: 89.44% | Test Acc: 89.43%
# Epoch 63 | Train Loss: 0.0935 | Val Loss: 0.3620 | Val Acc: 89.42% | Test Acc: 89.40%
# Epoch 64 | Train Loss: 0.0936 | Val Loss: 0.3667 | Val Acc: 89.42% | Test Acc: 89.18%
# Epoch 65 | Train Loss: 0.0882 | Val Loss: 0.3618 | Val Acc: 89.64% | Test Acc: 89.43%
# Epoch 66 | Train Loss: 0.0888 | Val Loss: 0.3688 | Val Acc: 89.44% | Test Acc: 89.14%
# Epoch 67 | Train Loss: 0.0875 | Val Loss: 0.3709 | Val Acc: 89.38% | Test Acc: 89.14%
# Epoch 68 | Train Loss: 0.0864 | Val Loss: 0.3741 | Val Acc: 89.50% | Test Acc: 89.25%
# Epoch 69 | Train Loss: 0.0858 | Val Loss: 0.3741 | Val Acc: 89.22% | Test Acc: 89.42%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 67.20it/s]
# Epoch 70 | Train Loss: 0.0849 | Val Loss: 0.3686 | Val Acc: 89.58% | Test Acc: 89.35%
#    [Tracker] 🚩 Early Stop Condition at Iter 24992 (Epoch 71, Test Acc: 89.43%)
# Epoch 71 | Train Loss: 0.0827 | Val Loss: 0.3686 | Val Acc: 89.62% | Test Acc: 89.43%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.0827 | Val Loss: 0.3689 | Val Acc: 89.50% | Test Acc: 89.38%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.0813 | Val Loss: 0.3673 | Val Acc: 89.54% | Test Acc: 89.46%
# Epoch 74 | Train Loss: 0.0802 | Val Loss: 0.3678 | Val Acc: 89.48% | Test Acc: 89.36%
# Epoch 75 | Train Loss: 0.0795 | Val Loss: 0.3661 | Val Acc: 89.52% | Test Acc: 89.40%
# Epoch 76 | Train Loss: 0.0794 | Val Loss: 0.3676 | Val Acc: 89.52% | Test Acc: 89.36%
# Epoch 77 | Train Loss: 0.0787 | Val Loss: 0.3715 | Val Acc: 89.30% | Test Acc: 89.44%
# Epoch 78 | Train Loss: 0.0785 | Val Loss: 0.3689 | Val Acc: 89.64% | Test Acc: 89.55%
# Epoch 79 | Train Loss: 0.0792 | Val Loss: 0.3688 | Val Acc: 89.56% | Test Acc: 89.40%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 64.07it/s]
# Epoch 80 | Train Loss: 0.0781 | Val Loss: 0.3680 | Val Acc: 89.56% | Test Acc: 89.52%
# Epoch 81 | Train Loss: 0.0794 | Val Loss: 0.3739 | Val Acc: 89.46% | Test Acc: 89.39%
# Epoch 82 | Train Loss: 0.0781 | Val Loss: 0.3713 | Val Acc: 89.60% | Test Acc: 89.49%
# Epoch 83 | Train Loss: 0.0783 | Val Loss: 0.3701 | Val Acc: 89.50% | Test Acc: 89.40%
# Epoch 84 | Train Loss: 0.0778 | Val Loss: 0.3700 | Val Acc: 89.48% | Test Acc: 89.54%
# Epoch 85 | Train Loss: 0.0780 | Val Loss: 0.3704 | Val Acc: 89.36% | Test Acc: 89.46%
# Epoch 86 | Train Loss: 0.0782 | Val Loss: 0.3694 | Val Acc: 89.50% | Test Acc: 89.44%
#
# Round 3 Results:
#   Test Accuracy: 89.44%
#   Remaining Parameters: 139,086.0 (51.57%)
#
# ======================================================================
# Round 4/15
# ======================================================================
# Scheduler enabled: MultiStepLR at epochs 57 and 71
# Epoch 01 | Train Loss: 1.4069 | Val Loss: 1.1236 | Val Acc: 60.96% | Test Acc: 61.07%
# Epoch 02 | Train Loss: 0.8925 | Val Loss: 0.9824 | Val Acc: 66.84% | Test Acc: 67.22%
# Epoch 03 | Train Loss: 0.6923 | Val Loss: 0.8595 | Val Acc: 72.18% | Test Acc: 71.65%
# Epoch 04 | Train Loss: 0.5890 | Val Loss: 0.7136 | Val Acc: 76.12% | Test Acc: 76.67%
# Epoch 05 | Train Loss: 0.5413 | Val Loss: 0.6548 | Val Acc: 77.80% | Test Acc: 78.65%
# Epoch 06 | Train Loss: 0.4915 | Val Loss: 0.5888 | Val Acc: 80.36% | Test Acc: 80.57%
# Epoch 07 | Train Loss: 0.4571 | Val Loss: 0.5446 | Val Acc: 81.60% | Test Acc: 81.17%
# Epoch 08 | Train Loss: 0.4286 | Val Loss: 0.5196 | Val Acc: 82.86% | Test Acc: 83.25%
# Epoch 09 | Train Loss: 0.4108 | Val Loss: 0.6133 | Val Acc: 79.72% | Test Acc: 79.91%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 62.12it/s]
# Epoch 10 | Train Loss: 0.3851 | Val Loss: 0.5700 | Val Acc: 81.96% | Test Acc: 81.37%
# Epoch 11 | Train Loss: 0.3662 | Val Loss: 0.4837 | Val Acc: 83.82% | Test Acc: 84.17%
# Epoch 12 | Train Loss: 0.3551 | Val Loss: 0.4823 | Val Acc: 84.64% | Test Acc: 84.32%
# Epoch 13 | Train Loss: 0.3350 | Val Loss: 0.6061 | Val Acc: 81.26% | Test Acc: 81.12%
# Epoch 14 | Train Loss: 0.3318 | Val Loss: 0.5201 | Val Acc: 83.42% | Test Acc: 84.12%
# Epoch 15 | Train Loss: 0.3142 | Val Loss: 0.4778 | Val Acc: 84.84% | Test Acc: 85.75%
# Epoch 16 | Train Loss: 0.3054 | Val Loss: 0.4523 | Val Acc: 85.62% | Test Acc: 85.48%
# Epoch 17 | Train Loss: 0.2948 | Val Loss: 0.4639 | Val Acc: 85.68% | Test Acc: 85.93%
# Epoch 18 | Train Loss: 0.2840 | Val Loss: 0.5403 | Val Acc: 83.78% | Test Acc: 83.49%
# Epoch 19 | Train Loss: 0.2836 | Val Loss: 0.4967 | Val Acc: 84.78% | Test Acc: 84.98%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 63.22it/s]
# Epoch 20 | Train Loss: 0.2696 | Val Loss: 0.4202 | Val Acc: 86.46% | Test Acc: 86.70%
# Epoch 21 | Train Loss: 0.2657 | Val Loss: 0.5045 | Val Acc: 84.24% | Test Acc: 84.08%
# Epoch 22 | Train Loss: 0.2570 | Val Loss: 0.4629 | Val Acc: 85.38% | Test Acc: 85.38%
# Epoch 23 | Train Loss: 0.2532 | Val Loss: 0.4998 | Val Acc: 85.44% | Test Acc: 84.68%
# Epoch 24 | Train Loss: 0.2466 | Val Loss: 0.4320 | Val Acc: 87.22% | Test Acc: 86.31%
# Epoch 25 | Train Loss: 0.2393 | Val Loss: 0.4478 | Val Acc: 86.32% | Test Acc: 85.91%
# Epoch 26 | Train Loss: 0.2323 | Val Loss: 0.4572 | Val Acc: 85.88% | Test Acc: 86.04%
# Epoch 27 | Train Loss: 0.2339 | Val Loss: 0.4703 | Val Acc: 86.32% | Test Acc: 86.29%
# Epoch 28 | Train Loss: 0.2331 | Val Loss: 0.4747 | Val Acc: 86.30% | Test Acc: 86.05%
# Epoch 29 | Train Loss: 0.2215 | Val Loss: 0.5098 | Val Acc: 84.92% | Test Acc: 85.52%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 59.55it/s]
# Epoch 30 | Train Loss: 0.2184 | Val Loss: 0.4515 | Val Acc: 86.44% | Test Acc: 85.92%
# Epoch 31 | Train Loss: 0.2103 | Val Loss: 0.4099 | Val Acc: 87.64% | Test Acc: 87.12%
# Epoch 32 | Train Loss: 0.2096 | Val Loss: 0.4847 | Val Acc: 86.00% | Test Acc: 85.56%
# Epoch 33 | Train Loss: 0.2086 | Val Loss: 0.4554 | Val Acc: 86.20% | Test Acc: 86.68%
# Epoch 34 | Train Loss: 0.2029 | Val Loss: 0.4310 | Val Acc: 87.50% | Test Acc: 87.15%
# Epoch 35 | Train Loss: 0.1982 | Val Loss: 0.4418 | Val Acc: 87.38% | Test Acc: 86.30%
# Epoch 36 | Train Loss: 0.1981 | Val Loss: 0.4587 | Val Acc: 86.92% | Test Acc: 86.33%
# Epoch 37 | Train Loss: 0.1892 | Val Loss: 0.4840 | Val Acc: 87.12% | Test Acc: 86.30%
# Epoch 38 | Train Loss: 0.1921 | Val Loss: 0.4447 | Val Acc: 86.84% | Test Acc: 86.81%
# Epoch 39 | Train Loss: 0.1908 | Val Loss: 0.4656 | Val Acc: 86.90% | Test Acc: 86.40%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 64.78it/s]
# Epoch 40 | Train Loss: 0.1814 | Val Loss: 0.4352 | Val Acc: 87.42% | Test Acc: 87.22%
# Epoch 41 | Train Loss: 0.1804 | Val Loss: 0.4850 | Val Acc: 86.24% | Test Acc: 85.87%
# Epoch 42 | Train Loss: 0.1770 | Val Loss: 0.4939 | Val Acc: 86.58% | Test Acc: 86.17%
# Epoch 43 | Train Loss: 0.1776 | Val Loss: 0.4750 | Val Acc: 86.96% | Test Acc: 86.47%
# Epoch 44 | Train Loss: 0.1749 | Val Loss: 0.4517 | Val Acc: 87.46% | Test Acc: 87.01%
# Epoch 45 | Train Loss: 0.1733 | Val Loss: 0.4432 | Val Acc: 87.76% | Test Acc: 86.83%
# Epoch 46 | Train Loss: 0.1686 | Val Loss: 0.4399 | Val Acc: 87.42% | Test Acc: 87.40%
# Epoch 47 | Train Loss: 0.1685 | Val Loss: 0.4650 | Val Acc: 86.96% | Test Acc: 87.03%
# Epoch 48 | Train Loss: 0.1651 | Val Loss: 0.4399 | Val Acc: 87.76% | Test Acc: 87.45%
# Epoch 49 | Train Loss: 0.1635 | Val Loss: 0.4441 | Val Acc: 87.88% | Test Acc: 87.65%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 63.02it/s]
# Epoch 50 | Train Loss: 0.1668 | Val Loss: 0.4488 | Val Acc: 87.80% | Test Acc: 87.13%
# Epoch 51 | Train Loss: 0.1623 | Val Loss: 0.4702 | Val Acc: 86.64% | Test Acc: 86.89%
# Epoch 52 | Train Loss: 0.1560 | Val Loss: 0.4816 | Val Acc: 87.46% | Test Acc: 86.79%
# Epoch 53 | Train Loss: 0.1565 | Val Loss: 0.4817 | Val Acc: 86.98% | Test Acc: 87.37%
# Epoch 54 | Train Loss: 0.1585 | Val Loss: 0.4633 | Val Acc: 87.76% | Test Acc: 87.50%
# Epoch 55 | Train Loss: 0.1562 | Val Loss: 0.4764 | Val Acc: 87.08% | Test Acc: 86.55%
# Epoch 56 | Train Loss: 0.1534 | Val Loss: 0.4497 | Val Acc: 87.92% | Test Acc: 87.59%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.1505 | Val Loss: 0.4799 | Val Acc: 86.90% | Test Acc: 87.06%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1102 | Val Loss: 0.3817 | Val Acc: 89.44% | Test Acc: 89.27%
# Epoch 59 | Train Loss: 0.0979 | Val Loss: 0.3811 | Val Acc: 89.54% | Test Acc: 89.37%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 61.62it/s]
# Epoch 60 | Train Loss: 0.0942 | Val Loss: 0.3787 | Val Acc: 89.40% | Test Acc: 89.31%
# Epoch 61 | Train Loss: 0.0895 | Val Loss: 0.3782 | Val Acc: 89.44% | Test Acc: 89.44%
# Epoch 62 | Train Loss: 0.0865 | Val Loss: 0.3810 | Val Acc: 89.40% | Test Acc: 89.49%
# Epoch 63 | Train Loss: 0.0833 | Val Loss: 0.3782 | Val Acc: 89.60% | Test Acc: 89.47%
# Epoch 64 | Train Loss: 0.0828 | Val Loss: 0.3816 | Val Acc: 89.44% | Test Acc: 89.59%
# Epoch 65 | Train Loss: 0.0816 | Val Loss: 0.3778 | Val Acc: 89.36% | Test Acc: 89.45%
# Epoch 66 | Train Loss: 0.0817 | Val Loss: 0.3844 | Val Acc: 89.44% | Test Acc: 89.60%
# Epoch 67 | Train Loss: 0.0797 | Val Loss: 0.3822 | Val Acc: 89.44% | Test Acc: 89.59%
# Epoch 68 | Train Loss: 0.0781 | Val Loss: 0.3847 | Val Acc: 89.40% | Test Acc: 89.61%
# Epoch 69 | Train Loss: 0.0788 | Val Loss: 0.3816 | Val Acc: 89.76% | Test Acc: 89.69%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 59.72it/s]
#    [Tracker] 🚩 Early Stop Condition at Iter 24640 (Epoch 70, Test Acc: 89.67%)
# Epoch 70 | Train Loss: 0.0770 | Val Loss: 0.3833 | Val Acc: 89.70% | Test Acc: 89.67%
# Epoch 71 | Train Loss: 0.0746 | Val Loss: 0.3863 | Val Acc: 89.44% | Test Acc: 89.61%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.0739 | Val Loss: 0.3862 | Val Acc: 89.56% | Test Acc: 89.65%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.0737 | Val Loss: 0.3874 | Val Acc: 89.52% | Test Acc: 89.51%
# Epoch 74 | Train Loss: 0.0737 | Val Loss: 0.3858 | Val Acc: 89.44% | Test Acc: 89.60%
# Epoch 75 | Train Loss: 0.0708 | Val Loss: 0.3866 | Val Acc: 89.54% | Test Acc: 89.60%
# Epoch 76 | Train Loss: 0.0702 | Val Loss: 0.3845 | Val Acc: 89.44% | Test Acc: 89.46%
# Epoch 77 | Train Loss: 0.0705 | Val Loss: 0.3839 | Val Acc: 89.48% | Test Acc: 89.64%
# Epoch 78 | Train Loss: 0.0712 | Val Loss: 0.3839 | Val Acc: 89.56% | Test Acc: 89.47%
# Epoch 79 | Train Loss: 0.0706 | Val Loss: 0.3849 | Val Acc: 89.46% | Test Acc: 89.59%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 65.31it/s]
# Epoch 80 | Train Loss: 0.0709 | Val Loss: 0.3858 | Val Acc: 89.46% | Test Acc: 89.63%
# Epoch 81 | Train Loss: 0.0695 | Val Loss: 0.3801 | Val Acc: 89.52% | Test Acc: 89.62%
# Epoch 82 | Train Loss: 0.0706 | Val Loss: 0.3875 | Val Acc: 89.64% | Test Acc: 89.55%
# Epoch 83 | Train Loss: 0.0706 | Val Loss: 0.3899 | Val Acc: 89.36% | Test Acc: 89.55%
# Epoch 84 | Train Loss: 0.0721 | Val Loss: 0.3876 | Val Acc: 89.52% | Test Acc: 89.51%
# Epoch 85 | Train Loss: 0.0706 | Val Loss: 0.3862 | Val Acc: 89.52% | Test Acc: 89.57%
# Epoch 86 | Train Loss: 0.0711 | Val Loss: 0.3867 | Val Acc: 89.52% | Test Acc: 89.64%
#
# Round 4 Results:
#   Test Accuracy: 89.64%
#   Remaining Parameters: 111,674.0 (41.40%)
#
# ======================================================================
# Round 5/15
# ======================================================================
# Scheduler enabled: MultiStepLR at epochs 57 and 71
# Epoch 01 | Train Loss: 1.3080 | Val Loss: 0.9750 | Val Acc: 66.88% | Test Acc: 66.53%
# Epoch 02 | Train Loss: 0.7657 | Val Loss: 0.8589 | Val Acc: 70.52% | Test Acc: 70.35%
# Epoch 03 | Train Loss: 0.6134 | Val Loss: 0.7150 | Val Acc: 76.08% | Test Acc: 75.15%
# Epoch 04 | Train Loss: 0.5292 | Val Loss: 0.6318 | Val Acc: 79.30% | Test Acc: 79.33%
# Epoch 05 | Train Loss: 0.4718 | Val Loss: 0.6668 | Val Acc: 78.50% | Test Acc: 78.11%
# Epoch 06 | Train Loss: 0.4333 | Val Loss: 0.5988 | Val Acc: 80.62% | Test Acc: 80.25%
# Epoch 07 | Train Loss: 0.4040 | Val Loss: 0.5342 | Val Acc: 82.58% | Test Acc: 83.05%
# Epoch 08 | Train Loss: 0.3717 | Val Loss: 0.5220 | Val Acc: 82.86% | Test Acc: 82.83%
# Epoch 09 | Train Loss: 0.3528 | Val Loss: 0.5018 | Val Acc: 83.64% | Test Acc: 83.79%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 66.97it/s]
# Epoch 10 | Train Loss: 0.3350 | Val Loss: 0.5691 | Val Acc: 82.12% | Test Acc: 81.97%
# Epoch 11 | Train Loss: 0.3148 | Val Loss: 0.4829 | Val Acc: 85.16% | Test Acc: 84.16%
# Epoch 12 | Train Loss: 0.3039 | Val Loss: 0.4225 | Val Acc: 86.72% | Test Acc: 85.48%
# Epoch 13 | Train Loss: 0.2927 | Val Loss: 0.5229 | Val Acc: 83.12% | Test Acc: 83.26%
# Epoch 14 | Train Loss: 0.2871 | Val Loss: 0.7315 | Val Acc: 78.38% | Test Acc: 77.97%
# Epoch 15 | Train Loss: 0.2722 | Val Loss: 0.4558 | Val Acc: 85.70% | Test Acc: 85.53%
# Epoch 16 | Train Loss: 0.2657 | Val Loss: 0.5220 | Val Acc: 84.14% | Test Acc: 83.60%
# Epoch 17 | Train Loss: 0.2555 | Val Loss: 0.4911 | Val Acc: 85.10% | Test Acc: 85.13%
# Epoch 18 | Train Loss: 0.2530 | Val Loss: 0.4712 | Val Acc: 85.82% | Test Acc: 85.36%
# Epoch 19 | Train Loss: 0.2399 | Val Loss: 0.4501 | Val Acc: 86.84% | Test Acc: 86.50%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 63.64it/s]
# Epoch 20 | Train Loss: 0.2364 | Val Loss: 0.4457 | Val Acc: 86.68% | Test Acc: 86.23%
# Epoch 21 | Train Loss: 0.2268 | Val Loss: 0.4414 | Val Acc: 86.70% | Test Acc: 86.29%
# Epoch 22 | Train Loss: 0.2258 | Val Loss: 0.4210 | Val Acc: 87.88% | Test Acc: 87.20%
# Epoch 23 | Train Loss: 0.2200 | Val Loss: 0.4298 | Val Acc: 87.24% | Test Acc: 86.64%
# Epoch 24 | Train Loss: 0.2184 | Val Loss: 0.4818 | Val Acc: 86.08% | Test Acc: 85.00%
# Epoch 25 | Train Loss: 0.2108 | Val Loss: 0.4587 | Val Acc: 86.00% | Test Acc: 85.85%
# Epoch 26 | Train Loss: 0.2057 | Val Loss: 0.4824 | Val Acc: 86.30% | Test Acc: 86.09%
# Epoch 27 | Train Loss: 0.2003 | Val Loss: 0.4883 | Val Acc: 85.62% | Test Acc: 85.28%
# Epoch 28 | Train Loss: 0.2013 | Val Loss: 0.4674 | Val Acc: 86.62% | Test Acc: 86.05%
# Epoch 29 | Train Loss: 0.1924 | Val Loss: 0.4192 | Val Acc: 87.54% | Test Acc: 87.12%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 65.12it/s]
# Epoch 30 | Train Loss: 0.1925 | Val Loss: 0.4493 | Val Acc: 87.08% | Test Acc: 86.85%
# Epoch 31 | Train Loss: 0.1918 | Val Loss: 0.4682 | Val Acc: 86.98% | Test Acc: 86.36%
# Epoch 32 | Train Loss: 0.1807 | Val Loss: 0.4513 | Val Acc: 87.16% | Test Acc: 86.79%
# Epoch 33 | Train Loss: 0.1855 | Val Loss: 0.4406 | Val Acc: 87.98% | Test Acc: 86.97%
# Epoch 34 | Train Loss: 0.1798 | Val Loss: 0.4729 | Val Acc: 87.12% | Test Acc: 86.25%
# Epoch 35 | Train Loss: 0.1779 | Val Loss: 0.4608 | Val Acc: 86.88% | Test Acc: 87.28%
# Epoch 36 | Train Loss: 0.1770 | Val Loss: 0.4340 | Val Acc: 87.96% | Test Acc: 86.92%
# Epoch 37 | Train Loss: 0.1724 | Val Loss: 0.4610 | Val Acc: 87.22% | Test Acc: 87.34%
# Epoch 38 | Train Loss: 0.1690 | Val Loss: 0.4482 | Val Acc: 87.58% | Test Acc: 87.23%
# Epoch 39 | Train Loss: 0.1672 | Val Loss: 0.4439 | Val Acc: 86.78% | Test Acc: 87.30%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 61.24it/s]
# Epoch 40 | Train Loss: 0.1632 | Val Loss: 0.4704 | Val Acc: 87.16% | Test Acc: 86.92%
# Epoch 41 | Train Loss: 0.1622 | Val Loss: 0.4388 | Val Acc: 87.48% | Test Acc: 87.08%
# Epoch 42 | Train Loss: 0.1592 | Val Loss: 0.4447 | Val Acc: 87.68% | Test Acc: 86.82%
# Epoch 43 | Train Loss: 0.1578 | Val Loss: 0.5022 | Val Acc: 86.40% | Test Acc: 85.98%
# Epoch 44 | Train Loss: 0.1565 | Val Loss: 0.4639 | Val Acc: 87.20% | Test Acc: 86.91%
# Epoch 45 | Train Loss: 0.1549 | Val Loss: 0.4618 | Val Acc: 87.32% | Test Acc: 86.82%
# Epoch 46 | Train Loss: 0.1541 | Val Loss: 0.5764 | Val Acc: 85.14% | Test Acc: 84.81%
# Epoch 47 | Train Loss: 0.1571 | Val Loss: 0.4741 | Val Acc: 87.12% | Test Acc: 87.12%
# Epoch 48 | Train Loss: 0.1525 | Val Loss: 0.4192 | Val Acc: 87.96% | Test Acc: 86.75%
# Epoch 49 | Train Loss: 0.1506 | Val Loss: 0.4815 | Val Acc: 86.98% | Test Acc: 86.81%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 69.34it/s]
# Epoch 50 | Train Loss: 0.1462 | Val Loss: 0.4522 | Val Acc: 87.50% | Test Acc: 87.22%
# Epoch 51 | Train Loss: 0.1467 | Val Loss: 0.4405 | Val Acc: 87.82% | Test Acc: 87.68%
# Epoch 52 | Train Loss: 0.1414 | Val Loss: 0.4737 | Val Acc: 87.12% | Test Acc: 86.91%
# Epoch 53 | Train Loss: 0.1388 | Val Loss: 0.4092 | Val Acc: 88.40% | Test Acc: 87.42%
# Epoch 54 | Train Loss: 0.1372 | Val Loss: 0.4278 | Val Acc: 87.86% | Test Acc: 88.57%
# Epoch 55 | Train Loss: 0.1376 | Val Loss: 0.4805 | Val Acc: 87.66% | Test Acc: 87.01%
# Epoch 56 | Train Loss: 0.1392 | Val Loss: 0.5091 | Val Acc: 86.66% | Test Acc: 86.97%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.1387 | Val Loss: 0.4755 | Val Acc: 87.30% | Test Acc: 86.87%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1027 | Val Loss: 0.3827 | Val Acc: 89.56% | Test Acc: 89.24%
# Epoch 59 | Train Loss: 0.0885 | Val Loss: 0.3807 | Val Acc: 89.40% | Test Acc: 89.48%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 67.58it/s]
# Epoch 60 | Train Loss: 0.0831 | Val Loss: 0.3814 | Val Acc: 89.54% | Test Acc: 89.05%
# Epoch 61 | Train Loss: 0.0813 | Val Loss: 0.3757 | Val Acc: 89.66% | Test Acc: 89.53%
# Epoch 62 | Train Loss: 0.0809 | Val Loss: 0.3821 | Val Acc: 89.68% | Test Acc: 89.41%
# Epoch 63 | Train Loss: 0.0789 | Val Loss: 0.3875 | Val Acc: 89.52% | Test Acc: 89.34%
# Epoch 64 | Train Loss: 0.0754 | Val Loss: 0.3823 | Val Acc: 89.50% | Test Acc: 89.44%
# Epoch 65 | Train Loss: 0.0731 | Val Loss: 0.3869 | Val Acc: 89.70% | Test Acc: 89.26%
# Epoch 66 | Train Loss: 0.0731 | Val Loss: 0.3842 | Val Acc: 89.78% | Test Acc: 89.35%
# Epoch 67 | Train Loss: 0.0737 | Val Loss: 0.3851 | Val Acc: 89.54% | Test Acc: 89.28%
# Epoch 68 | Train Loss: 0.0716 | Val Loss: 0.3878 | Val Acc: 89.84% | Test Acc: 89.29%
# Epoch 69 | Train Loss: 0.0722 | Val Loss: 0.3862 | Val Acc: 89.70% | Test Acc: 89.49%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 62.45it/s]
# Epoch 70 | Train Loss: 0.0675 | Val Loss: 0.3916 | Val Acc: 89.52% | Test Acc: 89.24%
#    [Tracker] 🚩 Early Stop Condition at Iter 24992 (Epoch 71, Test Acc: 89.42%)
# Epoch 71 | Train Loss: 0.0702 | Val Loss: 0.3834 | Val Acc: 89.76% | Test Acc: 89.42%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.0701 | Val Loss: 0.3847 | Val Acc: 89.76% | Test Acc: 89.35%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.0659 | Val Loss: 0.3836 | Val Acc: 89.62% | Test Acc: 89.42%
# Epoch 74 | Train Loss: 0.0640 | Val Loss: 0.3821 | Val Acc: 89.80% | Test Acc: 89.49%
# Epoch 75 | Train Loss: 0.0655 | Val Loss: 0.3842 | Val Acc: 89.82% | Test Acc: 89.46%
# Epoch 76 | Train Loss: 0.0669 | Val Loss: 0.3839 | Val Acc: 89.66% | Test Acc: 89.47%
# Epoch 77 | Train Loss: 0.0643 | Val Loss: 0.3835 | Val Acc: 89.70% | Test Acc: 89.41%
# Epoch 78 | Train Loss: 0.0654 | Val Loss: 0.3844 | Val Acc: 89.74% | Test Acc: 89.38%
# Epoch 79 | Train Loss: 0.0640 | Val Loss: 0.3840 | Val Acc: 89.78% | Test Acc: 89.35%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 64.34it/s]
# Epoch 80 | Train Loss: 0.0658 | Val Loss: 0.3861 | Val Acc: 89.68% | Test Acc: 89.29%
# Epoch 81 | Train Loss: 0.0641 | Val Loss: 0.3831 | Val Acc: 89.76% | Test Acc: 89.47%
# Epoch 82 | Train Loss: 0.0652 | Val Loss: 0.3838 | Val Acc: 89.80% | Test Acc: 89.49%
# Epoch 83 | Train Loss: 0.0647 | Val Loss: 0.3827 | Val Acc: 89.84% | Test Acc: 89.44%
# Epoch 84 | Train Loss: 0.0668 | Val Loss: 0.3850 | Val Acc: 89.80% | Test Acc: 89.51%
# Epoch 85 | Train Loss: 0.0632 | Val Loss: 0.3828 | Val Acc: 89.84% | Test Acc: 89.60%
# Epoch 86 | Train Loss: 0.0654 | Val Loss: 0.3850 | Val Acc: 89.84% | Test Acc: 89.49%
#
# Round 5 Results:
#   Test Accuracy: 89.49%
#   Remaining Parameters: 89,744.0 (33.27%)
#
# ======================================================================
# Round 6/15
# ======================================================================
# Scheduler enabled: MultiStepLR at epochs 57 and 71
# Epoch 01 | Train Loss: 1.2307 | Val Loss: 0.8985 | Val Acc: 69.66% | Test Acc: 69.41%
# Epoch 02 | Train Loss: 0.6806 | Val Loss: 0.7601 | Val Acc: 74.14% | Test Acc: 74.24%
# Epoch 03 | Train Loss: 0.5329 | Val Loss: 0.7824 | Val Acc: 74.82% | Test Acc: 74.85%
# Epoch 04 | Train Loss: 0.4565 | Val Loss: 0.5507 | Val Acc: 81.54% | Test Acc: 81.42%
# Epoch 05 | Train Loss: 0.4012 | Val Loss: 0.5068 | Val Acc: 83.22% | Test Acc: 83.16%
# Epoch 06 | Train Loss: 0.3720 | Val Loss: 0.4728 | Val Acc: 84.74% | Test Acc: 84.33%
# Epoch 07 | Train Loss: 0.3439 | Val Loss: 0.5244 | Val Acc: 83.64% | Test Acc: 83.17%
# Epoch 08 | Train Loss: 0.3213 | Val Loss: 0.4947 | Val Acc: 84.54% | Test Acc: 84.67%
# Epoch 09 | Train Loss: 0.2994 | Val Loss: 0.5077 | Val Acc: 83.82% | Test Acc: 84.48%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 64.26it/s]
# Epoch 10 | Train Loss: 0.2861 | Val Loss: 0.4508 | Val Acc: 85.62% | Test Acc: 85.65%
# Epoch 11 | Train Loss: 0.2707 | Val Loss: 0.4715 | Val Acc: 85.38% | Test Acc: 85.65%
# Epoch 12 | Train Loss: 0.2573 | Val Loss: 0.5006 | Val Acc: 84.82% | Test Acc: 84.08%
# Epoch 13 | Train Loss: 0.2478 | Val Loss: 0.4535 | Val Acc: 85.76% | Test Acc: 84.87%
# Epoch 14 | Train Loss: 0.2419 | Val Loss: 0.5120 | Val Acc: 84.60% | Test Acc: 85.08%
# Epoch 15 | Train Loss: 0.2340 | Val Loss: 0.5132 | Val Acc: 84.54% | Test Acc: 84.41%
# Epoch 16 | Train Loss: 0.2261 | Val Loss: 0.4437 | Val Acc: 86.02% | Test Acc: 86.12%
# Epoch 17 | Train Loss: 0.2196 | Val Loss: 0.4474 | Val Acc: 86.28% | Test Acc: 86.99%
# Epoch 18 | Train Loss: 0.2113 | Val Loss: 0.4217 | Val Acc: 87.32% | Test Acc: 87.03%
# Epoch 19 | Train Loss: 0.2061 | Val Loss: 0.4839 | Val Acc: 85.82% | Test Acc: 86.04%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 66.97it/s]
# Epoch 20 | Train Loss: 0.2021 | Val Loss: 0.4388 | Val Acc: 86.90% | Test Acc: 86.51%
# Epoch 21 | Train Loss: 0.1979 | Val Loss: 0.4439 | Val Acc: 86.84% | Test Acc: 87.39%
# Epoch 22 | Train Loss: 0.1942 | Val Loss: 0.4985 | Val Acc: 85.76% | Test Acc: 85.92%
# Epoch 23 | Train Loss: 0.1872 | Val Loss: 0.5100 | Val Acc: 85.50% | Test Acc: 85.22%
# Epoch 24 | Train Loss: 0.1821 | Val Loss: 0.4574 | Val Acc: 86.34% | Test Acc: 86.60%
# Epoch 25 | Train Loss: 0.1818 | Val Loss: 0.4304 | Val Acc: 86.94% | Test Acc: 87.18%
# Epoch 26 | Train Loss: 0.1785 | Val Loss: 0.4629 | Val Acc: 86.68% | Test Acc: 86.65%
# Epoch 27 | Train Loss: 0.1724 | Val Loss: 0.4504 | Val Acc: 87.04% | Test Acc: 87.10%
# Epoch 28 | Train Loss: 0.1695 | Val Loss: 0.4313 | Val Acc: 87.54% | Test Acc: 87.33%
# Epoch 29 | Train Loss: 0.1710 | Val Loss: 0.5188 | Val Acc: 85.20% | Test Acc: 85.55%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 68.54it/s]
# Epoch 30 | Train Loss: 0.1643 | Val Loss: 0.4395 | Val Acc: 87.60% | Test Acc: 87.21%
# Epoch 31 | Train Loss: 0.1651 | Val Loss: 0.4413 | Val Acc: 87.52% | Test Acc: 87.67%
# Epoch 32 | Train Loss: 0.1654 | Val Loss: 0.4779 | Val Acc: 86.38% | Test Acc: 86.81%
# Epoch 33 | Train Loss: 0.1562 | Val Loss: 0.4416 | Val Acc: 87.58% | Test Acc: 87.56%
# Epoch 34 | Train Loss: 0.1566 | Val Loss: 0.4459 | Val Acc: 87.38% | Test Acc: 87.45%
# Epoch 35 | Train Loss: 0.1578 | Val Loss: 0.4318 | Val Acc: 87.64% | Test Acc: 87.58%
# Epoch 36 | Train Loss: 0.1524 | Val Loss: 0.4680 | Val Acc: 87.14% | Test Acc: 87.08%
# Epoch 37 | Train Loss: 0.1503 | Val Loss: 0.4895 | Val Acc: 86.42% | Test Acc: 86.29%
# Epoch 38 | Train Loss: 0.1513 | Val Loss: 0.4495 | Val Acc: 87.40% | Test Acc: 87.53%
# Epoch 39 | Train Loss: 0.1489 | Val Loss: 0.4838 | Val Acc: 86.88% | Test Acc: 86.86%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 63.84it/s]
# Epoch 40 | Train Loss: 0.1471 | Val Loss: 0.4616 | Val Acc: 87.32% | Test Acc: 87.62%
# Epoch 41 | Train Loss: 0.1483 | Val Loss: 0.4372 | Val Acc: 87.70% | Test Acc: 87.57%
# Epoch 42 | Train Loss: 0.1429 | Val Loss: 0.4337 | Val Acc: 88.16% | Test Acc: 87.56%
# Epoch 43 | Train Loss: 0.1390 | Val Loss: 0.4474 | Val Acc: 87.78% | Test Acc: 87.10%
# Epoch 44 | Train Loss: 0.1409 | Val Loss: 0.4682 | Val Acc: 87.64% | Test Acc: 87.32%
# Epoch 45 | Train Loss: 0.1444 | Val Loss: 0.4353 | Val Acc: 88.28% | Test Acc: 88.03%
# Epoch 46 | Train Loss: 0.1374 | Val Loss: 0.5426 | Val Acc: 86.28% | Test Acc: 85.60%
# Epoch 47 | Train Loss: 0.1349 | Val Loss: 0.4213 | Val Acc: 88.44% | Test Acc: 88.03%
# Epoch 48 | Train Loss: 0.1325 | Val Loss: 0.4229 | Val Acc: 88.30% | Test Acc: 88.33%
# Epoch 49 | Train Loss: 0.1340 | Val Loss: 0.4412 | Val Acc: 87.82% | Test Acc: 87.92%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 60.37it/s]
# Epoch 50 | Train Loss: 0.1280 | Val Loss: 0.4499 | Val Acc: 87.82% | Test Acc: 87.84%
# Epoch 51 | Train Loss: 0.1296 | Val Loss: 0.5333 | Val Acc: 86.42% | Test Acc: 86.14%
# Epoch 52 | Train Loss: 0.1319 | Val Loss: 0.4507 | Val Acc: 87.60% | Test Acc: 87.25%
# Epoch 53 | Train Loss: 0.1347 | Val Loss: 0.5642 | Val Acc: 85.72% | Test Acc: 85.60%
# Epoch 54 | Train Loss: 0.1310 | Val Loss: 0.4477 | Val Acc: 88.30% | Test Acc: 87.69%
# Epoch 55 | Train Loss: 0.1277 | Val Loss: 0.4607 | Val Acc: 87.94% | Test Acc: 87.72%
# Epoch 56 | Train Loss: 0.1272 | Val Loss: 0.4619 | Val Acc: 87.78% | Test Acc: 87.52%
#  -> Scheduler Step! Current LR: 0.01
# ...
# Epoch 13 | Train Loss: 0.3720 | Val Loss: 0.5102 | Val Acc: 83.26% | Test Acc: 82.54%
# Epoch 14 | Train Loss: 0.3609 | Val Loss: 0.4419 | Val Acc: 85.46% | Test Acc: 84.75%
# Epoch 15 | Train Loss: 0.3513 | Val Loss: 0.4659 | Val Acc: 84.84% | Test Acc: 83.91%
# Epoch 16 | Train Loss: 0.3423 | Val Loss: 0.4716 | Val Acc: 84.76% | Test Acc: 84.02%
# Epoch 17 | Train Loss: 0.3383 | Val Loss: 0.4663 | Val Acc: 84.38% | Test Acc: 84.40%
# Epoch 18 | Train Loss: 0.3327 | Val Loss: 0.4747 | Val Acc: 84.62% | Test Acc: 84.12%
# Epoch 19 | Train Loss: 0.3270 | Val Loss: 0.4940 | Val Acc: 83.98% | Test Acc: 84.16%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 61.47it/s]
# Epoch 20 | Train Loss: 0.3212 | Val Loss: 0.4281 | Val Acc: 85.88% | Test Acc: 85.57%
# Epoch 21 | Train Loss: 0.3225 | Val Loss: 0.4145 | Val Acc: 85.60% | Test Acc: 85.31%
# Epoch 22 | Train Loss: 0.3101 | Val Loss: 0.4599 | Val Acc: 85.08% | Test Acc: 84.87%
# Epoch 23 | Train Loss: 0.3112 | Val Loss: 0.4420 | Val Acc: 85.32% | Test Acc: 85.54%
# Epoch 24 | Train Loss: 0.3047 | Val Loss: 0.4908 | Val Acc: 84.62% | Test Acc: 84.01%
# Epoch 25 | Train Loss: 0.3014 | Val Loss: 0.4969 | Val Acc: 84.18% | Test Acc: 84.61%
# Epoch 26 | Train Loss: 0.2997 | Val Loss: 0.4460 | Val Acc: 85.24% | Test Acc: 84.73%
# Epoch 27 | Train Loss: 0.2990 | Val Loss: 0.4424 | Val Acc: 85.46% | Test Acc: 85.56%
# Epoch 28 | Train Loss: 0.2924 | Val Loss: 0.4907 | Val Acc: 84.52% | Test Acc: 84.16%
# Epoch 29 | Train Loss: 0.2927 | Val Loss: 0.4701 | Val Acc: 85.22% | Test Acc: 85.25%
# Epoch 30/86: 100%|██████████| 352/352 [00:06<00:00, 58.57it/s]
# Epoch 30 | Train Loss: 0.2906 | Val Loss: 0.4700 | Val Acc: 84.96% | Test Acc: 84.81%
# Epoch 31 | Train Loss: 0.2868 | Val Loss: 0.4522 | Val Acc: 85.74% | Test Acc: 85.39%
# Epoch 32 | Train Loss: 0.2843 | Val Loss: 0.4256 | Val Acc: 86.94% | Test Acc: 86.02%
# Epoch 33 | Train Loss: 0.2842 | Val Loss: 0.4645 | Val Acc: 85.76% | Test Acc: 85.20%
# Epoch 34 | Train Loss: 0.2838 | Val Loss: 0.4415 | Val Acc: 86.16% | Test Acc: 85.48%
# Epoch 35 | Train Loss: 0.2781 | Val Loss: 0.4142 | Val Acc: 86.82% | Test Acc: 86.34%
# Epoch 36 | Train Loss: 0.2813 | Val Loss: 0.4338 | Val Acc: 86.04% | Test Acc: 85.31%
# Epoch 37 | Train Loss: 0.2807 | Val Loss: 0.4131 | Val Acc: 86.64% | Test Acc: 86.19%
# Epoch 38 | Train Loss: 0.2775 | Val Loss: 0.4239 | Val Acc: 86.26% | Test Acc: 85.87%
# Epoch 39 | Train Loss: 0.2777 | Val Loss: 0.4428 | Val Acc: 86.06% | Test Acc: 85.18%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 61.41it/s]
# Epoch 40 | Train Loss: 0.2740 | Val Loss: 0.4792 | Val Acc: 84.84% | Test Acc: 84.26%
# Epoch 41 | Train Loss: 0.2745 | Val Loss: 0.4508 | Val Acc: 85.84% | Test Acc: 85.23%
# Epoch 42 | Train Loss: 0.2698 | Val Loss: 0.4068 | Val Acc: 86.82% | Test Acc: 86.31%
# Epoch 43 | Train Loss: 0.2674 | Val Loss: 0.4273 | Val Acc: 86.68% | Test Acc: 85.75%
# Epoch 44 | Train Loss: 0.2684 | Val Loss: 0.4491 | Val Acc: 86.04% | Test Acc: 85.39%
# Epoch 45 | Train Loss: 0.2683 | Val Loss: 0.4258 | Val Acc: 86.68% | Test Acc: 86.30%
# Epoch 46 | Train Loss: 0.2694 | Val Loss: 0.4103 | Val Acc: 87.22% | Test Acc: 86.67%
# Epoch 47 | Train Loss: 0.2649 | Val Loss: 0.4602 | Val Acc: 86.32% | Test Acc: 86.22%
# Epoch 48 | Train Loss: 0.2657 | Val Loss: 0.4752 | Val Acc: 85.50% | Test Acc: 85.17%
# Epoch 49 | Train Loss: 0.2677 | Val Loss: 0.4173 | Val Acc: 86.86% | Test Acc: 86.78%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 64.70it/s]
# Epoch 50 | Train Loss: 0.2645 | Val Loss: 0.4815 | Val Acc: 85.26% | Test Acc: 84.18%
# Epoch 51 | Train Loss: 0.2660 | Val Loss: 0.4278 | Val Acc: 86.34% | Test Acc: 86.04%
# Epoch 52 | Train Loss: 0.2670 | Val Loss: 0.4049 | Val Acc: 87.26% | Test Acc: 86.92%
# Epoch 53 | Train Loss: 0.2604 | Val Loss: 0.5077 | Val Acc: 84.64% | Test Acc: 84.75%
# Epoch 54 | Train Loss: 0.2600 | Val Loss: 0.4593 | Val Acc: 86.20% | Test Acc: 85.96%
# Epoch 55 | Train Loss: 0.2639 | Val Loss: 0.4314 | Val Acc: 85.88% | Test Acc: 86.08%
# Epoch 56 | Train Loss: 0.2644 | Val Loss: 0.4339 | Val Acc: 86.44% | Test Acc: 86.09%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.2587 | Val Loss: 0.4241 | Val Acc: 86.84% | Test Acc: 86.28%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2276 | Val Loss: 0.3691 | Val Acc: 88.20% | Test Acc: 87.98%
# Epoch 59 | Train Loss: 0.2176 | Val Loss: 0.3647 | Val Acc: 88.50% | Test Acc: 88.00%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 59.51it/s]
# Epoch 60 | Train Loss: 0.2133 | Val Loss: 0.3683 | Val Acc: 88.42% | Test Acc: 87.94%
# Epoch 61 | Train Loss: 0.2117 | Val Loss: 0.3670 | Val Acc: 88.30% | Test Acc: 88.01%
# Epoch 62 | Train Loss: 0.2098 | Val Loss: 0.3692 | Val Acc: 88.10% | Test Acc: 87.86%
# Epoch 63 | Train Loss: 0.2066 | Val Loss: 0.3676 | Val Acc: 88.50% | Test Acc: 88.03%
# Epoch 64 | Train Loss: 0.2089 | Val Loss: 0.3683 | Val Acc: 88.36% | Test Acc: 87.88%
# Epoch 65 | Train Loss: 0.2034 | Val Loss: 0.3658 | Val Acc: 88.36% | Test Acc: 87.94%
# Epoch 66 | Train Loss: 0.2063 | Val Loss: 0.3681 | Val Acc: 88.38% | Test Acc: 88.04%
# Epoch 67 | Train Loss: 0.2053 | Val Loss: 0.3664 | Val Acc: 88.40% | Test Acc: 87.94%
# Epoch 68 | Train Loss: 0.2029 | Val Loss: 0.3688 | Val Acc: 88.26% | Test Acc: 88.05%
#    [Tracker] 🚩 Early Stop Condition at Iter 24288 (Epoch 69, Test Acc: 88.03%)
# Epoch 69 | Train Loss: 0.2021 | Val Loss: 0.3674 | Val Acc: 88.52% | Test Acc: 88.03%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 61.13it/s]
# Epoch 70 | Train Loss: 0.2051 | Val Loss: 0.3689 | Val Acc: 88.30% | Test Acc: 88.01%
# Epoch 71 | Train Loss: 0.2019 | Val Loss: 0.3693 | Val Acc: 88.42% | Test Acc: 88.05%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.1997 | Val Loss: 0.3679 | Val Acc: 88.46% | Test Acc: 88.04%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.2014 | Val Loss: 0.3687 | Val Acc: 88.32% | Test Acc: 88.02%
# Epoch 74 | Train Loss: 0.1978 | Val Loss: 0.3669 | Val Acc: 88.54% | Test Acc: 88.17%
# Epoch 75 | Train Loss: 0.1975 | Val Loss: 0.3675 | Val Acc: 88.28% | Test Acc: 88.12%
# Epoch 76 | Train Loss: 0.2002 | Val Loss: 0.3675 | Val Acc: 88.34% | Test Acc: 88.19%
# Epoch 77 | Train Loss: 0.1984 | Val Loss: 0.3723 | Val Acc: 88.26% | Test Acc: 87.94%
# Epoch 78 | Train Loss: 0.1958 | Val Loss: 0.3682 | Val Acc: 88.44% | Test Acc: 88.03%
# Epoch 79 | Train Loss: 0.1996 | Val Loss: 0.3650 | Val Acc: 88.56% | Test Acc: 88.22%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 63.63it/s]
# Epoch 80 | Train Loss: 0.1982 | Val Loss: 0.3659 | Val Acc: 88.32% | Test Acc: 88.14%
# Epoch 81 | Train Loss: 0.1988 | Val Loss: 0.3651 | Val Acc: 88.46% | Test Acc: 88.19%
# Epoch 82 | Train Loss: 0.1986 | Val Loss: 0.3667 | Val Acc: 88.44% | Test Acc: 88.02%
# Epoch 83 | Train Loss: 0.1956 | Val Loss: 0.3698 | Val Acc: 88.38% | Test Acc: 88.09%
# Epoch 84 | Train Loss: 0.1979 | Val Loss: 0.3663 | Val Acc: 88.52% | Test Acc: 88.18%
# Epoch 85 | Train Loss: 0.1940 | Val Loss: 0.3668 | Val Acc: 88.38% | Test Acc: 88.18%
# Epoch 86 | Train Loss: 0.1973 | Val Loss: 0.3688 | Val Acc: 88.32% | Test Acc: 88.03%
#
# Round 14 Results:
#   Test Accuracy: 88.03%
#   Remaining Parameters: 13,799.0 (5.12%)
#
# ======================================================================
# Round 15/15
# ======================================================================
# Scheduler enabled: MultiStepLR at epochs 57 and 71
# Epoch 01 | Train Loss: 1.4717 | Val Loss: 1.1494 | Val Acc: 59.82% | Test Acc: 58.19%
# Epoch 02 | Train Loss: 0.9835 | Val Loss: 1.0003 | Val Acc: 64.06% | Test Acc: 63.94%
# Epoch 03 | Train Loss: 0.8124 | Val Loss: 0.7937 | Val Acc: 73.26% | Test Acc: 72.27%
# Epoch 04 | Train Loss: 0.7198 | Val Loss: 0.8545 | Val Acc: 71.50% | Test Acc: 70.48%
# Epoch 05 | Train Loss: 0.6672 | Val Loss: 0.8415 | Val Acc: 72.76% | Test Acc: 71.61%
# Epoch 06 | Train Loss: 0.6183 | Val Loss: 0.8188 | Val Acc: 72.26% | Test Acc: 71.93%
# Epoch 07 | Train Loss: 0.5838 | Val Loss: 0.8773 | Val Acc: 71.60% | Test Acc: 72.39%
# Epoch 08 | Train Loss: 0.5599 | Val Loss: 0.6434 | Val Acc: 77.94% | Test Acc: 77.80%
# Epoch 09 | Train Loss: 0.5296 | Val Loss: 0.6164 | Val Acc: 78.96% | Test Acc: 79.07%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 65.55it/s]
# Epoch 10 | Train Loss: 0.5080 | Val Loss: 0.5277 | Val Acc: 82.58% | Test Acc: 81.97%
# Epoch 11 | Train Loss: 0.4929 | Val Loss: 0.5524 | Val Acc: 81.62% | Test Acc: 81.02%
# Epoch 12 | Train Loss: 0.4720 | Val Loss: 0.5300 | Val Acc: 82.76% | Test Acc: 81.86%
# Epoch 13 | Train Loss: 0.4640 | Val Loss: 0.5055 | Val Acc: 83.30% | Test Acc: 82.40%
# Epoch 14 | Train Loss: 0.4467 | Val Loss: 0.5200 | Val Acc: 82.64% | Test Acc: 82.13%
# Epoch 15 | Train Loss: 0.4331 | Val Loss: 0.5219 | Val Acc: 82.54% | Test Acc: 81.96%
# Epoch 16 | Train Loss: 0.4246 | Val Loss: 0.5584 | Val Acc: 82.16% | Test Acc: 80.64%
# Epoch 17 | Train Loss: 0.4165 | Val Loss: 0.5056 | Val Acc: 83.30% | Test Acc: 82.11%
# Epoch 18 | Train Loss: 0.4028 | Val Loss: 0.4632 | Val Acc: 84.36% | Test Acc: 83.85%
# Epoch 19 | Train Loss: 0.4003 | Val Loss: 0.5505 | Val Acc: 82.42% | Test Acc: 81.42%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 60.75it/s]
# Epoch 20 | Train Loss: 0.3897 | Val Loss: 0.5063 | Val Acc: 83.06% | Test Acc: 83.20%
# Epoch 21 | Train Loss: 0.3901 | Val Loss: 0.4994 | Val Acc: 83.36% | Test Acc: 82.49%
# Epoch 22 | Train Loss: 0.3755 | Val Loss: 0.4931 | Val Acc: 83.92% | Test Acc: 82.96%
# Epoch 23 | Train Loss: 0.3754 | Val Loss: 0.4736 | Val Acc: 84.82% | Test Acc: 83.70%
# Epoch 24 | Train Loss: 0.3663 | Val Loss: 0.4655 | Val Acc: 84.70% | Test Acc: 83.96%
# Epoch 25 | Train Loss: 0.3604 | Val Loss: 0.4865 | Val Acc: 83.98% | Test Acc: 83.50%
# Epoch 26 | Train Loss: 0.3611 | Val Loss: 0.4585 | Val Acc: 84.60% | Test Acc: 84.46%
# Epoch 27 | Train Loss: 0.3551 | Val Loss: 0.4513 | Val Acc: 84.92% | Test Acc: 84.47%
# Epoch 28 | Train Loss: 0.3572 | Val Loss: 0.4488 | Val Acc: 84.68% | Test Acc: 84.53%
# Epoch 29 | Train Loss: 0.3489 | Val Loss: 0.4794 | Val Acc: 84.40% | Test Acc: 83.59%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 62.79it/s]
# Epoch 30 | Train Loss: 0.3479 | Val Loss: 0.4988 | Val Acc: 83.86% | Test Acc: 82.78%
# Epoch 31 | Train Loss: 0.3475 | Val Loss: 0.4630 | Val Acc: 84.56% | Test Acc: 84.23%
# Epoch 32 | Train Loss: 0.3462 | Val Loss: 0.4384 | Val Acc: 85.84% | Test Acc: 84.53%
# Epoch 33 | Train Loss: 0.3398 | Val Loss: 0.4882 | Val Acc: 84.70% | Test Acc: 84.53%
# Epoch 34 | Train Loss: 0.3373 | Val Loss: 0.4330 | Val Acc: 85.70% | Test Acc: 85.70%
# Epoch 35 | Train Loss: 0.3323 | Val Loss: 0.4223 | Val Acc: 86.16% | Test Acc: 85.51%
# Epoch 36 | Train Loss: 0.3319 | Val Loss: 0.4601 | Val Acc: 85.06% | Test Acc: 84.27%
# Epoch 37 | Train Loss: 0.3295 | Val Loss: 0.4615 | Val Acc: 85.16% | Test Acc: 83.96%
# Epoch 38 | Train Loss: 0.3308 | Val Loss: 0.4457 | Val Acc: 85.86% | Test Acc: 85.10%
# Epoch 39 | Train Loss: 0.3283 | Val Loss: 0.4301 | Val Acc: 85.66% | Test Acc: 85.31%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 66.89it/s]
# Epoch 40 | Train Loss: 0.3226 | Val Loss: 0.5499 | Val Acc: 82.96% | Test Acc: 82.39%
# Epoch 41 | Train Loss: 0.3245 | Val Loss: 0.4488 | Val Acc: 85.32% | Test Acc: 84.48%
# Epoch 42 | Train Loss: 0.3255 | Val Loss: 0.4126 | Val Acc: 86.40% | Test Acc: 85.96%
# Epoch 43 | Train Loss: 0.3163 | Val Loss: 0.4688 | Val Acc: 85.40% | Test Acc: 84.23%
# Epoch 44 | Train Loss: 0.3239 | Val Loss: 0.4433 | Val Acc: 85.64% | Test Acc: 85.21%
# Epoch 45 | Train Loss: 0.3196 | Val Loss: 0.4132 | Val Acc: 86.18% | Test Acc: 85.61%
# Epoch 46 | Train Loss: 0.3152 | Val Loss: 0.4721 | Val Acc: 84.88% | Test Acc: 83.98%
# Epoch 47 | Train Loss: 0.3161 | Val Loss: 0.4546 | Val Acc: 85.34% | Test Acc: 84.95%
# Epoch 48 | Train Loss: 0.3116 | Val Loss: 0.4755 | Val Acc: 84.94% | Test Acc: 84.46%
# Epoch 49 | Train Loss: 0.3144 | Val Loss: 0.4497 | Val Acc: 85.40% | Test Acc: 84.73%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 65.42it/s]
# Epoch 50 | Train Loss: 0.3135 | Val Loss: 0.4279 | Val Acc: 86.22% | Test Acc: 85.32%
# Epoch 51 | Train Loss: 0.3144 | Val Loss: 0.4542 | Val Acc: 85.46% | Test Acc: 84.86%
# Epoch 52 | Train Loss: 0.3146 | Val Loss: 0.4470 | Val Acc: 85.72% | Test Acc: 84.69%
# Epoch 53 | Train Loss: 0.3105 | Val Loss: 0.4515 | Val Acc: 85.34% | Test Acc: 84.91%
# Epoch 54 | Train Loss: 0.3128 | Val Loss: 0.4347 | Val Acc: 86.08% | Test Acc: 85.51%
# Epoch 55 | Train Loss: 0.3103 | Val Loss: 0.4463 | Val Acc: 85.76% | Test Acc: 85.32%
# Epoch 56 | Train Loss: 0.3101 | Val Loss: 0.4173 | Val Acc: 86.82% | Test Acc: 85.76%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3072 | Val Loss: 0.4424 | Val Acc: 85.88% | Test Acc: 84.75%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2794 | Val Loss: 0.3762 | Val Acc: 87.98% | Test Acc: 87.08%
# Epoch 59 | Train Loss: 0.2688 | Val Loss: 0.3755 | Val Acc: 88.06% | Test Acc: 87.27%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 65.12it/s]
# Epoch 60 | Train Loss: 0.2640 | Val Loss: 0.3747 | Val Acc: 87.84% | Test Acc: 87.20%
# Epoch 61 | Train Loss: 0.2610 | Val Loss: 0.3747 | Val Acc: 87.96% | Test Acc: 87.14%
# Epoch 62 | Train Loss: 0.2571 | Val Loss: 0.3749 | Val Acc: 87.82% | Test Acc: 87.26%
# Epoch 63 | Train Loss: 0.2594 | Val Loss: 0.3776 | Val Acc: 87.70% | Test Acc: 87.16%
# Epoch 64 | Train Loss: 0.2565 | Val Loss: 0.3708 | Val Acc: 87.90% | Test Acc: 87.38%
# Epoch 65 | Train Loss: 0.2562 | Val Loss: 0.3728 | Val Acc: 88.10% | Test Acc: 87.22%
# Epoch 66 | Train Loss: 0.2572 | Val Loss: 0.3751 | Val Acc: 88.08% | Test Acc: 87.25%
# Epoch 67 | Train Loss: 0.2545 | Val Loss: 0.3704 | Val Acc: 87.68% | Test Acc: 87.17%
# Epoch 68 | Train Loss: 0.2542 | Val Loss: 0.3693 | Val Acc: 88.08% | Test Acc: 87.22%
# Epoch 69 | Train Loss: 0.2537 | Val Loss: 0.3731 | Val Acc: 88.14% | Test Acc: 87.16%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 65.29it/s]
# Epoch 70 | Train Loss: 0.2541 | Val Loss: 0.3732 | Val Acc: 88.04% | Test Acc: 87.31%
# Epoch 71 | Train Loss: 0.2490 | Val Loss: 0.3716 | Val Acc: 88.00% | Test Acc: 87.23%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.2520 | Val Loss: 0.3718 | Val Acc: 88.18% | Test Acc: 87.15%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.2482 | Val Loss: 0.3709 | Val Acc: 88.10% | Test Acc: 87.09%
# Epoch 74 | Train Loss: 0.2470 | Val Loss: 0.3725 | Val Acc: 88.00% | Test Acc: 87.15%
# Epoch 75 | Train Loss: 0.2504 | Val Loss: 0.3703 | Val Acc: 87.96% | Test Acc: 87.16%
# Epoch 76 | Train Loss: 0.2484 | Val Loss: 0.3708 | Val Acc: 88.10% | Test Acc: 87.28%
# Epoch 77 | Train Loss: 0.2473 | Val Loss: 0.3712 | Val Acc: 88.08% | Test Acc: 87.22%
#    [Tracker] 🚩 Early Stop Condition at Iter 27456 (Epoch 78, Test Acc: 87.28%)
# Epoch 78 | Train Loss: 0.2486 | Val Loss: 0.3704 | Val Acc: 88.02% | Test Acc: 87.28%
# Epoch 79 | Train Loss: 0.2468 | Val Loss: 0.3704 | Val Acc: 88.04% | Test Acc: 87.32%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 66.37it/s]
# Epoch 80 | Train Loss: 0.2486 | Val Loss: 0.3723 | Val Acc: 87.90% | Test Acc: 87.20%
# Epoch 81 | Train Loss: 0.2467 | Val Loss: 0.3720 | Val Acc: 88.04% | Test Acc: 87.28%
# Epoch 82 | Train Loss: 0.2476 | Val Loss: 0.3697 | Val Acc: 88.10% | Test Acc: 87.24%
# Epoch 83 | Train Loss: 0.2493 | Val Loss: 0.3713 | Val Acc: 87.98% | Test Acc: 87.22%
# Epoch 84 | Train Loss: 0.2466 | Val Loss: 0.3701 | Val Acc: 88.06% | Test Acc: 87.19%
# Epoch 85 | Train Loss: 0.2460 | Val Loss: 0.3718 | Val Acc: 88.14% | Test Acc: 87.39%
# Epoch 86 | Train Loss: 0.2455 | Val Loss: 0.3724 | Val Acc: 87.92% | Test Acc: 87.08%
#
# Round 15 Results:
#   Test Accuracy: 87.08%
#   Remaining Parameters: 11,444.0 (4.24%)
#
# ======================================================================
# Iterative Pruning Complete!
# ======================================================================
# Saved Iterative results to: ../../results/resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930/checkpoints/iterative_results_resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930.pth

# %%
# --- Data Aggregation ---
# Assuming all trials have the same number of rounds and pruning rates
n_rounds = len(all_trials_iterative[0])
n_trials = len(all_trials_iterative)

# Initialize lists to store aggregated data
rounds = []
remaining_params_pct = []
remaining_params = []
acc_means = []
acc_stds = []

for r_idx in range(n_rounds):
    # Extract data for this specific round across all trials
    # Structure: [Trial1_RoundX, Trial2_RoundX, Trial3_RoundX]
    round_data = [trial[r_idx] for trial in all_trials_iterative]
    
    # Static data (same for all trials)
    rounds.append(round_data[0]['round'])
    remaining_params_pct.append(round_data[0]['remaining_params_pct'])
    remaining_params.append(round_data[0]['remaining_params'])
    
    # Variable data (Accuracy) - Calculate Mean and Std
    accuracies = [r['test_accuracy'] for r in round_data]
    acc_means.append(np.mean(accuracies))
    acc_stds.append(np.std(accuracies))

# --- Print Summary Table ---
print("\n" + "="*80)
print(f"Pruning Results Summary ({n_trials} Trials Aggregated)")
print("="*80)
print(f"{'Round':<8} {'Params %':<12} {'Params':<15} {'Mean Acc %':<12} {'Std Dev':<10}")
print("-"*80)

for i in range(n_rounds):
    print(f"{rounds[i]:<8} {remaining_params_pct[i]:<12.2f} "
          f"{remaining_params[i]:<15,} {acc_means[i]:<12.2f} ± {acc_stds[i]:<10.2f}")
print("="*80)
# Out:
# ================================================================================
# Pruning Results Summary (3 Trials Aggregated)
# ================================================================================
# Round    Params %     Params          Mean Acc %   Std Dev
# --------------------------------------------------------------------------------
# 1        80.15        216,183.0       88.93        ± 0.13
# 2        64.27        173,351.0       89.36        ± 0.09
# 3        51.57        139,086.0       89.41        ± 0.18
# 4        41.40        111,674.0       89.58        ± 0.20
# 5        33.27        89,744.0        89.56        ± 0.05
# 6        26.77        72,199.0        89.68        ± 0.07
# 7        21.56        58,164.0        89.55        ± 0.08
# 8        17.40        46,936.0        89.67        ± 0.18
# 9        14.07        37,954.0        89.59        ± 0.13
# 10       11.41        30,768.0        89.33        ± 0.07
# 11       9.28         25,019.0        89.04        ± 0.20
# 12       7.57         20,420.0        88.67        ± 0.19
# 13       6.21         16,741.0        88.50        ± 0.11
# 14       5.12         13,798.0        87.91        ± 0.12
# 15       4.24         11,443.0        86.91        ± 0.21
# ================================================================================

# %%
# --- Visualize with Error Bars ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Convert to numpy arrays for plotting
x_pct = np.array(remaining_params_pct)
y_mean = np.array(acc_means)
y_std = np.array(acc_stds)

# Plot 1: Accuracy vs Sparsity (Mean + Std Shadow)
# Plot the mean line
ax1.plot(x_pct, y_mean, 'o-', linewidth=2, markersize=6, label='Mean Accuracy')

# Plot the shadow (Mean +/- Std) 

ax1.fill_between(x_pct, y_mean - y_std, y_mean + y_std, alpha=0.2, color='blue', label='Std Dev range')

# Baseline Handling: Calculate mean baseline from Round 1 (0% pruned)
baseline_mean = y_mean[0] 
ax1.axhline(y=baseline_mean, color='r', linestyle='--', label=f'Mean Baseline ({baseline_mean:.2f}%)', alpha=0.7)

ax1.set_xlabel('Percent of Weights Remaining (%)', fontsize=12)
ax1.set_ylabel('Test Accuracy (%)', fontsize=12)
ax1.set_title(f'Test Accuracy vs Sparsity ({n_trials} Trials)', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)
ax1.invert_xaxis()  # 100% -> 0%

# Plot 2: Params Reduction (Deterministic, no error bars needed)
ax2.plot(rounds, remaining_params, 'o-', linewidth=2, markersize=8, color='orange')
ax2.set_xlabel('Pruning Round', fontsize=12)
ax2.set_ylabel('Parameters Remaining', fontsize=12)
ax2.set_title('Parameters Reduction', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.3)
ax2.set_yscale('log') 

plt.tight_layout()

# Save Pruning Figure
# Ensure fig_dir exists in your context
pruning_fig_path = os.path.join(fig_dir, f"Iterative_pruning_results_multi_trial_{run_id}.png")
plt.savefig(pruning_fig_path, dpi=150)
plt.show()

print(f"Pruning figure saved to: {pruning_fig_path}")
# Out:
# Pruning figure saved to: ../../results/resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930/figures/Iterative_pruning_results_multi_trial_resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930.png

# %%
import matplotlib.pyplot as plt
import os
import numpy as np

# --- Visualize with Error Bars (Vertical Lines) ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Convert to numpy arrays for plotting
x_pct = np.array(remaining_params_pct)
y_mean = np.array(acc_means)
y_std = np.array(acc_stds)

# ==============================================================================
# Plot 1: Accuracy vs Sparsity (Using Error Bars)
# ==============================================================================

# ax1.errorbar 是关键函数
# x, y: 坐标
# yerr: 误差范围 (这里用标准差)
# fmt='o-': 样式 (圆点 + 实线)
# capsize=4: 误差棒顶部和底部的小横杠宽度 (让它看起来更像论文)
# elinewidth=1.5: 误差棒的线条粗细
ax1.errorbar(x_pct, y_mean, yerr=y_std, fmt='o-', 
             linewidth=2, markersize=6, capsize=4, elinewidth=1.5,
             color='tab:blue', ecolor='tab:blue', label='Mean Accuracy')

# Baseline Handling
baseline_mean = y_mean[0] 
ax1.axhline(y=baseline_mean, color='r', linestyle='--', label=f'Mean Baseline ({baseline_mean:.2f}%)', alpha=0.7)

ax1.set_xlabel('Percent of Weights Remaining (%)', fontsize=12)
ax1.set_ylabel('Test Accuracy (%)', fontsize=12)
ax1.set_title(f'Test Accuracy vs Sparsity ({n_trials} Trials)', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)
ax1.invert_xaxis()  # 100% -> 0% (Standard for pruning plots)

# ==============================================================================
# Plot 2: Params Reduction (No changes needed)
# ==============================================================================
ax2.plot(rounds, remaining_params, 'o-', linewidth=2, markersize=8, color='orange')
ax2.set_xlabel('Pruning Round', fontsize=12)
ax2.set_ylabel('Parameters Remaining', fontsize=12)
ax2.set_title('Parameters Reduction', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.3)
ax2.set_yscale('log') 

plt.tight_layout()

# Save Pruning Figure
if 'fig_dir' not in globals(): fig_dir = "." # Fallback if fig_dir is not defined
pruning_fig_path = os.path.join(fig_dir, f"Iterative_pruning_results_multi_trial_errorbars_{run_id}.png")
plt.savefig(pruning_fig_path, dpi=300) # Increased DPI for better quality
plt.show()

print(f"Pruning figure saved to: {pruning_fig_path}")
# Out:
# Pruning figure saved to: ../../results/resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930/figures/Iterative_pruning_results_multi_trial_errorbars_resnet20_iterative_random_init_LR_0.01_3_trials_20260114_033930.png

# %%
# --- Identify Winning Tickets (Based on Mean Accuracy) ---

# Define Baseline: Mean accuracy of the unpruned model (Round 1)
baseline_mean_acc = acc_means[0] 

winning_tickets_indices = []

# Loop through aggregated stats
for i in range(n_rounds):
    # Criteria: Mean Accuracy >= 98% of Mean Baseline
    if acc_means[i] >= baseline_mean_acc * 0.98:
        winning_tickets_indices.append(i)

print(f"\n{'='*70}")
print(f"Winning Ticket Analysis (Based on {n_trials} Trials Mean)")
print(f"{'='*70}")
print(f"Mean Baseline Accuracy: {baseline_mean_acc:.2f}%")
print(f"\nWinning Tickets (Mean Acc >= {baseline_mean_acc * 0.98:.2f}%):")
print(f"{'Round':<8} {'Sparsity %':<12} {'Params':<15} {'Mean Acc %':<12}")
print("-"*70)

best_ticket_idx = -1
min_params = float('inf')

for idx in winning_tickets_indices:
    sparsity = 100 - remaining_params_pct[idx]
    print(f"{rounds[idx]:<8} {sparsity:<12.1f} "
          f"{remaining_params[idx]:<15,} {acc_means[idx]:<12.2f}")
    
    # Track the best ticket (most sparse)
    if remaining_params[idx] < min_params:
        min_params = remaining_params[idx]
        best_ticket_idx = idx

if best_ticket_idx != -1:
    print(f"\nBest Winning Ticket (Most Sparse):")
    print(f"  Round: {rounds[best_ticket_idx]}")
    print(f"  Sparsity: {100 - remaining_params_pct[best_ticket_idx]:.1f}%")
    print(f"  Parameters: {remaining_params[best_ticket_idx]:,}")
    print(f"  Mean Accuracy: {acc_means[best_ticket_idx]:.2f}%")
# Out:
# ======================================================================
# Winning Ticket Analysis (Based on 3 Trials Mean)
# ======================================================================
# Mean Baseline Accuracy: 88.93%
#
# Winning Tickets (Mean Acc >= 87.15%):
# Round    Sparsity %   Params          Mean Acc %
# ----------------------------------------------------------------------
# 1        19.8         216,183.0       88.93
# 2        35.7         173,351.0       89.36
# 3        48.4         139,086.0       89.41
# 4        58.6         111,674.0       89.58
# 5        66.7         89,744.0        89.56
# 6        73.2         72,199.0        89.68
# 7        78.4         58,164.0        89.55
# 8        82.6         46,936.0        89.67
# 9        85.9         37,954.0        89.59
# 10       88.6         30,768.0        89.33
# 11       90.7         25,019.0        89.04
# 12       92.4         20,420.0        88.67
# 13       93.8         16,741.0        88.50
# 14       94.9         13,798.0        87.91
#
# Best Winning Ticket (Most Sparse):
#   Round: 14
#   Sparsity: 94.9%
#   Parameters: 13,798.0
#   Mean Accuracy: 87.91%

# %% [markdown]
# ### 5.2 Random Init

# %%
# ============================================================================
# PHASE 2: Random Reinitialization (Control)
# ============================================================================
print(f"\n{'='*40}")
print("PHASE 2: Random Reinitialization Experiments")
print(f"{'='*40}")

all_trials_random = []

for trial_idx, seed in enumerate(SEEDS):
    print(f"\n>>> Starting Random Init Trial {trial_idx + 1}/{len(SEEDS)} | Seed {seed}")
    
    # 1. Set seed (Ensure data shuffle matches Phase 1)
    set_seed(seed)
    
    # 2. Prepare Data
    train_loader, val_loader, test_loader = get_dataloaders(seed)
    
    # 3. Retrieve Masks from Phase 1
    current_iter_results = all_trials_iterative[trial_idx]
    
    trial_random_results = []
    
    # 4. Create a fresh base model for re-init
    base_model_rnd = ResNet20_CIFAR10().to(device)
    
    # 5. Iterate through rounds using Phase 1 masks
    for res in current_iter_results:
        mask = res['mask']
        if mask is None: continue # Skip Round 0 (no pruning)
        
        print(f"   -> Random Reinit for Sparsity: {res['remaining_params_pct']:.2f}%")
        
        # Run Random Reinit Pruning
        # [CRITICAL UPDATE]: Passing 'config' so the correct scheduler is used
        rand_res = random_reinit_pruning(
            model=copy.deepcopy(base_model_rnd),
            train_loader=train_loader,
            test_loader=test_loader,
            val_loader=val_loader,
            optimizer_class=torch.optim.SGD,
            optimizer_kwargs={'lr': lr, 'momentum': 0.9, 'weight_decay': 1e-4},
            device=device,
            mask=mask,
            # Pass the same config structure you used in Phase 1
            config=pruning_config,
            epochs=epochs_per_round,
            verbose=True 
        )
        
        # Add metadata for plotting
        rand_res['remaining_params_pct'] = res['remaining_params_pct']
        rand_res['round'] = res['round']
        trial_random_results.append(rand_res)
        
    all_trials_random.append(trial_random_results)

# 6. Save Random Init Results separately
random_save_path = os.path.join(ckpt_dir, f"random_init_results_{run_id}.pth")
torch.save({
    'trials': all_trials_random,
    'seeds': SEEDS,
    'config': pruning_config,
    'lr': lr
}, random_save_path)
print(f"Saved Random Init results to: {random_save_path}")
# Out:
# ========================================
# PHASE 2: Random Reinitialization Experiments
# ========================================
#
# >>> Starting Random Init Trial 1/3 | Seed 42
#
# Seed set to: 42
#    -> Random Reinit for Sparsity: 80.15%
#
# ======================================================================
# Starting Random Reinit Control Experiment
# Sparsity Level: 80.15% weights remaining
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# ======================================================================
# Scheduler enabled: MultiStepLR at epochs 57 and 71
# Epoch 01 | Train Loss: 1.6288 | Val Loss: 1.5285 | Val Acc: 47.08% | Test Acc: 47.90%
# Epoch 02 | Train Loss: 1.2298 | Val Loss: 1.1834 | Val Acc: 58.14% | Test Acc: 58.32%
# Epoch 03 | Train Loss: 1.0483 | Val Loss: 1.3170 | Val Acc: 58.28% | Test Acc: 58.42%
# Epoch 04 | Train Loss: 0.9190 | Val Loss: 0.9363 | Val Acc: 67.54% | Test Acc: 68.29%

# %%
# --- Data Aggregation (Random Init) ---
# Assuming all_trials_random is a List[List[Dict]] populated from your Phase 2 loop
n_rounds_rnd = len(all_trials_random[0])
n_trials_rnd = len(all_trials_random)

# Initialize lists to store aggregated data
rounds_rnd = []
remaining_params_pct_rnd = []
remaining_params_rnd = []
acc_means_rnd = []
acc_stds_rnd = []

for r_idx in range(n_rounds_rnd):
    # Extract data for this specific round across all random trials
    # Structure: [Trial1_RoundX, Trial2_RoundX, Trial3_RoundX]
    round_data = [trial[r_idx] for trial in all_trials_random]
    
    # Static data (same structure as iterative)
    rounds_rnd.append(round_data[0]['round'])
    remaining_params_pct_rnd.append(round_data[0]['remaining_params_pct'])
    remaining_params_rnd.append(round_data[0]['remaining_params']) # Assuming this key exists, else compute
    
    # Variable data (Accuracy) - Calculate Mean and Std
    accuracies = [r['test_accuracy'] for r in round_data]
    acc_means_rnd.append(np.mean(accuracies))
    acc_stds_rnd.append(np.std(accuracies))

# --- Print Summary Table ---
print("\n" + "="*80)
print(f"Random Reinit Results Summary ({n_trials_rnd} Trials Aggregated)")
print("="*80)
print(f"{'Round':<8} {'Params %':<12} {'Mean Acc %':<12} {'Std Dev':<10}")
print("-"*80)

for i in range(n_rounds_rnd):
    print(f"{rounds_rnd[i]:<8} {remaining_params_pct_rnd[i]:<12.2f} "
          f"{acc_means_rnd[i]:<12.2f} ± {acc_stds_rnd[i]:<10.2f}")
print("="*80)
# Out:
# ================================================================================
# Random Reinit Results Summary (3 Trials Aggregated)
# ================================================================================
# Round    Params %     Mean Acc %   Std Dev
# --------------------------------------------------------------------------------
# 1        80.15        90.54        ± 0.09
# 2        64.27        90.28        ± 0.19
# 3        51.57        89.86        ± 0.10
# 4        41.40        89.68        ± 0.15
# 5        33.27        88.35        ± 0.90
# 6        26.77        88.65        ± 0.27
# 7        21.56        87.86        ± 0.20
# 8        17.40        87.42        ± 0.11
# 9        14.07        86.57        ± 0.48
# 10       11.41        85.89        ± 0.09
# 11       9.28         84.95        ± 0.18
# 12       7.57         84.09        ± 0.21
# 13       6.21         83.31        ± 0.25
# 14       5.12         81.81        ± 0.37
# 15       4.24         80.36        ± 0.05
# ================================================================================

# %%
# --- Visualize Random Init with Error Bars ---
fig, ax1 = plt.subplots(1, 1, figsize=(8, 6))

# Convert to numpy arrays
x_pct_rnd = np.array(remaining_params_pct_rnd)
y_mean_rnd = np.array(acc_means_rnd)
y_std_rnd = np.array(acc_stds_rnd)

# ==============================================================================
# Plot: Accuracy vs Sparsity (Random Init)
# ==============================================================================

# Error bar plot
ax1.errorbar(x_pct_rnd, y_mean_rnd, yerr=y_std_rnd, fmt='s--', 
             linewidth=2, markersize=6, capsize=4, elinewidth=1.5,
             color='tab:orange', ecolor='tab:orange', label='Mean Accuracy (Random Reinit)')

# Baseline Handling (Optional: Compare against Iterative Baseline)
# If 'baseline_mean' exists from the previous iterative block, we can use it.
if 'baseline_mean' in globals():
    ax1.axhline(y=baseline_mean, color='r', linestyle='--', label=f'Iterative Baseline ({baseline_mean:.2f}%)', alpha=0.5)

ax1.set_xlabel('Percent of Weights Remaining (%)', fontsize=12)
ax1.set_ylabel('Test Accuracy (%)', fontsize=12)
ax1.set_title(f'Random Reinit Accuracy vs Sparsity ({n_trials_rnd} Trials)', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)
ax1.invert_xaxis()  # 100% -> 0%

plt.tight_layout()

# Save Figure
if 'fig_dir' not in globals(): fig_dir = "." 
random_fig_path = os.path.join(fig_dir, f"Random_init_results_multi_trial_errorbars_{run_id}.png")
plt.savefig(random_fig_path, dpi=300)
plt.show()

print(f"Random init figure saved to: {random_fig_path}")
# Out:
# Random init figure saved to: ../../results/resnet20_iterative_random_init_LR_0.1_3_trials_20260113_123051/figures/Random_init_results_multi_trial_errorbars_resnet20_iterative_random_init_LR_0.1_3_trials_20260113_123051.png

# %%
# --- Analyze Random Init Performance (Control) ---

# Use the same baseline as Iterative Pruning if available
if 'baseline_mean_acc' not in globals():
    # Fallback if iterative block wasn't run
    baseline_mean_acc = acc_means_rnd[0]

random_matching_tickets = []

# Loop through aggregated stats
for i in range(n_rounds_rnd):
    # Criteria: Mean Accuracy >= 98% of Baseline
    # This checks if Random Init can essentially "get lucky" and match the original network
    if acc_means_rnd[i] >= baseline_mean_acc * 0.98:
        random_matching_tickets.append(i)

print(f"\n{'='*70}")
print(f"Random Reinit Analysis (Control Experiment)")
print(f"{'='*70}")
print(f"Target Baseline Accuracy: {baseline_mean_acc:.2f}%")
print(f"\nRandom Configurations Matching Baseline (>= {baseline_mean_acc * 0.98:.2f}%):")

if not random_matching_tickets:
    print("None found. (As expected, random reinitialization usually fails at high sparsity)")
else:
    print(f"{'Round':<8} {'Sparsity %':<12} {'Mean Acc %':<12}")
    print("-"*40)
    for idx in random_matching_tickets:
        sparsity = 100 - remaining_params_pct_rnd[idx]
        print(f"{rounds_rnd[idx]:<8} {sparsity:<12.1f} "
              f"{acc_means_rnd[idx]:<12.2f}")

print("="*70)
# Out:
# ======================================================================
# Random Reinit Analysis (Control Experiment)
# ======================================================================
# Target Baseline Accuracy: 90.79%
#
# Random Configurations Matching Baseline (>= 88.98%):
# Round    Sparsity %   Mean Acc %
# ----------------------------------------
# 1        19.8         90.54
# 2        35.7         90.28
# 3        48.4         89.86
# 4        58.6         89.68
# ======================================================================

# %%
# --- Configuration ---
# Ensure these variables exist from your previous cells
# Iterative Data (Winning Ticket)
x_iter = np.array(remaining_params_pct)
y_iter_mean = np.array(acc_means)
y_iter_std = np.array(acc_stds)

# Random Init Data (Control)
x_rnd = np.array(remaining_params_pct_rnd)
y_rnd_mean = np.array(acc_means_rnd)
y_rnd_std = np.array(acc_stds_rnd)

# --- Visualize: Winning Ticket vs Random Reinit (Combined) ---
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

# ==============================================================================
# 1. Plot Winning Ticket (Iterative Pruning) -> Solid Line
# ==============================================================================
ax.errorbar(x_iter, y_iter_mean, yerr=y_iter_std, fmt='o-', 
             linewidth=2, markersize=6, capsize=4, elinewidth=1.5,
             color='tab:blue', ecolor='tab:blue', label='Winning Ticket (Iterative)')

# ==============================================================================
# 2. Plot Random Reinit (Control) -> Dashed Line
# ==============================================================================
ax.errorbar(x_rnd, y_rnd_mean, yerr=y_rnd_std, fmt='s--', 
             linewidth=2, markersize=6, capsize=4, elinewidth=1.5,
             color='tab:orange', ecolor='tab:orange', label='Random Reinit (Control)')

# ==============================================================================
# 3. Baseline Handling
# ==============================================================================
# Use the Mean Baseline from the Iterative Pruning (Round 1)
baseline_val = y_iter_mean[0]
ax.axhline(y=baseline_val, color='grey', linestyle=':', linewidth=2, 
           label=f'Unpruned Baseline ({baseline_val:.2f}%)', alpha=0.8)

# ==============================================================================
# 4. Styling (Match Paper Style)
# ==============================================================================
ax.set_xlabel('Percent of Weights Remaining (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title(f'Winning Ticket vs Random Reinit ({n_trials} Trials)', fontsize=14, fontweight='bold')

ax.grid(True, which="both", linestyle='--', alpha=0.4)
ax.legend(fontsize=11, loc='best')

# Use Log Scale for X-axis to match Figure 8 style (better visibility for high sparsity)
ax.set_xscale('log')
ax.invert_xaxis()  # 100% -> 0%

# Set Custom Ticks for Log Scale (100, 50, 20, 10, 5, 2, 1)
ticks = [100, 50, 20, 10, 5, 2, 1]
ax.set_xticks(ticks)
ax.set_xticklabels([str(t) for t in ticks])
ax.minorticks_off() # Turn off minor ticks to look cleaner

plt.tight_layout()

# ==============================================================================
# 5. Save Figure
# ==============================================================================
if 'fig_dir' not in globals(): fig_dir = "."
combined_fig_path = os.path.join(fig_dir, f"Winning_Ticket_vs_Random_MultiTrial_Final_{run_id}.png")
plt.savefig(combined_fig_path, dpi=300)
plt.show()

print(f"Combined figure saved to: {combined_fig_path}")
# Out:
# Combined figure saved to: ../../results/resnet20_iterative_random_init_LR_0.1_3_trials_20260113_123051/figures/Winning_Ticket_vs_Random_MultiTrial_Final_resnet20_iterative_random_init_LR_0.1_3_trials_20260113_123051.png

# %% [markdown]
# ## 6. Analyze Results

# %% [markdown]
# ### 6.1 Iterative Pruning
#
# Visualize and analyze the pruning results.

# %% [markdown]
# ## 7. Identify Winning Tickets
#
# Find which pruned networks are "winning tickets" (match or exceed baseline accuracy).

# %% [markdown]
# ## 8. Save Results

# %% [markdown]
# ## 9. Next Steps
#
# ### Experiment Ideas:
#
# 1. **Compare pruning strategies**
#    - Try different `prune_rate_conv` and `prune_rate_fc`
#    - Compare `layerwise` vs `global` pruning
#
# 2. **Random reinitialization baseline**
#    - Use `random_reinit_pruning()` to show winning tickets need original initialization
#
# 3. **One-shot pruning**
#    - Compare `one_shot_pruning()` vs iterative pruning
#
# 4. **Visualize weight distributions**
#    - Plot weight magnitude histograms before/after pruning
#
# 5. **Learning rate experiments**
#    - Test different learning rates (paper shows this matters!)

# %% [markdown]
# ## Notes and Observations
#
# **TODO: Add your observations here**
#
# - What worked well?
# - What surprised you?
# - Any implementation challenges?
# - Ideas for the final report?
