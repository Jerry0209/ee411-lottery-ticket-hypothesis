# %% [markdown]
# # EE-411 Lottery Ticket Hypothesis - Experiment Resnet-18 + Iterative + Random Init + Learning Rate = 0.01 Warmup + 3 Trials
#
# **Author:** Tianrui (Jerry)
# **Model:** ResNet 18
# **Dataset:** [CIFAR-10]
# **Date:** [2026.01.14]
#
# ---
#
# ## Instructions
#
# 1. **Define your model** in the "Model Definition" section
# 2. **Train baseline model** to get initial performance
# 3. **Run pruning experiments** using the shared pruning algorithms
# 4. **Visualize and analyze** your results
# 5. **Save your results** to the `results/` folder
#
# ## Quick Links
#
# - [Paper](https://arxiv.org/abs/1803.03635): "The Lottery Ticket Hypothesis"
# - [Shared Code](../../shared/): Training utils and pruning algorithms
# - [Results](../../results/): Save checkpoints and figures here

# %% [markdown]
# ## Setup Run ID

# %%
import os
import time
from datetime import datetime

# 1. Generate a unique Run ID (Model + Timestamp)
# e.g., "resnet20_20231027_153045"
model_name = "resnet20_iterative_random_init_LR_0.01_warmup_3_trials"  # Or "resnet18"
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
run_id = f"{model_name}_{timestamp}"

# 2. Create specific directories for THIS run
# Instead of dumping everything in 'results/', we make a subfolder
base_dir = "../../results"
run_dir = os.path.join(base_dir, run_id)
ckpt_dir = os.path.join(run_dir, "checkpoints")
fig_dir = os.path.join(run_dir, "figures")

os.makedirs(ckpt_dir, exist_ok=True)
os.makedirs(fig_dir, exist_ok=True)

print(f"Experiment Initialized: {run_id}")
print(f"Results will be saved to: {run_dir}")
# Out:
# Experiment Initialized: resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904
# Results will be saved to: ../../results/resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
sys.path.append('../..')  # Add project root to path

import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset, random_split
import matplotlib.pyplot as plt
from tqdm import tqdm

# Import shared utilities
from shared.training_utils import fit, predict, set_seed, plot_loss
from shared.pruning import (
    iterative_pruning,
    one_shot_pruning,
    one_shot_pruning_efficient,
    random_reinit_pruning,
    get_pruning_config,
    count_parameters,
    evaluate_model,
    apply_mask,
    create_global_mask
)

# Fix random seeds for reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# ## 2. Data Loading
#
# ### For CIFAR-10 (Conv-2, Conv-4, Conv-6, ResNet-18)

# %%
# CIFAR-10 Data Loading


# Define transforms
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  # New ! Crucial for CIFAR-10 
    transforms.RandomHorizontalFlip(),     # New ! Crucial for generalization 
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])


# ============================================================================
# 2. Download and Load Datasets (Twice!)
# ============================================================================

# transform_train
train_set_augmented = torchvision.datasets.CIFAR10(
    root='../../data', 
    train=True, 
    download=True, 
    transform=transform_train  # <--- Augmented data
)

# transform_test
train_set_clean = torchvision.datasets.CIFAR10(
    root='../../data', 
    train=True, 
    download=True, 
    transform=transform_test   # <--- Clean data
)

test_dataset = torchvision.datasets.CIFAR10(
    root='../../data', 
    train=False, 
    download=True, 
    transform=transform_test
)



# ============================================================================
# 3. Split Train/Val using Indices
# ============================================================================
# Make sure it's able to reproduce the same split every time
num_train = len(train_set_augmented) # 50000
indices = list(range(num_train))
split = 45000
seed = 42 

np.random.seed(seed)
np.random.shuffle(indices)

train_idx = indices[:split]
val_idx = indices[split:]

# train_dataset
train_dataset = Subset(train_set_augmented, train_idx)
# val_dataset construction using clean data
val_dataset   = Subset(train_set_clean, val_idx)


# ============================================================================
# 4. Create Data Loaders
# ============================================================================
# Create data loaders
# batch_size = 60  # From paper
batch_size = 128  # Paper uses 128 for ResNet-18

train_loader = DataLoader(
    train_dataset, 
    batch_size=batch_size, 
    shuffle=True,
    num_workers=2
)

val_loader = DataLoader(
    val_dataset, 
    batch_size=batch_size, 
    shuffle=False,
    num_workers=2
)

test_loader = DataLoader(
    test_dataset, 
    batch_size=batch_size, 
    shuffle=False,
    num_workers=2
)

# ============================================================================
# 5. Verify & Config Check
# ============================================================================

print(f"Train: {len(train_dataset)} samples")
print(f"Val:   {len(val_dataset)} samples")
print(f"Test:  {len(test_dataset)} samples")
print(f"Batches per epoch: {len(train_loader)}")

# Automatic Epochs Recommendation
iterations_needed = 30000
steps_per_epoch = len(train_loader)
recommended_epochs = int(np.ceil(iterations_needed / steps_per_epoch))

print(f"\n[Config Check]")
print(f"To reach {iterations_needed} iterations with batch size {batch_size}:")
print(f"You should set EPOCHS >= {recommended_epochs}")
# Out:
# Train: 45000 samples
# Val:   5000 samples
# Test:  10000 samples
# Batches per epoch: 352
#
# [Config Check]
# To reach 30000 iterations with batch size 128:
# You should set EPOCHS >= 86

# %% [markdown]
# ## 3. Model Definition
#
# **TODO: Define your model here**

# %%
# ResNet18 for CIFAR-10
import copy
import torch
import torch.nn as nn
# from torchvision.models import resnet18
import torch.nn.functional as F
import torch.nn.init as init



# # ResNet-20 for CIFAR-10 (Kaiming He, used in the paper)
# def _weights_init(m):
#     """
#     Kaiming Initialization (He Initialization) as used in the paper.
#     """
#     if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
#         init.kaiming_normal_(m.weight)

def _weights_init(m):
    """
    Paper uses Gaussian Glorot (Xavier Normal) initialization.
    """
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        # Gaussian Glorot (Xavier Normal) is used in the paper
        init.xavier_normal_(m.weight)
        # If there is bias, typically initialized to 0 (though ResNet's Conv usually doesn't have bias)
        if m.bias is not None:
            init.constant_(m.bias, 0)

            

class LambdaLayer(nn.Module):
    def __init__(self, lambd):
        super(LambdaLayer, self).__init__()
        self.lambd = lambd

    def forward(self, x):
        return self.lambd(x)

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.downsample = nn.Sequential() # named as "downsample" as pruning.py
        if stride != 1 or in_planes != planes:
            # Paper Option A: Zero-padding for shortcut
            self.downsample = LambdaLayer(lambda x:
                                        F.pad(x[:, :, ::2, ::2], (0, 0, 0, 0, planes//4, planes//4), "constant", 0))

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.downsample(x)
        out = F.relu(out)
        return out

class ResNet20_CIFAR10(nn.Module):
    def __init__(self):
        super(ResNet20_CIFAR10, self).__init__()
        self.in_planes = 16
        
        # ResNet-20: 3 layers * 3 blocks * 2 convs + 1st conv + 1 linear = 20 layers
        num_blocks = [3, 3, 3] 

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        
        self.layer1 = self._make_layer(BasicBlock, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(BasicBlock, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(BasicBlock, 64, num_blocks[2], stride=2)
        
        self.linear = nn.Linear(64, 10)
        
        # Apply initialization
        self.apply(_weights_init)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out



# Create model instance
# model = ResNet18_CIFAR10().to(device)
model = ResNet20_CIFAR10().to(device)
initial_weights_state = copy.deepcopy(model.state_dict())
init_weights_path = os.path.join(ckpt_dir, f"initial_weights_theta0_{run_id}.pth")
torch.save(initial_weights_state, init_weights_path)
print(f"Initial weights saved to: {init_weights_path}")

# Print model info
total_params = count_parameters(model)
print(f"Model: ResNet20_CIFAR10")
print(f"Total parameters: {total_params:,}")
print(f"\nModel architecture:")
print(model)
# Out:
# Initial weights saved to: ../../results/resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904/checkpoints/initial_weights_theta0_resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904.pth
# Model: ResNet20_CIFAR10
# Total parameters: 269,722
#
# Model architecture:
# ResNet20_CIFAR10(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): LambdaLayer()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): LambdaLayer()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#   )
#   (linear): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ## 4. Baseline Training
#
# Train the unpruned model to establish baseline performance.

# %%
# Training configuration (from paper)
# Adjust these based on your model!
     
learning_rate = 0.1 # Paper recommends 0.1 (or 0.03 with warmup)
epochs = 86  

# Optimizer
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

optimizer = torch.optim.SGD(
    model.parameters(), 
    lr=learning_rate,             # Paper recommends 0.1 for constant, or 0.03 with warmup
    momentum=0.9, 
    weight_decay=1e-4   # Helps prevent overfitting
)

# Paper: Divide LR by 10 at 20k and 25k iterations
# 20,000 / 352 ≈ 57 epochs
# 25,000 / 352 ≈ 71 epochs
scheduler = torch.optim.lr_scheduler.MultiStepLR(
    optimizer, 
    milestones=[57, 71], 
    gamma=0.01
)

# --- Dynamic Print ---
optimizer_name = optimizer.__class__.__name__
current_lr = optimizer.param_groups[0]['lr']

print(f"Training configuration:")
print(f"  Optimizer: {optimizer_name}") # Dynamic!
print(f"  Learning rate: {learning_rate}")
print(f"  Epochs: {epochs}")
print(f"  Batch size: {batch_size}")
print(f"\nStarting training...\n")

test_loss, test_accuracy = predict(model, test_loader, device)
# Out:
# Training configuration:
#   Optimizer: SGD
#   Learning rate: 0.1
#   Epochs: 86
#   Batch size: 128
#
# Starting training...
#
# Test set: Avg. loss: 2.8741, Accuracy: 1049/10000 (10%)

# %%
# # Train using shared training_utils
# losses = fit(
#     model=model,
#     train_dataloader=train_loader,
#     optimizer=optimizer,
#     epochs=epochs,
#     device=device,
#     scheduler=scheduler  # New! Don't forget to pass the scheduler!
# )

# # Evaluate on test set
# test_loss, test_accuracy = predict(model, test_loader, device)

# print(f"\n{'='*60}")
# print(f"Baseline Results")
# print(f"{'='*60}")
# print(f"Test Accuracy: {test_accuracy:.2f}%")
# print(f"Test Loss: {test_loss:.4f}")

# %% [markdown]
# ### Visualize Training

# %%
# iterations_per_epoch = len(train_loader)
# # ================= Drawing Figure 1: X-axis = Epochs =================

# plt.figure(figsize=(10, 5))
# plt.plot(losses, linewidth=2)
# plt.xlabel('Epoch', fontsize=12)
# plt.ylabel('Training Loss', fontsize=12)
# plt.title(f'Baseline Training Loss ({model_name})', fontsize=14)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()

# # Save with run_id
# loss_fig_path = os.path.join(fig_dir, f"baseline_loss_{run_id}.png")
# plt.savefig(loss_fig_path, dpi=150)
# plt.show()

# print(f"Loss figure saved to: {loss_fig_path}")

# # ================= Drawing Figure 2: X-axis = Iterations =================
# iterations_x = [i * iterations_per_epoch for i in range(1, len(losses) + 1)]

# plt.figure(figsize=(10, 5))
# plt.plot(iterations_x, losses, linewidth=2, color='red', linestyle='--', label='Train Loss')
# plt.xlabel('Iterations', fontsize=12)
# plt.ylabel('Training Loss', fontsize=12)
# plt.title(f'Baseline Training Loss vs Iterations ({model_name})', fontsize=14)
# plt.grid(True, alpha=0.3)
# plt.legend()
# plt.tight_layout()

# # Save Iteration Figure
# loss_fig_path_iter = os.path.join(fig_dir, f"baseline_loss_iter_{run_id}.png")
# plt.savefig(loss_fig_path_iter, dpi=150)
# plt.show()
# print(f"Iteration-based loss figure saved to: {loss_fig_path_iter}")
# Out:
# Loss figure saved to: ../../results/resnet20_one_shot_original_init_20260110_215316/figures/baseline_loss_resnet20_one_shot_original_init_20260110_215316.png
# Iteration-based loss figure saved to: ../../results/resnet20_one_shot_original_init_20260110_215316/figures/baseline_loss_iter_resnet20_one_shot_original_init_20260110_215316.png

# %% [markdown]
# ### Save Baseline Model

# %%
# # --- Save Baseline Model ---
# # Save with the unique run_id in the filename
# baseline_path = os.path.join(ckpt_dir, f"baseline_{run_id}.pth")

# torch.save({
#     'model_state_dict': model.state_dict(),
#     'optimizer_state_dict': optimizer.state_dict(),
#     'test_accuracy': test_accuracy,
#     'test_loss': test_loss,
#     'epochs': epochs,
#     'config': {
#         'optimizer': optimizer_name,
#         'lr': current_lr
#     }
# }, baseline_path)

# print(f"Baseline model saved to: {baseline_path}")
# Out:
# Baseline model saved to: ../../results/resnet20_one_shot_original_init_20260110_215316/checkpoints/baseline_resnet20_one_shot_original_init_20260110_215316.pth

# %% [markdown]
# ## 5. Pruning Experiments

# %% [markdown]
# ### 5.1 Iterative Pruning
#
# Run the main pruning experiment from the paper.

# %%
# Get pruning configuration for your model
# Options: 'lenet', 'conv2', 'conv4', 'conv6', 'resnet18', 'resnet20'

pruning_config = get_pruning_config('resnet20')

print("Pruning Configuration:")
for key, value in pruning_config.items():
    print(f"  {key}: {value}")
# Out:
# Pruning Configuration:
#   prune_rate_conv: 0.2
#   prune_rate_fc: 0.0
#   pruning_strategy: global
#   warmup_strategy: linear_20k
#   description: ResNet-20 LR=0.03 Warmup=20k

# %%
# --- Seed Configuration for Trials ---
SEEDS = [42, 43, 44]
lr = 0.01
epochs_per_round = 86  # ~30k iterations

# --- Data Preparation Function (Re-usable for every seed) ---
def get_dataloaders(seed):
    """Re-creates dataloaders with specific seed-based shuffling"""
    
    # Define transforms
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    # Load Datasets
    train_set_augmented = torchvision.datasets.CIFAR10(root='../../data', train=True, download=True, transform=transform_train)
    train_set_clean = torchvision.datasets.CIFAR10(root='../../data', train=True, download=True, transform=transform_test)
    test_dataset = torchvision.datasets.CIFAR10(root='../../data', train=False, download=True, transform=transform_test)

    # Split Train/Val (Dependent on Seed)
    num_train = len(train_set_augmented)
    indices = list(range(num_train))
    split = 45000
    
    # Temporarily set numpy seed for split consistency within this function call
    rng = np.random.RandomState(seed) 
    rng.shuffle(indices)

    train_idx = indices[:split]
    val_idx = indices[split:]

    train_dataset = Subset(train_set_augmented, train_idx)
    val_dataset = Subset(train_set_clean, val_idx)

    # Create Loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
    
    return train_loader, val_loader, test_loader

# %%
# ============================================================================
# PHASE 1: Iterative Pruning (Winning Tickets)
# ============================================================================
print(f"\n{'='*40}")
print("PHASE 1: Iterative Pruning Experiments")
print(f"{'='*40}")

all_trials_iterative = []

for trial_idx, seed in enumerate(SEEDS):
    print(f"\n>>> Starting Iterative Trial {trial_idx + 1}/{len(SEEDS)} | Seed {seed}")
    
    # 1. Set seed for reproducibility
    set_seed(seed)
    
    # 2. Prepare Data & Model
    train_loader, val_loader, test_loader = get_dataloaders(seed)
    model = ResNet20_CIFAR10().to(device)
    
    # 3. Run Iterative Pruning
    iter_results = iterative_pruning(
        model=model,
        train_loader=train_loader,
        test_loader=test_loader,
        val_loader=val_loader,
        optimizer_class=torch.optim.SGD,
        optimizer_kwargs={'lr': lr, 'momentum': 0.9, 'weight_decay': 1e-4},
        device=device,
        config=pruning_config,
        epochs_per_round=epochs_per_round,
        n_rounds=15,
        verbose=True
    )
    
    all_trials_iterative.append(iter_results)

# 4. Save Iterative Results immediately
iterative_save_path = os.path.join(ckpt_dir, f"iterative_results_{run_id}.pth")
torch.save({
    'trials': all_trials_iterative,
    'seeds': SEEDS,
    'config': pruning_config,
    'lr': lr
}, iterative_save_path)
print(f"Saved Iterative results to: {iterative_save_path}")
# Out:
# ========================================
# PHASE 1: Iterative Pruning Experiments
# ========================================
#
# >>> Starting Iterative Trial 1/3 | Seed 42
#
# Seed set to: 42
# ======================================================================
# Starting Iterative Pruning
# Initial parameters: 269,722
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# Warmup strategy: linear_20k
# ======================================================================
#
# ======================================================================
# Round 1/15
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.2587 | Val Loss: 1.9737 | Val Acc: 25.78% | Test Acc: 25.57%
# Epoch 02 | Train Loss: 1.8798 | Val Loss: 1.7558 | Val Acc: 35.56% | Test Acc: 35.69%
# Epoch 03 | Train Loss: 1.6989 | Val Loss: 1.5947 | Val Acc: 39.98% | Test Acc: 41.51%
# Epoch 04 | Train Loss: 1.5798 | Val Loss: 1.5268 | Val Acc: 43.04% | Test Acc: 44.18%
# Epoch 05 | Train Loss: 1.4854 | Val Loss: 1.4548 | Val Acc: 47.50% | Test Acc: 47.32%
# Epoch 06 | Train Loss: 1.3947 | Val Loss: 1.3667 | Val Acc: 50.46% | Test Acc: 51.35%
# Epoch 07 | Train Loss: 1.3159 | Val Loss: 1.2716 | Val Acc: 54.48% | Test Acc: 55.09%
# Epoch 08 | Train Loss: 1.2299 | Val Loss: 1.3610 | Val Acc: 52.98% | Test Acc: 54.36%
# Epoch 09 | Train Loss: 1.1583 | Val Loss: 1.1860 | Val Acc: 57.26% | Test Acc: 59.23%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 63.72it/s]
# Epoch 10 | Train Loss: 1.0945 | Val Loss: 1.1619 | Val Acc: 58.90% | Test Acc: 60.24%
# Epoch 11 | Train Loss: 1.0397 | Val Loss: 1.0639 | Val Acc: 62.60% | Test Acc: 62.92%
# Epoch 12 | Train Loss: 0.9872 | Val Loss: 1.1206 | Val Acc: 62.34% | Test Acc: 62.55%
# Epoch 13 | Train Loss: 0.9397 | Val Loss: 1.2235 | Val Acc: 61.12% | Test Acc: 61.65%
# Epoch 14 | Train Loss: 0.8983 | Val Loss: 1.0275 | Val Acc: 65.56% | Test Acc: 64.90%
# Epoch 15 | Train Loss: 0.8571 | Val Loss: 0.9247 | Val Acc: 68.64% | Test Acc: 68.20%
# Epoch 16 | Train Loss: 0.8216 | Val Loss: 1.0808 | Val Acc: 64.80% | Test Acc: 65.92%
# Epoch 17 | Train Loss: 0.7883 | Val Loss: 0.8993 | Val Acc: 69.22% | Test Acc: 69.42%
# Epoch 18 | Train Loss: 0.7568 | Val Loss: 0.9128 | Val Acc: 69.30% | Test Acc: 69.42%
# Epoch 19 | Train Loss: 0.7251 | Val Loss: 0.9382 | Val Acc: 69.18% | Test Acc: 69.11%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 65.35it/s]
# Epoch 20 | Train Loss: 0.6986 | Val Loss: 0.9463 | Val Acc: 69.16% | Test Acc: 68.71%
# Epoch 21 | Train Loss: 0.6711 | Val Loss: 0.8869 | Val Acc: 71.58% | Test Acc: 71.62%
# Epoch 22 | Train Loss: 0.6535 | Val Loss: 0.7834 | Val Acc: 74.18% | Test Acc: 74.03%
# Epoch 23 | Train Loss: 0.6256 | Val Loss: 0.8018 | Val Acc: 73.40% | Test Acc: 73.53%
# Epoch 24 | Train Loss: 0.6128 | Val Loss: 0.7611 | Val Acc: 74.40% | Test Acc: 75.29%
# Epoch 25 | Train Loss: 0.5882 | Val Loss: 0.6903 | Val Acc: 76.66% | Test Acc: 76.51%
# Epoch 26 | Train Loss: 0.5696 | Val Loss: 0.7886 | Val Acc: 73.34% | Test Acc: 74.01%
# Epoch 27 | Train Loss: 0.5542 | Val Loss: 0.6927 | Val Acc: 77.58% | Test Acc: 77.56%
# Epoch 28 | Train Loss: 0.5430 | Val Loss: 0.6576 | Val Acc: 78.64% | Test Acc: 77.76%
# Epoch 29 | Train Loss: 0.5265 | Val Loss: 0.6357 | Val Acc: 78.04% | Test Acc: 78.90%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 62.64it/s]
# Epoch 30 | Train Loss: 0.5152 | Val Loss: 0.7760 | Val Acc: 75.70% | Test Acc: 75.45%
# Epoch 31 | Train Loss: 0.5014 | Val Loss: 0.7020 | Val Acc: 77.90% | Test Acc: 77.79%
# Epoch 32 | Train Loss: 0.4896 | Val Loss: 0.8751 | Val Acc: 72.78% | Test Acc: 73.12%
# Epoch 33 | Train Loss: 0.4751 | Val Loss: 0.6241 | Val Acc: 79.72% | Test Acc: 80.03%
# Epoch 34 | Train Loss: 0.4676 | Val Loss: 0.6267 | Val Acc: 79.54% | Test Acc: 80.00%
# Epoch 35 | Train Loss: 0.4573 | Val Loss: 0.8467 | Val Acc: 74.96% | Test Acc: 75.19%
# Epoch 36 | Train Loss: 0.4433 | Val Loss: 0.6638 | Val Acc: 78.48% | Test Acc: 79.01%
# Epoch 37 | Train Loss: 0.4390 | Val Loss: 0.6824 | Val Acc: 77.88% | Test Acc: 78.19%
# Epoch 38 | Train Loss: 0.4278 | Val Loss: 0.6769 | Val Acc: 78.86% | Test Acc: 78.76%
# Epoch 39 | Train Loss: 0.4174 | Val Loss: 0.6624 | Val Acc: 78.98% | Test Acc: 79.70%
# Epoch 40/86: 100%|██████████| 352/352 [00:06<00:00, 56.78it/s]
# Epoch 40 | Train Loss: 0.4140 | Val Loss: 0.5862 | Val Acc: 80.78% | Test Acc: 81.63%
# Epoch 41 | Train Loss: 0.4083 | Val Loss: 0.6453 | Val Acc: 80.40% | Test Acc: 79.69%
# Epoch 42 | Train Loss: 0.3891 | Val Loss: 0.5043 | Val Acc: 83.26% | Test Acc: 83.49%
# Epoch 43 | Train Loss: 0.3901 | Val Loss: 0.5889 | Val Acc: 81.86% | Test Acc: 81.59%
# Epoch 44 | Train Loss: 0.3830 | Val Loss: 0.5319 | Val Acc: 82.76% | Test Acc: 82.60%
# Epoch 45 | Train Loss: 0.3708 | Val Loss: 0.5887 | Val Acc: 82.10% | Test Acc: 81.16%
# Epoch 46 | Train Loss: 0.3691 | Val Loss: 0.6253 | Val Acc: 80.08% | Test Acc: 80.39%
# Epoch 47 | Train Loss: 0.3574 | Val Loss: 0.4887 | Val Acc: 84.12% | Test Acc: 83.68%
# Epoch 48 | Train Loss: 0.3524 | Val Loss: 0.5123 | Val Acc: 83.48% | Test Acc: 83.39%
# Epoch 49 | Train Loss: 0.3499 | Val Loss: 0.5476 | Val Acc: 82.78% | Test Acc: 83.11%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 64.71it/s]
# Epoch 50 | Train Loss: 0.3410 | Val Loss: 0.5938 | Val Acc: 80.74% | Test Acc: 80.80%
# Epoch 51 | Train Loss: 0.3405 | Val Loss: 0.5619 | Val Acc: 82.88% | Test Acc: 82.29%
# Epoch 52 | Train Loss: 0.3272 | Val Loss: 0.5181 | Val Acc: 83.76% | Test Acc: 83.81%
# Epoch 53 | Train Loss: 0.3299 | Val Loss: 0.4706 | Val Acc: 84.74% | Test Acc: 84.75%
# Epoch 54 | Train Loss: 0.3186 | Val Loss: 0.5059 | Val Acc: 84.30% | Test Acc: 83.94%
# Epoch 55 | Train Loss: 0.3153 | Val Loss: 0.6131 | Val Acc: 81.14% | Test Acc: 81.86%
# Epoch 56 | Train Loss: 0.3137 | Val Loss: 0.5793 | Val Acc: 82.24% | Test Acc: 82.43%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3090 | Val Loss: 0.5545 | Val Acc: 83.52% | Test Acc: 83.35%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2370 | Val Loss: 0.3865 | Val Acc: 87.90% | Test Acc: 87.72%
# Epoch 59 | Train Loss: 0.2149 | Val Loss: 0.3872 | Val Acc: 87.80% | Test Acc: 87.71%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 63.25it/s]
# Epoch 60 | Train Loss: 0.2100 | Val Loss: 0.3891 | Val Acc: 87.88% | Test Acc: 87.65%
# Epoch 61 | Train Loss: 0.2013 | Val Loss: 0.3815 | Val Acc: 88.20% | Test Acc: 87.76%
# Epoch 62 | Train Loss: 0.1995 | Val Loss: 0.3847 | Val Acc: 88.10% | Test Acc: 88.11%
# Epoch 63 | Train Loss: 0.1954 | Val Loss: 0.3890 | Val Acc: 87.86% | Test Acc: 87.95%
# Epoch 64 | Train Loss: 0.1908 | Val Loss: 0.3850 | Val Acc: 87.96% | Test Acc: 88.09%
# Epoch 65 | Train Loss: 0.1890 | Val Loss: 0.3894 | Val Acc: 87.86% | Test Acc: 87.93%
# Epoch 66 | Train Loss: 0.1865 | Val Loss: 0.3915 | Val Acc: 87.76% | Test Acc: 88.23%
# Epoch 67 | Train Loss: 0.1851 | Val Loss: 0.3895 | Val Acc: 87.98% | Test Acc: 88.19%
# Epoch 68 | Train Loss: 0.1827 | Val Loss: 0.3903 | Val Acc: 87.86% | Test Acc: 88.00%
# Epoch 69 | Train Loss: 0.1807 | Val Loss: 0.3871 | Val Acc: 88.52% | Test Acc: 88.09%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 64.91it/s]
# Epoch 70 | Train Loss: 0.1784 | Val Loss: 0.3865 | Val Acc: 88.28% | Test Acc: 87.99%
#    [Tracker] 🚩 Early Stop Condition at Iter 24992 (Epoch 71, Test Acc: 88.00%)
# Epoch 71 | Train Loss: 0.1778 | Val Loss: 0.3922 | Val Acc: 88.32% | Test Acc: 88.00%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.1690 | Val Loss: 0.3882 | Val Acc: 88.40% | Test Acc: 88.06%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.1672 | Val Loss: 0.3848 | Val Acc: 88.36% | Test Acc: 88.16%
# Epoch 74 | Train Loss: 0.1701 | Val Loss: 0.3893 | Val Acc: 88.18% | Test Acc: 88.16%
# Epoch 75 | Train Loss: 0.1650 | Val Loss: 0.3887 | Val Acc: 88.20% | Test Acc: 88.09%
# Epoch 76 | Train Loss: 0.1658 | Val Loss: 0.3902 | Val Acc: 88.22% | Test Acc: 88.15%
# Epoch 77 | Train Loss: 0.1673 | Val Loss: 0.3879 | Val Acc: 88.20% | Test Acc: 88.22%
# Epoch 78 | Train Loss: 0.1662 | Val Loss: 0.3884 | Val Acc: 88.14% | Test Acc: 88.23%
# Epoch 79 | Train Loss: 0.1681 | Val Loss: 0.3866 | Val Acc: 88.28% | Test Acc: 88.18%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 60.43it/s]
# Epoch 80 | Train Loss: 0.1642 | Val Loss: 0.3867 | Val Acc: 88.28% | Test Acc: 88.15%
# Epoch 81 | Train Loss: 0.1683 | Val Loss: 0.3892 | Val Acc: 88.34% | Test Acc: 88.26%
# Epoch 82 | Train Loss: 0.1634 | Val Loss: 0.3893 | Val Acc: 88.28% | Test Acc: 88.25%
# Epoch 83 | Train Loss: 0.1640 | Val Loss: 0.3937 | Val Acc: 88.04% | Test Acc: 88.17%
# Epoch 84 | Train Loss: 0.1660 | Val Loss: 0.3876 | Val Acc: 88.32% | Test Acc: 88.28%
# Epoch 85 | Train Loss: 0.1667 | Val Loss: 0.3871 | Val Acc: 88.42% | Test Acc: 88.28%
# Epoch 86 | Train Loss: 0.1656 | Val Loss: 0.3909 | Val Acc: 88.18% | Test Acc: 88.28%
#
# Round 1 Results:
#   Test Accuracy: 88.28%
#   Remaining Parameters: 216,183.0 (80.15%)
#
# ======================================================================
# Round 2/15
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.1233 | Val Loss: 1.7975 | Val Acc: 34.76% | Test Acc: 33.84%
# Epoch 02 | Train Loss: 1.7054 | Val Loss: 1.5730 | Val Acc: 41.40% | Test Acc: 42.13%
# Epoch 03 | Train Loss: 1.5359 | Val Loss: 1.4588 | Val Acc: 46.08% | Test Acc: 46.90%
# Epoch 04 | Train Loss: 1.4227 | Val Loss: 1.3637 | Val Acc: 50.08% | Test Acc: 51.13%
# Epoch 05 | Train Loss: 1.3121 | Val Loss: 1.3236 | Val Acc: 52.64% | Test Acc: 53.03%
# Epoch 06 | Train Loss: 1.2132 | Val Loss: 1.1741 | Val Acc: 57.60% | Test Acc: 58.60%
# Epoch 07 | Train Loss: 1.1221 | Val Loss: 1.1528 | Val Acc: 59.36% | Test Acc: 59.92%
# Epoch 08 | Train Loss: 1.0416 | Val Loss: 1.0342 | Val Acc: 63.60% | Test Acc: 64.51%
# Epoch 09 | Train Loss: 0.9697 | Val Loss: 0.9950 | Val Acc: 65.42% | Test Acc: 65.55%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 63.31it/s]
# Epoch 10 | Train Loss: 0.9144 | Val Loss: 0.9584 | Val Acc: 65.92% | Test Acc: 66.99%
# Epoch 11 | Train Loss: 0.8567 | Val Loss: 0.9339 | Val Acc: 67.84% | Test Acc: 68.28%
# Epoch 12 | Train Loss: 0.8019 | Val Loss: 0.8316 | Val Acc: 70.40% | Test Acc: 71.30%
# Epoch 13 | Train Loss: 0.7539 | Val Loss: 0.7618 | Val Acc: 73.84% | Test Acc: 73.56%
# Epoch 14 | Train Loss: 0.7109 | Val Loss: 0.8274 | Val Acc: 72.48% | Test Acc: 71.96%
# Epoch 15 | Train Loss: 0.6725 | Val Loss: 0.7277 | Val Acc: 74.90% | Test Acc: 75.97%
# Epoch 16 | Train Loss: 0.6410 | Val Loss: 0.7197 | Val Acc: 76.42% | Test Acc: 75.55%
# Epoch 17 | Train Loss: 0.6082 | Val Loss: 0.8216 | Val Acc: 73.12% | Test Acc: 73.00%
# Epoch 18 | Train Loss: 0.5850 | Val Loss: 0.6852 | Val Acc: 76.50% | Test Acc: 76.75%
# Epoch 19 | Train Loss: 0.5657 | Val Loss: 0.6587 | Val Acc: 77.96% | Test Acc: 77.62%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 63.14it/s]
# Epoch 20 | Train Loss: 0.5423 | Val Loss: 0.7177 | Val Acc: 76.26% | Test Acc: 76.38%
# Epoch 21 | Train Loss: 0.5229 | Val Loss: 0.8771 | Val Acc: 72.36% | Test Acc: 72.00%
# Epoch 22 | Train Loss: 0.5072 | Val Loss: 0.8020 | Val Acc: 74.86% | Test Acc: 75.01%
# Epoch 23 | Train Loss: 0.4953 | Val Loss: 0.7093 | Val Acc: 77.32% | Test Acc: 77.60%
# Epoch 24 | Train Loss: 0.4776 | Val Loss: 0.6195 | Val Acc: 79.42% | Test Acc: 79.22%
# Epoch 25 | Train Loss: 0.4656 | Val Loss: 0.8325 | Val Acc: 74.58% | Test Acc: 74.23%
# Epoch 26 | Train Loss: 0.4521 | Val Loss: 0.7018 | Val Acc: 77.18% | Test Acc: 77.28%
# Epoch 27 | Train Loss: 0.4445 | Val Loss: 0.7187 | Val Acc: 77.50% | Test Acc: 77.67%
# Epoch 28 | Train Loss: 0.4316 | Val Loss: 0.6051 | Val Acc: 79.98% | Test Acc: 80.30%
# Epoch 29 | Train Loss: 0.4239 | Val Loss: 0.6292 | Val Acc: 80.00% | Test Acc: 79.54%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 61.99it/s]
# Epoch 30 | Train Loss: 0.4130 | Val Loss: 0.6013 | Val Acc: 80.98% | Test Acc: 81.07%
# Epoch 31 | Train Loss: 0.4010 | Val Loss: 0.5531 | Val Acc: 81.82% | Test Acc: 81.49%
# Epoch 32 | Train Loss: 0.3935 | Val Loss: 0.6271 | Val Acc: 79.74% | Test Acc: 79.76%
# Epoch 33 | Train Loss: 0.3822 | Val Loss: 0.6296 | Val Acc: 80.40% | Test Acc: 79.85%
# Epoch 34 | Train Loss: 0.3815 | Val Loss: 0.5830 | Val Acc: 81.50% | Test Acc: 81.31%
# Epoch 35 | Train Loss: 0.3726 | Val Loss: 0.6586 | Val Acc: 79.48% | Test Acc: 79.29%
# Epoch 36 | Train Loss: 0.3627 | Val Loss: 0.5417 | Val Acc: 81.82% | Test Acc: 82.11%
# Epoch 37 | Train Loss: 0.3596 | Val Loss: 0.5546 | Val Acc: 81.88% | Test Acc: 83.05%
# Epoch 38 | Train Loss: 0.3541 | Val Loss: 0.5191 | Val Acc: 83.66% | Test Acc: 83.15%
# Epoch 39 | Train Loss: 0.3448 | Val Loss: 0.5927 | Val Acc: 81.62% | Test Acc: 80.79%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 67.63it/s]
# Epoch 40 | Train Loss: 0.3334 | Val Loss: 0.5244 | Val Acc: 83.66% | Test Acc: 83.19%
# Epoch 41 | Train Loss: 0.3331 | Val Loss: 0.5172 | Val Acc: 83.42% | Test Acc: 82.76%
# Epoch 42 | Train Loss: 0.3279 | Val Loss: 0.6439 | Val Acc: 80.30% | Test Acc: 79.98%
# Epoch 43 | Train Loss: 0.3232 | Val Loss: 0.5582 | Val Acc: 82.28% | Test Acc: 81.97%
# Epoch 44 | Train Loss: 0.3137 | Val Loss: 0.5807 | Val Acc: 82.56% | Test Acc: 82.27%
# Epoch 45 | Train Loss: 0.3140 | Val Loss: 0.5173 | Val Acc: 83.74% | Test Acc: 83.61%
# Epoch 46 | Train Loss: 0.3098 | Val Loss: 0.5796 | Val Acc: 82.00% | Test Acc: 82.25%
# Epoch 47 | Train Loss: 0.3002 | Val Loss: 0.5456 | Val Acc: 83.16% | Test Acc: 82.75%
# Epoch 48 | Train Loss: 0.2963 | Val Loss: 0.4912 | Val Acc: 84.78% | Test Acc: 84.33%
# Epoch 49 | Train Loss: 0.2923 | Val Loss: 0.5258 | Val Acc: 83.58% | Test Acc: 83.44%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 62.44it/s]
# Epoch 50 | Train Loss: 0.2859 | Val Loss: 0.5693 | Val Acc: 82.30% | Test Acc: 82.19%
# Epoch 51 | Train Loss: 0.2891 | Val Loss: 0.5625 | Val Acc: 83.30% | Test Acc: 83.19%
# Epoch 52 | Train Loss: 0.2798 | Val Loss: 0.4562 | Val Acc: 85.04% | Test Acc: 84.49%
# Epoch 53 | Train Loss: 0.2749 | Val Loss: 0.6128 | Val Acc: 81.78% | Test Acc: 81.69%
# Epoch 54 | Train Loss: 0.2741 | Val Loss: 0.5029 | Val Acc: 84.84% | Test Acc: 84.85%
# Epoch 55 | Train Loss: 0.2736 | Val Loss: 0.4932 | Val Acc: 85.02% | Test Acc: 84.32%
# Epoch 56 | Train Loss: 0.2639 | Val Loss: 0.4792 | Val Acc: 85.46% | Test Acc: 84.65%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.2631 | Val Loss: 0.5403 | Val Acc: 84.36% | Test Acc: 84.24%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1976 | Val Loss: 0.3618 | Val Acc: 88.16% | Test Acc: 88.43%
# Epoch 59 | Train Loss: 0.1735 | Val Loss: 0.3601 | Val Acc: 88.20% | Test Acc: 88.38%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 65.34it/s]
# Epoch 60 | Train Loss: 0.1692 | Val Loss: 0.3635 | Val Acc: 88.24% | Test Acc: 88.50%
# Epoch 61 | Train Loss: 0.1657 | Val Loss: 0.3653 | Val Acc: 88.36% | Test Acc: 88.70%
# Epoch 62 | Train Loss: 0.1617 | Val Loss: 0.3686 | Val Acc: 88.24% | Test Acc: 88.65%
# Epoch 63 | Train Loss: 0.1572 | Val Loss: 0.3661 | Val Acc: 88.56% | Test Acc: 88.58%
# Epoch 64 | Train Loss: 0.1541 | Val Loss: 0.3658 | Val Acc: 88.68% | Test Acc: 88.58%
# Epoch 65 | Train Loss: 0.1521 | Val Loss: 0.3647 | Val Acc: 88.58% | Test Acc: 88.76%
# Epoch 66 | Train Loss: 0.1464 | Val Loss: 0.3695 | Val Acc: 88.20% | Test Acc: 88.69%
# Epoch 67 | Train Loss: 0.1483 | Val Loss: 0.3726 | Val Acc: 88.54% | Test Acc: 88.35%
# Epoch 68 | Train Loss: 0.1453 | Val Loss: 0.3772 | Val Acc: 88.32% | Test Acc: 88.66%
#    [Tracker] 🚩 Early Stop Condition at Iter 24288 (Epoch 69, Test Acc: 88.72%)
# Epoch 69 | Train Loss: 0.1452 | Val Loss: 0.3696 | Val Acc: 88.56% | Test Acc: 88.72%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 61.79it/s]
# Epoch 70 | Train Loss: 0.1424 | Val Loss: 0.3734 | Val Acc: 88.54% | Test Acc: 88.68%
# Epoch 71 | Train Loss: 0.1438 | Val Loss: 0.3717 | Val Acc: 88.66% | Test Acc: 88.56%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.1365 | Val Loss: 0.3702 | Val Acc: 88.56% | Test Acc: 88.69%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.1375 | Val Loss: 0.3704 | Val Acc: 88.76% | Test Acc: 88.76%
# Epoch 74 | Train Loss: 0.1351 | Val Loss: 0.3702 | Val Acc: 88.86% | Test Acc: 88.85%
# Epoch 75 | Train Loss: 0.1347 | Val Loss: 0.3675 | Val Acc: 88.60% | Test Acc: 88.78%
# Epoch 76 | Train Loss: 0.1318 | Val Loss: 0.3714 | Val Acc: 88.50% | Test Acc: 88.86%
# Epoch 77 | Train Loss: 0.1325 | Val Loss: 0.3704 | Val Acc: 88.80% | Test Acc: 88.79%
# Epoch 78 | Train Loss: 0.1304 | Val Loss: 0.3714 | Val Acc: 88.56% | Test Acc: 88.85%
# Epoch 79 | Train Loss: 0.1331 | Val Loss: 0.3711 | Val Acc: 88.56% | Test Acc: 88.89%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 65.57it/s]
# Epoch 80 | Train Loss: 0.1335 | Val Loss: 0.3726 | Val Acc: 88.66% | Test Acc: 88.78%
# Epoch 81 | Train Loss: 0.1312 | Val Loss: 0.3706 | Val Acc: 88.56% | Test Acc: 88.82%
# Epoch 82 | Train Loss: 0.1333 | Val Loss: 0.3713 | Val Acc: 88.68% | Test Acc: 88.91%
# Epoch 83 | Train Loss: 0.1318 | Val Loss: 0.3714 | Val Acc: 88.54% | Test Acc: 88.85%
# Epoch 84 | Train Loss: 0.1330 | Val Loss: 0.3684 | Val Acc: 88.68% | Test Acc: 88.92%
# Epoch 85 | Train Loss: 0.1313 | Val Loss: 0.3733 | Val Acc: 88.46% | Test Acc: 88.74%
# Epoch 86 | Train Loss: 0.1319 | Val Loss: 0.3717 | Val Acc: 88.62% | Test Acc: 88.84%
#
# Round 2 Results:
#   Test Accuracy: 88.84%
#   Remaining Parameters: 173,351.0 (64.27%)
#
# ======================================================================
# Round 3/15
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.0352 | Val Loss: 1.7010 | Val Acc: 37.70% | Test Acc: 37.58%
# Epoch 02 | Train Loss: 1.6123 | Val Loss: 1.4991 | Val Acc: 44.24% | Test Acc: 45.66%
# Epoch 03 | Train Loss: 1.4329 | Val Loss: 1.3335 | Val Acc: 51.62% | Test Acc: 52.07%
# Epoch 04 | Train Loss: 1.2764 | Val Loss: 1.2100 | Val Acc: 57.06% | Test Acc: 57.08%
# Epoch 05 | Train Loss: 1.1322 | Val Loss: 1.1422 | Val Acc: 59.82% | Test Acc: 60.33%
# Epoch 06 | Train Loss: 1.0230 | Val Loss: 1.0685 | Val Acc: 63.52% | Test Acc: 63.07%
# Epoch 07 | Train Loss: 0.9258 | Val Loss: 0.9202 | Val Acc: 67.84% | Test Acc: 67.35%
# Epoch 08 | Train Loss: 0.8444 | Val Loss: 0.9821 | Val Acc: 66.68% | Test Acc: 67.18%
# Epoch 09 | Train Loss: 0.7745 | Val Loss: 0.7508 | Val Acc: 74.44% | Test Acc: 73.83%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 65.07it/s]
# Epoch 10 | Train Loss: 0.7062 | Val Loss: 0.7169 | Val Acc: 75.74% | Test Acc: 75.04%
# Epoch 11 | Train Loss: 0.6555 | Val Loss: 0.7079 | Val Acc: 75.50% | Test Acc: 75.70%
# Epoch 12 | Train Loss: 0.6154 | Val Loss: 0.7142 | Val Acc: 76.54% | Test Acc: 75.57%
# Epoch 13 | Train Loss: 0.5803 | Val Loss: 0.6374 | Val Acc: 79.14% | Test Acc: 78.20%
# Epoch 14 | Train Loss: 0.5496 | Val Loss: 0.6332 | Val Acc: 77.84% | Test Acc: 78.32%
# Epoch 15 | Train Loss: 0.5241 | Val Loss: 0.6067 | Val Acc: 79.86% | Test Acc: 79.42%
# Epoch 16 | Train Loss: 0.5004 | Val Loss: 0.5927 | Val Acc: 80.36% | Test Acc: 80.00%
# Epoch 17 | Train Loss: 0.4795 | Val Loss: 0.5903 | Val Acc: 79.54% | Test Acc: 80.00%
# Epoch 18 | Train Loss: 0.4558 | Val Loss: 0.6180 | Val Acc: 79.22% | Test Acc: 79.28%
# Epoch 19 | Train Loss: 0.4469 | Val Loss: 0.5149 | Val Acc: 82.96% | Test Acc: 82.06%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 60.87it/s]
# Epoch 20 | Train Loss: 0.4292 | Val Loss: 0.6642 | Val Acc: 79.84% | Test Acc: 78.75%
# Epoch 21 | Train Loss: 0.4118 | Val Loss: 0.6009 | Val Acc: 80.32% | Test Acc: 80.29%
# Epoch 22 | Train Loss: 0.4033 | Val Loss: 0.6626 | Val Acc: 78.40% | Test Acc: 78.31%
# Epoch 23 | Train Loss: 0.3906 | Val Loss: 0.6041 | Val Acc: 80.68% | Test Acc: 79.61%
# Epoch 24 | Train Loss: 0.3834 | Val Loss: 0.5846 | Val Acc: 80.68% | Test Acc: 81.19%
# Epoch 25 | Train Loss: 0.3730 | Val Loss: 0.5437 | Val Acc: 82.54% | Test Acc: 82.06%
# Epoch 26 | Train Loss: 0.3652 | Val Loss: 0.5914 | Val Acc: 81.64% | Test Acc: 81.16%
# Epoch 27 | Train Loss: 0.3535 | Val Loss: 0.5633 | Val Acc: 82.22% | Test Acc: 82.25%
# Epoch 28 | Train Loss: 0.3372 | Val Loss: 0.6448 | Val Acc: 79.56% | Test Acc: 79.83%
# Epoch 29 | Train Loss: 0.3380 | Val Loss: 0.5695 | Val Acc: 82.10% | Test Acc: 81.64%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 63.76it/s]
# Epoch 30 | Train Loss: 0.3363 | Val Loss: 0.4824 | Val Acc: 84.46% | Test Acc: 84.19%
# Epoch 31 | Train Loss: 0.3228 | Val Loss: 0.5378 | Val Acc: 83.10% | Test Acc: 82.67%
# Epoch 32 | Train Loss: 0.3213 | Val Loss: 0.5690 | Val Acc: 82.82% | Test Acc: 82.11%
# Epoch 33 | Train Loss: 0.3111 | Val Loss: 0.5902 | Val Acc: 81.52% | Test Acc: 80.95%
# Epoch 34 | Train Loss: 0.3073 | Val Loss: 0.5171 | Val Acc: 83.78% | Test Acc: 83.91%
# Epoch 35 | Train Loss: 0.3056 | Val Loss: 0.5311 | Val Acc: 83.14% | Test Acc: 83.23%
# Epoch 36 | Train Loss: 0.3004 | Val Loss: 0.5063 | Val Acc: 84.24% | Test Acc: 84.25%
# Epoch 37 | Train Loss: 0.2924 | Val Loss: 0.5984 | Val Acc: 82.48% | Test Acc: 81.86%
# Epoch 38 | Train Loss: 0.2889 | Val Loss: 0.5685 | Val Acc: 82.76% | Test Acc: 82.40%
# Epoch 39 | Train Loss: 0.2876 | Val Loss: 0.4678 | Val Acc: 85.00% | Test Acc: 84.62%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 66.20it/s]
# Epoch 40 | Train Loss: 0.2831 | Val Loss: 0.5121 | Val Acc: 84.64% | Test Acc: 83.47%
# Epoch 41 | Train Loss: 0.2823 | Val Loss: 0.5303 | Val Acc: 83.86% | Test Acc: 83.40%
# Epoch 42 | Train Loss: 0.2738 | Val Loss: 0.5021 | Val Acc: 84.92% | Test Acc: 84.33%
# Epoch 43 | Train Loss: 0.2673 | Val Loss: 0.4973 | Val Acc: 84.76% | Test Acc: 84.54%
# Epoch 44 | Train Loss: 0.2680 | Val Loss: 0.5078 | Val Acc: 84.50% | Test Acc: 84.30%
# Epoch 45 | Train Loss: 0.2659 | Val Loss: 0.5927 | Val Acc: 82.38% | Test Acc: 81.54%
# Epoch 46 | Train Loss: 0.2577 | Val Loss: 0.4647 | Val Acc: 86.28% | Test Acc: 85.72%
# Epoch 47 | Train Loss: 0.2622 | Val Loss: 0.6062 | Val Acc: 83.16% | Test Acc: 82.38%
# Epoch 48 | Train Loss: 0.2523 | Val Loss: 0.5084 | Val Acc: 84.84% | Test Acc: 84.64%
# Epoch 49 | Train Loss: 0.2538 | Val Loss: 0.5655 | Val Acc: 83.66% | Test Acc: 83.59%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 64.82it/s]
# Epoch 50 | Train Loss: 0.2504 | Val Loss: 0.6197 | Val Acc: 82.74% | Test Acc: 82.62%
# Epoch 51 | Train Loss: 0.2445 | Val Loss: 0.4806 | Val Acc: 85.14% | Test Acc: 85.60%
# Epoch 52 | Train Loss: 0.2456 | Val Loss: 0.5627 | Val Acc: 84.60% | Test Acc: 83.76%
# Epoch 53 | Train Loss: 0.2407 | Val Loss: 0.5450 | Val Acc: 84.44% | Test Acc: 84.07%
# Epoch 54 | Train Loss: 0.2372 | Val Loss: 0.4868 | Val Acc: 85.64% | Test Acc: 85.65%
# Epoch 55 | Train Loss: 0.2438 | Val Loss: 0.5366 | Val Acc: 84.70% | Test Acc: 84.11%
# Epoch 56 | Train Loss: 0.2344 | Val Loss: 0.5385 | Val Acc: 84.44% | Test Acc: 84.21%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.2306 | Val Loss: 0.5613 | Val Acc: 83.86% | Test Acc: 83.67%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1704 | Val Loss: 0.3599 | Val Acc: 88.74% | Test Acc: 88.80%
# Epoch 59 | Train Loss: 0.1482 | Val Loss: 0.3654 | Val Acc: 88.62% | Test Acc: 88.82%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 65.54it/s]
# Epoch 60 | Train Loss: 0.1441 | Val Loss: 0.3592 | Val Acc: 88.86% | Test Acc: 89.16%
# Epoch 61 | Train Loss: 0.1377 | Val Loss: 0.3650 | Val Acc: 88.70% | Test Acc: 88.87%
# Epoch 62 | Train Loss: 0.1345 | Val Loss: 0.3617 | Val Acc: 88.98% | Test Acc: 89.11%
# Epoch 63 | Train Loss: 0.1300 | Val Loss: 0.3663 | Val Acc: 89.06% | Test Acc: 89.11%
# Epoch 64 | Train Loss: 0.1297 | Val Loss: 0.3716 | Val Acc: 88.74% | Test Acc: 89.16%
# Epoch 65 | Train Loss: 0.1268 | Val Loss: 0.3705 | Val Acc: 88.70% | Test Acc: 89.11%
# Epoch 66 | Train Loss: 0.1276 | Val Loss: 0.3757 | Val Acc: 88.64% | Test Acc: 88.99%
# Epoch 67 | Train Loss: 0.1254 | Val Loss: 0.3744 | Val Acc: 89.14% | Test Acc: 88.96%
#    [Tracker] 🚩 Early Stop Condition at Iter 23936 (Epoch 68, Test Acc: 89.06%)
# Epoch 68 | Train Loss: 0.1221 | Val Loss: 0.3736 | Val Acc: 88.72% | Test Acc: 89.06%
# Epoch 69 | Train Loss: 0.1195 | Val Loss: 0.3757 | Val Acc: 88.78% | Test Acc: 88.96%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 59.73it/s]
# Epoch 70 | Train Loss: 0.1173 | Val Loss: 0.3813 | Val Acc: 88.76% | Test Acc: 89.07%
# Epoch 71 | Train Loss: 0.1176 | Val Loss: 0.3852 | Val Acc: 88.54% | Test Acc: 89.05%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.1126 | Val Loss: 0.3822 | Val Acc: 88.60% | Test Acc: 89.01%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.1126 | Val Loss: 0.3813 | Val Acc: 88.58% | Test Acc: 89.13%
# Epoch 74 | Train Loss: 0.1111 | Val Loss: 0.3816 | Val Acc: 88.52% | Test Acc: 89.08%
# Epoch 75 | Train Loss: 0.1095 | Val Loss: 0.3806 | Val Acc: 88.64% | Test Acc: 88.99%
# Epoch 76 | Train Loss: 0.1101 | Val Loss: 0.3809 | Val Acc: 88.60% | Test Acc: 89.15%
# Epoch 77 | Train Loss: 0.1094 | Val Loss: 0.3799 | Val Acc: 88.66% | Test Acc: 89.16%
# Epoch 78 | Train Loss: 0.1110 | Val Loss: 0.3792 | Val Acc: 88.78% | Test Acc: 89.16%
# Epoch 79 | Train Loss: 0.1083 | Val Loss: 0.3791 | Val Acc: 88.54% | Test Acc: 89.20%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 63.39it/s]
# Epoch 80 | Train Loss: 0.1085 | Val Loss: 0.3786 | Val Acc: 88.54% | Test Acc: 89.19%
# Epoch 81 | Train Loss: 0.1087 | Val Loss: 0.3831 | Val Acc: 88.70% | Test Acc: 89.21%
# Epoch 82 | Train Loss: 0.1087 | Val Loss: 0.3833 | Val Acc: 88.68% | Test Acc: 89.16%
# Epoch 83 | Train Loss: 0.1082 | Val Loss: 0.3811 | Val Acc: 88.56% | Test Acc: 89.23%
# Epoch 84 | Train Loss: 0.1080 | Val Loss: 0.3817 | Val Acc: 88.54% | Test Acc: 89.19%
# Epoch 85 | Train Loss: 0.1103 | Val Loss: 0.3806 | Val Acc: 88.74% | Test Acc: 89.15%
# Epoch 86 | Train Loss: 0.1076 | Val Loss: 0.3836 | Val Acc: 88.80% | Test Acc: 89.14%
#
# Round 3 Results:
#   Test Accuracy: 89.14%
#   Remaining Parameters: 139,086.0 (51.57%)
#
# ======================================================================
# Round 4/15
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.0193 | Val Loss: 1.6460 | Val Acc: 38.36% | Test Acc: 38.78%
# Epoch 02 | Train Loss: 1.5367 | Val Loss: 1.4066 | Val Acc: 48.06% | Test Acc: 49.41%
# Epoch 03 | Train Loss: 1.3139 | Val Loss: 1.2080 | Val Acc: 56.40% | Test Acc: 57.19%
# Epoch 04 | Train Loss: 1.1322 | Val Loss: 1.0532 | Val Acc: 63.04% | Test Acc: 63.35%
# Epoch 05 | Train Loss: 0.9852 | Val Loss: 0.9488 | Val Acc: 66.16% | Test Acc: 66.06%
# Epoch 06 | Train Loss: 0.8696 | Val Loss: 0.8209 | Val Acc: 71.16% | Test Acc: 70.80%
# Epoch 07 | Train Loss: 0.7750 | Val Loss: 0.7487 | Val Acc: 73.64% | Test Acc: 73.39%
# Epoch 08 | Train Loss: 0.6979 | Val Loss: 0.7014 | Val Acc: 75.82% | Test Acc: 75.66%
# Epoch 09 | Train Loss: 0.6346 | Val Loss: 0.6502 | Val Acc: 78.08% | Test Acc: 77.85%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 66.07it/s]
# Epoch 10 | Train Loss: 0.5850 | Val Loss: 0.6412 | Val Acc: 77.88% | Test Acc: 77.95%
# Epoch 11 | Train Loss: 0.5422 | Val Loss: 0.5802 | Val Acc: 80.22% | Test Acc: 79.94%
# Epoch 12 | Train Loss: 0.5101 | Val Loss: 0.5853 | Val Acc: 80.62% | Test Acc: 80.24%
# Epoch 13 | Train Loss: 0.4791 | Val Loss: 0.5610 | Val Acc: 81.00% | Test Acc: 81.03%
# Epoch 14 | Train Loss: 0.4576 | Val Loss: 0.5879 | Val Acc: 80.48% | Test Acc: 80.89%
# Epoch 15 | Train Loss: 0.4362 | Val Loss: 0.5368 | Val Acc: 81.88% | Test Acc: 81.96%
# Epoch 16 | Train Loss: 0.4170 | Val Loss: 0.5339 | Val Acc: 81.96% | Test Acc: 82.09%
# Epoch 17 | Train Loss: 0.3974 | Val Loss: 0.5420 | Val Acc: 82.12% | Test Acc: 82.24%
# Epoch 18 | Train Loss: 0.3793 | Val Loss: 0.5401 | Val Acc: 82.18% | Test Acc: 82.13%
# Epoch 19 | Train Loss: 0.3694 | Val Loss: 0.5136 | Val Acc: 83.32% | Test Acc: 82.67%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 64.53it/s]
# Epoch 20 | Train Loss: 0.3537 | Val Loss: 0.5162 | Val Acc: 83.22% | Test Acc: 82.90%
# Epoch 21 | Train Loss: 0.3420 | Val Loss: 0.5632 | Val Acc: 81.04% | Test Acc: 81.27%
# Epoch 22 | Train Loss: 0.3320 | Val Loss: 0.5548 | Val Acc: 81.22% | Test Acc: 81.31%
# Epoch 23 | Train Loss: 0.3230 | Val Loss: 0.5023 | Val Acc: 83.66% | Test Acc: 83.85%
# Epoch 24 | Train Loss: 0.3153 | Val Loss: 0.4829 | Val Acc: 84.36% | Test Acc: 83.86%
# Epoch 25 | Train Loss: 0.3056 | Val Loss: 0.4808 | Val Acc: 84.60% | Test Acc: 84.28%
# Epoch 26 | Train Loss: 0.2987 | Val Loss: 0.4942 | Val Acc: 84.30% | Test Acc: 83.42%
# Epoch 27 | Train Loss: 0.2935 | Val Loss: 0.5401 | Val Acc: 83.46% | Test Acc: 82.15%
# Epoch 28 | Train Loss: 0.2897 | Val Loss: 0.6443 | Val Acc: 80.76% | Test Acc: 80.76%
# Epoch 29 | Train Loss: 0.2826 | Val Loss: 0.4693 | Val Acc: 85.22% | Test Acc: 84.69%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 61.59it/s]
# Epoch 30 | Train Loss: 0.2837 | Val Loss: 0.5392 | Val Acc: 83.74% | Test Acc: 82.73%
# Epoch 31 | Train Loss: 0.2718 | Val Loss: 0.5005 | Val Acc: 84.74% | Test Acc: 83.99%
# Epoch 32 | Train Loss: 0.2687 | Val Loss: 0.5689 | Val Acc: 82.96% | Test Acc: 82.79%
# Epoch 33 | Train Loss: 0.2639 | Val Loss: 0.5666 | Val Acc: 83.02% | Test Acc: 82.62%
# Epoch 34 | Train Loss: 0.2627 | Val Loss: 0.5214 | Val Acc: 84.70% | Test Acc: 83.52%
# Epoch 35 | Train Loss: 0.2567 | Val Loss: 0.5418 | Val Acc: 83.68% | Test Acc: 83.11%
# Epoch 36 | Train Loss: 0.2553 | Val Loss: 0.5419 | Val Acc: 83.88% | Test Acc: 83.78%
# Epoch 37 | Train Loss: 0.2491 | Val Loss: 0.5027 | Val Acc: 85.46% | Test Acc: 85.07%
# Epoch 38 | Train Loss: 0.2458 | Val Loss: 0.5081 | Val Acc: 85.02% | Test Acc: 84.40%
# Epoch 39 | Train Loss: 0.2478 | Val Loss: 0.4855 | Val Acc: 84.94% | Test Acc: 85.14%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 63.97it/s]
# Epoch 40 | Train Loss: 0.2420 | Val Loss: 0.5390 | Val Acc: 84.00% | Test Acc: 83.56%
# Epoch 41 | Train Loss: 0.2348 | Val Loss: 0.5387 | Val Acc: 84.40% | Test Acc: 84.14%
# Epoch 42 | Train Loss: 0.2325 | Val Loss: 0.6076 | Val Acc: 82.46% | Test Acc: 82.70%
# Epoch 43 | Train Loss: 0.2336 | Val Loss: 0.4770 | Val Acc: 85.42% | Test Acc: 85.16%
# Epoch 44 | Train Loss: 0.2313 | Val Loss: 0.4826 | Val Acc: 85.96% | Test Acc: 85.16%
# Epoch 45 | Train Loss: 0.2275 | Val Loss: 0.5829 | Val Acc: 83.84% | Test Acc: 83.42%
# Epoch 46 | Train Loss: 0.2299 | Val Loss: 0.5009 | Val Acc: 85.14% | Test Acc: 84.88%
# Epoch 47 | Train Loss: 0.2243 | Val Loss: 0.4831 | Val Acc: 86.18% | Test Acc: 85.94%
# Epoch 48 | Train Loss: 0.2262 | Val Loss: 0.4942 | Val Acc: 85.14% | Test Acc: 85.39%
# Epoch 49 | Train Loss: 0.2216 | Val Loss: 0.4602 | Val Acc: 86.16% | Test Acc: 86.34%
# Epoch 50/86: 100%|██████████| 352/352 [00:06<00:00, 57.56it/s]
# Epoch 50 | Train Loss: 0.2217 | Val Loss: 0.5606 | Val Acc: 83.72% | Test Acc: 83.75%
# Epoch 51 | Train Loss: 0.2185 | Val Loss: 0.5313 | Val Acc: 84.84% | Test Acc: 84.60%
# Epoch 52 | Train Loss: 0.2141 | Val Loss: 0.5663 | Val Acc: 83.74% | Test Acc: 83.24%
# Epoch 53 | Train Loss: 0.2211 | Val Loss: 0.7093 | Val Acc: 80.86% | Test Acc: 80.33%
# Epoch 54 | Train Loss: 0.2129 | Val Loss: 0.5971 | Val Acc: 83.72% | Test Acc: 84.65%
# Epoch 55 | Train Loss: 0.2118 | Val Loss: 0.5030 | Val Acc: 85.66% | Test Acc: 85.24%
# Epoch 56 | Train Loss: 0.2093 | Val Loss: 0.4624 | Val Acc: 86.72% | Test Acc: 85.94%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.2088 | Val Loss: 0.4321 | Val Acc: 87.02% | Test Acc: 86.77%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1482 | Val Loss: 0.3638 | Val Acc: 88.64% | Test Acc: 88.78%
# Epoch 59 | Train Loss: 0.1311 | Val Loss: 0.3666 | Val Acc: 88.92% | Test Acc: 88.65%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 60.88it/s]
# Epoch 60 | Train Loss: 0.1242 | Val Loss: 0.3693 | Val Acc: 88.94% | Test Acc: 88.84%
# Epoch 61 | Train Loss: 0.1192 | Val Loss: 0.3645 | Val Acc: 88.96% | Test Acc: 89.09%
# Epoch 62 | Train Loss: 0.1157 | Val Loss: 0.3662 | Val Acc: 89.02% | Test Acc: 89.03%
# Epoch 63 | Train Loss: 0.1128 | Val Loss: 0.3729 | Val Acc: 88.80% | Test Acc: 88.87%
# Epoch 64 | Train Loss: 0.1098 | Val Loss: 0.3723 | Val Acc: 88.94% | Test Acc: 89.06%
# Epoch 65 | Train Loss: 0.1105 | Val Loss: 0.3751 | Val Acc: 88.80% | Test Acc: 88.92%
# Epoch 66 | Train Loss: 0.1096 | Val Loss: 0.3739 | Val Acc: 88.82% | Test Acc: 89.01%
# Epoch 67 | Train Loss: 0.1066 | Val Loss: 0.3805 | Val Acc: 88.90% | Test Acc: 88.95%
#    [Tracker] 🚩 Early Stop Condition at Iter 23936 (Epoch 68, Test Acc: 89.15%)
# Epoch 68 | Train Loss: 0.1054 | Val Loss: 0.3767 | Val Acc: 89.02% | Test Acc: 89.15%
# Epoch 69 | Train Loss: 0.1036 | Val Loss: 0.3760 | Val Acc: 89.10% | Test Acc: 89.06%
# Epoch 70/86: 100%|██████████| 352/352 [00:06<00:00, 57.76it/s]
# Epoch 70 | Train Loss: 0.1042 | Val Loss: 0.3781 | Val Acc: 89.38% | Test Acc: 89.03%
# Epoch 71 | Train Loss: 0.0997 | Val Loss: 0.3797 | Val Acc: 88.96% | Test Acc: 89.02%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.0970 | Val Loss: 0.3778 | Val Acc: 89.12% | Test Acc: 89.14%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.0970 | Val Loss: 0.3796 | Val Acc: 88.94% | Test Acc: 88.97%
# Epoch 74 | Train Loss: 0.0968 | Val Loss: 0.3772 | Val Acc: 89.10% | Test Acc: 89.03%
# Epoch 75 | Train Loss: 0.0944 | Val Loss: 0.3785 | Val Acc: 89.12% | Test Acc: 89.15%
# Epoch 76 | Train Loss: 0.0959 | Val Loss: 0.3783 | Val Acc: 89.04% | Test Acc: 89.21%
# Epoch 77 | Train Loss: 0.0931 | Val Loss: 0.3766 | Val Acc: 89.12% | Test Acc: 89.13%
# Epoch 78 | Train Loss: 0.0962 | Val Loss: 0.3761 | Val Acc: 88.94% | Test Acc: 89.12%
# Epoch 79 | Train Loss: 0.0937 | Val Loss: 0.3775 | Val Acc: 89.06% | Test Acc: 89.15%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 66.62it/s]
# Epoch 80 | Train Loss: 0.0939 | Val Loss: 0.3754 | Val Acc: 89.28% | Test Acc: 89.09%
# Epoch 81 | Train Loss: 0.0935 | Val Loss: 0.3754 | Val Acc: 89.22% | Test Acc: 89.06%
# Epoch 82 | Train Loss: 0.0911 | Val Loss: 0.3786 | Val Acc: 89.24% | Test Acc: 89.10%
# Epoch 83 | Train Loss: 0.0951 | Val Loss: 0.3778 | Val Acc: 89.04% | Test Acc: 89.17%
# Epoch 84 | Train Loss: 0.0943 | Val Loss: 0.3777 | Val Acc: 88.94% | Test Acc: 89.06%
# Epoch 85 | Train Loss: 0.0932 | Val Loss: 0.3753 | Val Acc: 89.12% | Test Acc: 89.11%
# Epoch 86 | Train Loss: 0.0926 | Val Loss: 0.3772 | Val Acc: 89.26% | Test Acc: 89.09%
#
# Round 4 Results:
#   Test Accuracy: 89.09%
#   Remaining Parameters: 111,674.0 (41.40%)
#
# ======================================================================
# Round 5/15
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 1.9635 | Val Loss: 1.5816 | Val Acc: 42.06% | Test Acc: 43.04%
# Epoch 02 | Train Loss: 1.4778 | Val Loss: 1.3264 | Val Acc: 51.56% | Test Acc: 52.87%
# Epoch 03 | Train Loss: 1.2494 | Val Loss: 1.1252 | Val Acc: 59.46% | Test Acc: 60.58%
# Epoch 04 | Train Loss: 1.0575 | Val Loss: 1.0008 | Val Acc: 65.08% | Test Acc: 64.97%
# Epoch 05 | Train Loss: 0.9080 | Val Loss: 0.8409 | Val Acc: 71.12% | Test Acc: 69.91%
# Epoch 06 | Train Loss: 0.7887 | Val Loss: 0.7256 | Val Acc: 74.98% | Test Acc: 74.12%
# Epoch 07 | Train Loss: 0.6930 | Val Loss: 0.7289 | Val Acc: 75.50% | Test Acc: 75.14%
# Epoch 08 | Train Loss: 0.6144 | Val Loss: 0.6322 | Val Acc: 78.46% | Test Acc: 77.80%
# Epoch 09 | Train Loss: 0.5609 | Val Loss: 0.5820 | Val Acc: 80.12% | Test Acc: 79.79%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 65.74it/s]
# Epoch 10 | Train Loss: 0.5168 | Val Loss: 0.5945 | Val Acc: 80.32% | Test Acc: 79.67%
# Epoch 11 | Train Loss: 0.4769 | Val Loss: 0.5565 | Val Acc: 81.34% | Test Acc: 81.08%
# Epoch 12 | Train Loss: 0.4515 | Val Loss: 0.5322 | Val Acc: 81.54% | Test Acc: 82.04%
# Epoch 13 | Train Loss: 0.4220 | Val Loss: 0.5228 | Val Acc: 82.22% | Test Acc: 82.17%
# Epoch 14 | Train Loss: 0.3993 | Val Loss: 0.6415 | Val Acc: 79.54% | Test Acc: 78.98%
# Epoch 15 | Train Loss: 0.3803 | Val Loss: 0.5229 | Val Acc: 82.36% | Test Acc: 82.53%
# Epoch 16 | Train Loss: 0.3645 | Val Loss: 0.5057 | Val Acc: 82.98% | Test Acc: 82.57%
# Epoch 17 | Train Loss: 0.3442 | Val Loss: 0.5683 | Val Acc: 81.82% | Test Acc: 80.99%
# Epoch 18 | Train Loss: 0.3315 | Val Loss: 0.5114 | Val Acc: 83.72% | Test Acc: 83.46%
# Epoch 19 | Train Loss: 0.3185 | Val Loss: 0.4662 | Val Acc: 84.62% | Test Acc: 84.12%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 67.27it/s]
# Epoch 20 | Train Loss: 0.3046 | Val Loss: 0.5595 | Val Acc: 82.34% | Test Acc: 82.34%
# Epoch 21 | Train Loss: 0.3035 | Val Loss: 0.5809 | Val Acc: 81.46% | Test Acc: 81.72%
# Epoch 22 | Train Loss: 0.2923 | Val Loss: 0.4968 | Val Acc: 84.12% | Test Acc: 84.19%
# Epoch 23 | Train Loss: 0.2813 | Val Loss: 0.4910 | Val Acc: 84.24% | Test Acc: 84.22%
# Epoch 24 | Train Loss: 0.2765 | Val Loss: 0.4481 | Val Acc: 85.46% | Test Acc: 84.96%
# Epoch 25 | Train Loss: 0.2683 | Val Loss: 0.5859 | Val Acc: 82.60% | Test Acc: 81.79%
# Epoch 26 | Train Loss: 0.2634 | Val Loss: 0.4644 | Val Acc: 85.52% | Test Acc: 84.72%
# Epoch 27 | Train Loss: 0.2556 | Val Loss: 0.5153 | Val Acc: 84.48% | Test Acc: 83.90%
# Epoch 28 | Train Loss: 0.2520 | Val Loss: 0.4688 | Val Acc: 85.88% | Test Acc: 85.41%
# Epoch 29 | Train Loss: 0.2425 | Val Loss: 0.5470 | Val Acc: 82.98% | Test Acc: 82.77%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 67.07it/s]
# Epoch 30 | Train Loss: 0.2452 | Val Loss: 0.5161 | Val Acc: 84.42% | Test Acc: 83.85%
# Epoch 31 | Train Loss: 0.2413 | Val Loss: 0.5171 | Val Acc: 84.64% | Test Acc: 84.76%
# Epoch 32 | Train Loss: 0.2310 | Val Loss: 0.5420 | Val Acc: 83.80% | Test Acc: 84.11%
# Epoch 33 | Train Loss: 0.2372 | Val Loss: 0.4932 | Val Acc: 84.58% | Test Acc: 85.15%
# Epoch 34 | Train Loss: 0.2284 | Val Loss: 0.4886 | Val Acc: 85.48% | Test Acc: 85.25%
# Epoch 35 | Train Loss: 0.2277 | Val Loss: 0.5038 | Val Acc: 84.66% | Test Acc: 84.79%
# Epoch 36 | Train Loss: 0.2263 | Val Loss: 0.5196 | Val Acc: 84.94% | Test Acc: 84.79%
# Epoch 37 | Train Loss: 0.2227 | Val Loss: 0.5130 | Val Acc: 84.96% | Test Acc: 85.16%
# Epoch 38 | Train Loss: 0.2251 | Val Loss: 0.4643 | Val Acc: 86.06% | Test Acc: 85.92%
# Epoch 39 | Train Loss: 0.2225 | Val Loss: 0.4838 | Val Acc: 85.40% | Test Acc: 85.46%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 62.01it/s]
# Epoch 40 | Train Loss: 0.2172 | Val Loss: 0.5522 | Val Acc: 84.58% | Test Acc: 84.53%
# Epoch 41 | Train Loss: 0.2125 | Val Loss: 0.5136 | Val Acc: 84.88% | Test Acc: 84.88%
# Epoch 42 | Train Loss: 0.2103 | Val Loss: 0.4598 | Val Acc: 86.76% | Test Acc: 86.62%
# Epoch 43 | Train Loss: 0.2122 | Val Loss: 0.4982 | Val Acc: 85.64% | Test Acc: 85.82%
# Epoch 44 | Train Loss: 0.2073 | Val Loss: 0.5210 | Val Acc: 84.58% | Test Acc: 85.03%
# Epoch 45 | Train Loss: 0.2069 | Val Loss: 0.5505 | Val Acc: 84.50% | Test Acc: 85.15%
# Epoch 46 | Train Loss: 0.2114 | Val Loss: 0.4991 | Val Acc: 85.04% | Test Acc: 85.95%
# Epoch 47 | Train Loss: 0.2035 | Val Loss: 0.4946 | Val Acc: 85.42% | Test Acc: 85.72%
# Epoch 48 | Train Loss: 0.2013 | Val Loss: 0.5430 | Val Acc: 84.48% | Test Acc: 84.60%
# Epoch 49 | Train Loss: 0.2014 | Val Loss: 0.4913 | Val Acc: 85.80% | Test Acc: 85.40%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 60.54it/s]
# Epoch 50 | Train Loss: 0.2009 | Val Loss: 0.4653 | Val Acc: 86.38% | Test Acc: 85.16%
# Epoch 51 | Train Loss: 0.2014 | Val Loss: 0.4492 | Val Acc: 86.80% | Test Acc: 86.92%
# Epoch 52 | Train Loss: 0.2038 | Val Loss: 0.5006 | Val Acc: 85.82% | Test Acc: 85.61%
# Epoch 53 | Train Loss: 0.1922 | Val Loss: 0.6271 | Val Acc: 83.20% | Test Acc: 83.32%
# Epoch 54 | Train Loss: 0.1945 | Val Loss: 0.5060 | Val Acc: 85.44% | Test Acc: 85.82%
# Epoch 55 | Train Loss: 0.1962 | Val Loss: 0.6177 | Val Acc: 83.68% | Test Acc: 83.22%
# Epoch 56 | Train Loss: 0.1937 | Val Loss: 0.5293 | Val Acc: 85.26% | Test Acc: 84.84%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.1917 | Val Loss: 0.5247 | Val Acc: 85.24% | Test Acc: 85.62%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.1360 | Val Loss: 0.3855 | Val Acc: 88.66% | Test Acc: 88.98%
# Epoch 59 | Train Loss: 0.1171 | Val Loss: 0.3838 | Val Acc: 88.88% | Test Acc: 89.00%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 59.71it/s]
# Epoch 60 | Train Loss: 0.1116 | Val Loss: 0.3887 | Val Acc: 88.66% | Test Acc: 88.83%
# Epoch 61 | Train Loss: 0.1076 | Val Loss: 0.3789 | Val Acc: 88.78% | Test Acc: 89.06%
# Epoch 62 | Train Loss: 0.1035 | Val Loss: 0.3881 | Val Acc: 89.02% | Test Acc: 89.01%
# Epoch 63 | Train Loss: 0.1013 | Val Loss: 0.3869 | Val Acc: 88.86% | Test Acc: 89.00%
# Epoch 64 | Train Loss: 0.1005 | Val Loss: 0.3910 | Val Acc: 89.00% | Test Acc: 88.98%
# Epoch 65 | Train Loss: 0.0979 | Val Loss: 0.3921 | Val Acc: 88.94% | Test Acc: 89.06%
# Epoch 66 | Train Loss: 0.0939 | Val Loss: 0.3972 | Val Acc: 88.70% | Test Acc: 88.97%
# Epoch 67 | Train Loss: 0.0921 | Val Loss: 0.3888 | Val Acc: 88.96% | Test Acc: 89.01%
# Epoch 68 | Train Loss: 0.0916 | Val Loss: 0.3989 | Val Acc: 88.84% | Test Acc: 89.10%
# Epoch 69 | Train Loss: 0.0929 | Val Loss: 0.3945 | Val Acc: 88.92% | Test Acc: 89.17%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 63.18it/s]
# Epoch 70 | Train Loss: 0.0883 | Val Loss: 0.4075 | Val Acc: 88.56% | Test Acc: 88.78%
#    [Tracker] 🚩 Early Stop Condition at Iter 24992 (Epoch 71, Test Acc: 88.98%)
# Epoch 71 | Train Loss: 0.0889 | Val Loss: 0.3997 | Val Acc: 88.66% | Test Acc: 88.98%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.0899 | Val Loss: 0.3971 | Val Acc: 88.86% | Test Acc: 88.99%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.0861 | Val Loss: 0.4012 | Val Acc: 88.66% | Test Acc: 88.96%
# Epoch 74 | Train Loss: 0.0841 | Val Loss: 0.3987 | Val Acc: 88.92% | Test Acc: 89.14%
# Epoch 75 | Train Loss: 0.0859 | Val Loss: 0.4010 | Val Acc: 88.90% | Test Acc: 89.10%
# Epoch 76 | Train Loss: 0.0847 | Val Loss: 0.4003 | Val Acc: 88.78% | Test Acc: 89.03%
# Epoch 77 | Train Loss: 0.0836 | Val Loss: 0.3994 | Val Acc: 88.88% | Test Acc: 89.09%
# Epoch 78 | Train Loss: 0.0850 | Val Loss: 0.3994 | Val Acc: 88.76% | Test Acc: 88.96%
# Epoch 79 | Train Loss: 0.0834 | Val Loss: 0.4016 | Val Acc: 88.74% | Test Acc: 88.94%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 66.27it/s]
# Epoch 80 | Train Loss: 0.0864 | Val Loss: 0.4010 | Val Acc: 89.00% | Test Acc: 89.10%
# Epoch 81 | Train Loss: 0.0844 | Val Loss: 0.4002 | Val Acc: 88.94% | Test Acc: 89.05%
# Epoch 82 | Train Loss: 0.0819 | Val Loss: 0.3984 | Val Acc: 89.02% | Test Acc: 89.16%
# Epoch 83 | Train Loss: 0.0818 | Val Loss: 0.3989 | Val Acc: 89.02% | Test Acc: 89.13%
# Epoch 84 | Train Loss: 0.0834 | Val Loss: 0.3999 | Val Acc: 88.94% | Test Acc: 89.05%
# Epoch 85 | Train Loss: 0.0828 | Val Loss: 0.3976 | Val Acc: 89.10% | Test Acc: 89.17%
# Epoch 86 | Train Loss: 0.0818 | Val Loss: 0.4009 | Val Acc: 89.08% | Test Acc: 89.14%
#
# Round 5 Results:
#   Test Accuracy: 89.14%
#   Remaining Parameters: 89,744.0 (33.27%)
#
# ======================================================================
# Round 6/15
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 1.9222 | Val Loss: 1.5534 | Val Acc: 42.50% | Test Acc: 43.40%
# Epoch 02 | Train Loss: 1.4390 | Val Loss: 1.2947 | Val Acc: 53.70% | Test Acc: 53.67%
# Epoch 03 | Train Loss: 1.1905 | Val Loss: 1.0525 | Val Acc: 62.44% | Test Acc: 62.90%
# Epoch 04 | Train Loss: 0.9892 | Val Loss: 0.8915 | Val Acc: 68.96% | Test Acc: 68.60%
# Epoch 05 | Train Loss: 0.8369 | Val Loss: 0.7717 | Val Acc: 73.50% | Test Acc: 72.68%
# Epoch 06 | Train Loss: 0.7252 | Val Loss: 0.6823 | Val Acc: 76.72% | Test Acc: 75.96%
# Epoch 07 | Train Loss: 0.6428 | Val Loss: 0.6275 | Val Acc: 78.88% | Test Acc: 77.77%
# Epoch 08 | Train Loss: 0.5748 | Val Loss: 0.5955 | Val Acc: 79.60% | Test Acc: 79.52%
# Epoch 09 | Train Loss: 0.5244 | Val Loss: 0.5662 | Val Acc: 80.52% | Test Acc: 79.88%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 60.95it/s]
# Epoch 10 | Train Loss: 0.4796 | Val Loss: 0.5337 | Val Acc: 81.58% | Test Acc: 81.20%
# Epoch 11 | Train Loss: 0.4408 | Val Loss: 0.5470 | Val Acc: 81.50% | Test Acc: 81.27%
# Epoch 12 | Train Loss: 0.4160 | Val Loss: 0.5639 | Val Acc: 81.70% | Test Acc: 81.11%
# Epoch 13 | Train Loss: 0.3879 | Val Loss: 0.5286 | Val Acc: 81.90% | Test Acc: 81.95%
# Epoch 14 | Train Loss: 0.3639 | Val Loss: 0.5212 | Val Acc: 82.66% | Test Acc: 82.56%
# Epoch 15 | Train Loss: 0.3451 | Val Loss: 0.5632 | Val Acc: 81.90% | Test Acc: 81.20%
# Epoch 16 | Train Loss: 0.3321 | Val Loss: 0.5297 | Val Acc: 82.48% | Test Acc: 82.48%
# Epoch 17 | Train Loss: 0.3128 | Val Loss: 0.4621 | Val Acc: 84.80% | Test Acc: 84.41%
# Epoch 18 | Train Loss: 0.2984 | Val Loss: 0.4670 | Val Acc: 84.74% | Test Acc: 84.22%
# Epoch 19 | Train Loss: 0.2871 | Val Loss: 0.4648 | Val Acc: 85.26% | Test Acc: 84.49%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 64.02it/s]
# Epoch 20 | Train Loss: 0.2760 | Val Loss: 0.4874 | Val Acc: 84.42% | Test Acc: 84.61%
# Epoch 21 | Train Loss: 0.2734 | Val Loss: 0.5039 | Val Acc: 84.28% | Test Acc: 83.86%
# Epoch 22 | Train Loss: 0.2605 | Val Loss: 0.4617 | Val Acc: 85.32% | Test Acc: 85.17%
# Epoch 23 | Train Loss: 0.2548 | Val Loss: 0.5232 | Val Acc: 84.22% | Test Acc: 83.67%
# Epoch 24 | Train Loss: 0.2467 | Val Loss: 0.5651 | Val Acc: 82.62% | Test Acc: 83.12%
# Epoch 25 | Train Loss: 0.2426 | Val Loss: 0.4671 | Val Acc: 85.84% | Test Acc: 84.99%
# Epoch 26 | Train Loss: 0.2427 | Val Loss: 0.4876 | Val Acc: 84.98% | Test Acc: 85.04%
# Epoch 27 | Train Loss: 0.2361 | Val Loss: 0.4433 | Val Acc: 86.28% | Test Acc: 85.76%
# Epoch 28 | Train Loss: 0.2296 | Val Loss: 0.4860 | Val Acc: 85.14% | Test Acc: 85.44%
# Epoch 29 | Train Loss: 0.2289 | Val Loss: 0.7250 | Val Acc: 79.54% | Test Acc: 79.96%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 60.57it/s]
# Epoch 30 | Train Loss: 0.2230 | Val Loss: 0.5103 | Val Acc: 84.92% | Test Acc: 84.50%
# Epoch 31 | Train Loss: 0.2173 | Val Loss: 0.5712 | Val Acc: 83.10% | Test Acc: 82.99%
# Epoch 32 | Train Loss: 0.2155 | Val Loss: 0.5514 | Val Acc: 83.70% | Test Acc: 83.37%
# Epoch 33 | Train Loss: 0.2165 | Val Loss: 0.6165 | Val Acc: 82.54% | Test Acc: 82.93%
# Epoch 34 | Train Loss: 0.2117 | Val Loss: 0.4810 | Val Acc: 85.80% | Test Acc: 85.48%
# Epoch 35 | Train Loss: 0.2122 | Val Loss: 0.5578 | Val Acc: 83.90% | Test Acc: 83.80%
# Epoch 36 | Train Loss: 0.2073 | Val Loss: 0.5476 | Val Acc: 84.56% | Test Acc: 84.02%
# Epoch 37 | Train Loss: 0.2084 | Val Loss: 0.5584 | Val Acc: 84.60% | Test Acc: 84.46%
# Epoch 38 | Train Loss: 0.2040 | Val Loss: 0.5191 | Val Acc: 85.26% | Test Acc: 85.16%
# Epoch 39 | Train Loss: 0.2062 | Val Loss: 0.5281 | Val Acc: 84.94% | Test Acc: 84.64%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 66.83it/s]
# Epoch 40 | Train Loss: 0.2015 | Val Loss: 0.4909 | Val Acc: 85.82% | Test Acc: 85.54%
# Epoch 41 | Train Loss: 0.2005 | Val Loss: 0.5688 | Val Acc: 83.72% | Test Acc: 83.06%
# Epoch 42 | Train Loss: 0.1986 | Val Loss: 0.4544 | Val Acc: 86.60% | Test Acc: 86.44%
# Epoch 43 | Train Loss: 0.1980 | Val Loss: 0.5604 | Val Acc: 84.28% | Test Acc: 84.27%
# Epoch 44 | Train Loss: 0.1972 | Val Loss: 0.4685 | Val Acc: 85.88% | Test Acc: 86.22%
# Epoch 45 | Train Loss: 0.1960 | Val Loss: 0.4510 | Val Acc: 86.72% | Test Acc: 86.28%
# Epoch 46 | Train Loss: 0.1976 | Val Loss: 0.5073 | Val Acc: 85.94% | Test Acc: 85.90%
# Epoch 47 | Train Loss: 0.1953 | Val Loss: 0.4896 | Val Acc: 86.20% | Test Acc: 86.23%
# Epoch 48 | Train Loss: 0.1959 | Val Loss: 0.4819 | Val Acc: 86.10% | Test Acc: 85.91%
# Epoch 49 | Train Loss: 0.1856 | Val Loss: 0.4670 | Val Acc: 86.34% | Test Acc: 86.42%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 67.07it/s]
# Epoch 50 | Train Loss: 0.1896 | Val Loss: 0.4620 | Val Acc: 86.70% | Test Acc: 86.23%
# Epoch 51 | Train Loss: 0.1850 | Val Loss: 0.6214 | Val Acc: 82.62% | Test Acc: 82.86%
# Epoch 52 | Train Loss: 0.1900 | Val Loss: 0.6493 | Val Acc: 82.60% | Test Acc: 82.74%
# Epoch 53 | Train Loss: 0.1887 | Val Loss: 0.5138 | Val Acc: 85.82% | Test Acc: 85.53%
# Epoch 54 | Train Loss: 0.1827 | Val Loss: 0.5108 | Val Acc: 86.28% | Test Acc: 85.95%
# Epoch 55 | Train Loss: 0.1851 | Val Loss: 0.7366 | Val Acc: 81.32% | Test Acc: 81.40%
# Epoch 56 | Train Loss: 0.1819 | Val Loss: 0.5168 | Val Acc: 86.42% | Test Acc: 85.61%
#  -> Scheduler Step! Current LR: 0.01
# ...
# Epoch 13 | Train Loss: 0.4736 | Val Loss: 0.5534 | Val Acc: 81.26% | Test Acc: 80.59%
# Epoch 14 | Train Loss: 0.4486 | Val Loss: 0.4858 | Val Acc: 83.46% | Test Acc: 82.63%
# Epoch 15 | Train Loss: 0.4350 | Val Loss: 0.5144 | Val Acc: 82.56% | Test Acc: 81.58%
# Epoch 16 | Train Loss: 0.4175 | Val Loss: 0.4851 | Val Acc: 83.30% | Test Acc: 81.95%
# Epoch 17 | Train Loss: 0.4044 | Val Loss: 0.4959 | Val Acc: 83.02% | Test Acc: 82.21%
# Epoch 18 | Train Loss: 0.3958 | Val Loss: 0.4471 | Val Acc: 84.60% | Test Acc: 84.00%
# Epoch 19 | Train Loss: 0.3847 | Val Loss: 0.5210 | Val Acc: 82.86% | Test Acc: 81.98%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 64.79it/s]
# Epoch 20 | Train Loss: 0.3789 | Val Loss: 0.5137 | Val Acc: 83.60% | Test Acc: 82.49%
# Epoch 21 | Train Loss: 0.3748 | Val Loss: 0.4665 | Val Acc: 84.38% | Test Acc: 83.10%
# Epoch 22 | Train Loss: 0.3672 | Val Loss: 0.4780 | Val Acc: 83.48% | Test Acc: 83.35%
# Epoch 23 | Train Loss: 0.3594 | Val Loss: 0.6070 | Val Acc: 80.40% | Test Acc: 80.39%
# Epoch 24 | Train Loss: 0.3556 | Val Loss: 0.6468 | Val Acc: 80.84% | Test Acc: 79.85%
# Epoch 25 | Train Loss: 0.3560 | Val Loss: 0.4964 | Val Acc: 83.40% | Test Acc: 82.79%
# Epoch 26 | Train Loss: 0.3500 | Val Loss: 0.4894 | Val Acc: 83.80% | Test Acc: 83.15%
# Epoch 27 | Train Loss: 0.3452 | Val Loss: 0.4750 | Val Acc: 84.32% | Test Acc: 83.21%
# Epoch 28 | Train Loss: 0.3442 | Val Loss: 0.4570 | Val Acc: 84.88% | Test Acc: 83.95%
# Epoch 29 | Train Loss: 0.3421 | Val Loss: 0.6338 | Val Acc: 80.32% | Test Acc: 79.47%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 66.20it/s]
# Epoch 30 | Train Loss: 0.3439 | Val Loss: 0.4472 | Val Acc: 85.42% | Test Acc: 84.42%
# Epoch 31 | Train Loss: 0.3331 | Val Loss: 0.4259 | Val Acc: 85.94% | Test Acc: 84.90%
# Epoch 32 | Train Loss: 0.3368 | Val Loss: 0.4412 | Val Acc: 85.98% | Test Acc: 85.00%
# Epoch 33 | Train Loss: 0.3396 | Val Loss: 0.4657 | Val Acc: 84.56% | Test Acc: 83.91%
# Epoch 34 | Train Loss: 0.3336 | Val Loss: 0.4418 | Val Acc: 85.38% | Test Acc: 84.73%
# Epoch 35 | Train Loss: 0.3288 | Val Loss: 0.4221 | Val Acc: 85.84% | Test Acc: 85.26%
# Epoch 36 | Train Loss: 0.3296 | Val Loss: 0.5821 | Val Acc: 81.90% | Test Acc: 80.16%
# Epoch 37 | Train Loss: 0.3289 | Val Loss: 0.5006 | Val Acc: 84.06% | Test Acc: 83.40%
# Epoch 38 | Train Loss: 0.3263 | Val Loss: 0.4755 | Val Acc: 84.46% | Test Acc: 83.68%
# Epoch 39 | Train Loss: 0.3280 | Val Loss: 0.4947 | Val Acc: 84.14% | Test Acc: 83.32%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 62.44it/s]
# Epoch 40 | Train Loss: 0.3270 | Val Loss: 0.4582 | Val Acc: 85.10% | Test Acc: 84.54%
# Epoch 41 | Train Loss: 0.3227 | Val Loss: 0.4973 | Val Acc: 84.26% | Test Acc: 84.16%
# Epoch 42 | Train Loss: 0.3234 | Val Loss: 0.4526 | Val Acc: 84.98% | Test Acc: 84.01%
# Epoch 43 | Train Loss: 0.3222 | Val Loss: 0.4587 | Val Acc: 85.28% | Test Acc: 83.68%
# Epoch 44 | Train Loss: 0.3203 | Val Loss: 0.4352 | Val Acc: 86.24% | Test Acc: 84.50%
# Epoch 45 | Train Loss: 0.3177 | Val Loss: 0.4919 | Val Acc: 84.28% | Test Acc: 83.84%
# Epoch 46 | Train Loss: 0.3232 | Val Loss: 0.4358 | Val Acc: 85.68% | Test Acc: 84.46%
# Epoch 47 | Train Loss: 0.3188 | Val Loss: 0.4856 | Val Acc: 84.88% | Test Acc: 83.92%
# Epoch 48 | Train Loss: 0.3125 | Val Loss: 0.4342 | Val Acc: 85.86% | Test Acc: 85.02%
# Epoch 49 | Train Loss: 0.3215 | Val Loss: 0.4222 | Val Acc: 86.38% | Test Acc: 84.97%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 66.60it/s]
# Epoch 50 | Train Loss: 0.3146 | Val Loss: 0.5600 | Val Acc: 83.02% | Test Acc: 82.55%
# Epoch 51 | Train Loss: 0.3172 | Val Loss: 0.4828 | Val Acc: 84.78% | Test Acc: 83.73%
# Epoch 52 | Train Loss: 0.3124 | Val Loss: 0.4466 | Val Acc: 85.50% | Test Acc: 84.82%
# Epoch 53 | Train Loss: 0.3113 | Val Loss: 0.4267 | Val Acc: 86.04% | Test Acc: 85.48%
# Epoch 54 | Train Loss: 0.3121 | Val Loss: 0.4440 | Val Acc: 85.78% | Test Acc: 84.66%
# Epoch 55 | Train Loss: 0.3153 | Val Loss: 0.4822 | Val Acc: 84.28% | Test Acc: 83.68%
# Epoch 56 | Train Loss: 0.3140 | Val Loss: 0.4282 | Val Acc: 86.02% | Test Acc: 84.80%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3118 | Val Loss: 0.4745 | Val Acc: 85.04% | Test Acc: 83.94%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2666 | Val Loss: 0.3613 | Val Acc: 88.32% | Test Acc: 87.28%
# Epoch 59 | Train Loss: 0.2521 | Val Loss: 0.3580 | Val Acc: 88.48% | Test Acc: 87.18%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 60.29it/s]
# Epoch 60 | Train Loss: 0.2458 | Val Loss: 0.3595 | Val Acc: 88.20% | Test Acc: 87.24%
# Epoch 61 | Train Loss: 0.2420 | Val Loss: 0.3583 | Val Acc: 88.38% | Test Acc: 87.07%
# Epoch 62 | Train Loss: 0.2408 | Val Loss: 0.3599 | Val Acc: 88.34% | Test Acc: 87.23%
# Epoch 63 | Train Loss: 0.2381 | Val Loss: 0.3597 | Val Acc: 88.38% | Test Acc: 87.48%
# Epoch 64 | Train Loss: 0.2397 | Val Loss: 0.3611 | Val Acc: 88.26% | Test Acc: 87.44%
# Epoch 65 | Train Loss: 0.2310 | Val Loss: 0.3578 | Val Acc: 88.54% | Test Acc: 87.56%
# Epoch 66 | Train Loss: 0.2325 | Val Loss: 0.3561 | Val Acc: 88.44% | Test Acc: 87.33%
# Epoch 67 | Train Loss: 0.2308 | Val Loss: 0.3575 | Val Acc: 88.72% | Test Acc: 87.45%
# Epoch 68 | Train Loss: 0.2298 | Val Loss: 0.3614 | Val Acc: 88.10% | Test Acc: 87.31%
# Epoch 69 | Train Loss: 0.2283 | Val Loss: 0.3572 | Val Acc: 88.20% | Test Acc: 87.49%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 59.79it/s]
# Epoch 70 | Train Loss: 0.2300 | Val Loss: 0.3580 | Val Acc: 88.42% | Test Acc: 87.50%
# Epoch 71 | Train Loss: 0.2263 | Val Loss: 0.3549 | Val Acc: 88.52% | Test Acc: 87.61%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.2243 | Val Loss: 0.3538 | Val Acc: 88.54% | Test Acc: 87.65%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.2242 | Val Loss: 0.3541 | Val Acc: 88.26% | Test Acc: 87.75%
# Epoch 74 | Train Loss: 0.2254 | Val Loss: 0.3526 | Val Acc: 88.40% | Test Acc: 87.60%
# Epoch 75 | Train Loss: 0.2255 | Val Loss: 0.3540 | Val Acc: 88.30% | Test Acc: 87.55%
# Epoch 76 | Train Loss: 0.2237 | Val Loss: 0.3530 | Val Acc: 88.36% | Test Acc: 87.62%
# Epoch 77 | Train Loss: 0.2225 | Val Loss: 0.3554 | Val Acc: 88.54% | Test Acc: 87.55%
# Epoch 78 | Train Loss: 0.2258 | Val Loss: 0.3543 | Val Acc: 88.50% | Test Acc: 87.65%
# Epoch 79 | Train Loss: 0.2178 | Val Loss: 0.3521 | Val Acc: 88.44% | Test Acc: 87.49%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 62.80it/s]
# Epoch 80 | Train Loss: 0.2225 | Val Loss: 0.3542 | Val Acc: 88.38% | Test Acc: 87.80%
# Epoch 81 | Train Loss: 0.2198 | Val Loss: 0.3529 | Val Acc: 88.54% | Test Acc: 87.63%
# Epoch 82 | Train Loss: 0.2194 | Val Loss: 0.3535 | Val Acc: 88.30% | Test Acc: 87.52%
# Epoch 83 | Train Loss: 0.2206 | Val Loss: 0.3564 | Val Acc: 88.30% | Test Acc: 87.55%
#    [Tracker] 🚩 Early Stop Condition at Iter 29568 (Epoch 84, Test Acc: 87.38%)
# Epoch 84 | Train Loss: 0.2201 | Val Loss: 0.3548 | Val Acc: 88.34% | Test Acc: 87.38%
# Epoch 85 | Train Loss: 0.2193 | Val Loss: 0.3547 | Val Acc: 88.36% | Test Acc: 87.43%
# Epoch 86 | Train Loss: 0.2219 | Val Loss: 0.3549 | Val Acc: 88.34% | Test Acc: 87.59%
#
# Round 14 Results:
#   Test Accuracy: 87.59%
#   Remaining Parameters: 13,799.0 (5.12%)
#
# ======================================================================
# Round 15/15
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.0919 | Val Loss: 1.7731 | Val Acc: 34.24% | Test Acc: 35.01%
# Epoch 02 | Train Loss: 1.6477 | Val Loss: 1.5553 | Val Acc: 43.56% | Test Acc: 43.42%
# Epoch 03 | Train Loss: 1.4477 | Val Loss: 1.3407 | Val Acc: 51.20% | Test Acc: 51.68%
# Epoch 04 | Train Loss: 1.2727 | Val Loss: 1.1707 | Val Acc: 58.98% | Test Acc: 58.36%
# Epoch 05 | Train Loss: 1.1322 | Val Loss: 1.0488 | Val Acc: 62.80% | Test Acc: 62.59%
# Epoch 06 | Train Loss: 1.0022 | Val Loss: 0.9063 | Val Acc: 68.40% | Test Acc: 67.94%
# Epoch 07 | Train Loss: 0.8817 | Val Loss: 0.7948 | Val Acc: 72.54% | Test Acc: 71.93%
# Epoch 08 | Train Loss: 0.7846 | Val Loss: 0.7371 | Val Acc: 74.38% | Test Acc: 74.33%
# Epoch 09 | Train Loss: 0.7018 | Val Loss: 0.6762 | Val Acc: 76.78% | Test Acc: 76.24%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 61.94it/s]
# Epoch 10 | Train Loss: 0.6400 | Val Loss: 0.6232 | Val Acc: 78.46% | Test Acc: 78.17%
# Epoch 11 | Train Loss: 0.5940 | Val Loss: 0.5854 | Val Acc: 79.60% | Test Acc: 79.53%
# Epoch 12 | Train Loss: 0.5541 | Val Loss: 0.6067 | Val Acc: 78.82% | Test Acc: 78.78%
# Epoch 13 | Train Loss: 0.5278 | Val Loss: 0.5631 | Val Acc: 80.86% | Test Acc: 80.56%
# Epoch 14 | Train Loss: 0.5009 | Val Loss: 0.5560 | Val Acc: 81.12% | Test Acc: 81.27%
# Epoch 15 | Train Loss: 0.4802 | Val Loss: 0.5480 | Val Acc: 80.62% | Test Acc: 80.86%
# Epoch 16 | Train Loss: 0.4651 | Val Loss: 0.5403 | Val Acc: 81.60% | Test Acc: 81.17%
# Epoch 17 | Train Loss: 0.4560 | Val Loss: 0.5050 | Val Acc: 82.68% | Test Acc: 82.13%
# Epoch 18 | Train Loss: 0.4416 | Val Loss: 0.4722 | Val Acc: 84.58% | Test Acc: 83.47%
# Epoch 19 | Train Loss: 0.4300 | Val Loss: 0.6218 | Val Acc: 79.64% | Test Acc: 78.85%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 67.16it/s]
# Epoch 20 | Train Loss: 0.4226 | Val Loss: 0.4937 | Val Acc: 83.34% | Test Acc: 82.93%
# Epoch 21 | Train Loss: 0.4143 | Val Loss: 0.5900 | Val Acc: 80.24% | Test Acc: 79.81%
# Epoch 22 | Train Loss: 0.4112 | Val Loss: 0.6203 | Val Acc: 79.66% | Test Acc: 78.77%
# Epoch 23 | Train Loss: 0.4094 | Val Loss: 0.5010 | Val Acc: 82.96% | Test Acc: 82.39%
# Epoch 24 | Train Loss: 0.4029 | Val Loss: 0.5271 | Val Acc: 82.18% | Test Acc: 82.45%
# Epoch 25 | Train Loss: 0.3938 | Val Loss: 0.5207 | Val Acc: 82.68% | Test Acc: 82.31%
# Epoch 26 | Train Loss: 0.3891 | Val Loss: 0.4727 | Val Acc: 84.42% | Test Acc: 83.49%
# Epoch 27 | Train Loss: 0.3877 | Val Loss: 0.4895 | Val Acc: 83.84% | Test Acc: 83.31%
# Epoch 28 | Train Loss: 0.3895 | Val Loss: 0.5265 | Val Acc: 82.66% | Test Acc: 82.32%
# Epoch 29 | Train Loss: 0.3827 | Val Loss: 0.5111 | Val Acc: 83.36% | Test Acc: 82.14%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 62.74it/s]
# Epoch 30 | Train Loss: 0.3843 | Val Loss: 0.6216 | Val Acc: 80.88% | Test Acc: 80.12%
# Epoch 31 | Train Loss: 0.3774 | Val Loss: 0.4751 | Val Acc: 84.08% | Test Acc: 83.73%
# Epoch 32 | Train Loss: 0.3748 | Val Loss: 0.4415 | Val Acc: 84.98% | Test Acc: 84.25%
# Epoch 33 | Train Loss: 0.3701 | Val Loss: 0.5230 | Val Acc: 83.20% | Test Acc: 82.47%
# Epoch 34 | Train Loss: 0.3738 | Val Loss: 0.4996 | Val Acc: 83.30% | Test Acc: 83.06%
# Epoch 35 | Train Loss: 0.3686 | Val Loss: 0.5130 | Val Acc: 83.54% | Test Acc: 83.01%
# Epoch 36 | Train Loss: 0.3685 | Val Loss: 0.4984 | Val Acc: 83.48% | Test Acc: 82.72%
# Epoch 37 | Train Loss: 0.3657 | Val Loss: 0.4901 | Val Acc: 84.18% | Test Acc: 83.69%
# Epoch 38 | Train Loss: 0.3689 | Val Loss: 0.4880 | Val Acc: 84.34% | Test Acc: 83.32%
# Epoch 39 | Train Loss: 0.3640 | Val Loss: 0.4900 | Val Acc: 84.08% | Test Acc: 83.35%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 61.47it/s]
# Epoch 40 | Train Loss: 0.3677 | Val Loss: 0.5074 | Val Acc: 83.50% | Test Acc: 83.16%
# Epoch 41 | Train Loss: 0.3592 | Val Loss: 0.5323 | Val Acc: 83.62% | Test Acc: 83.32%
# Epoch 42 | Train Loss: 0.3626 | Val Loss: 0.5348 | Val Acc: 83.06% | Test Acc: 82.69%
# Epoch 43 | Train Loss: 0.3597 | Val Loss: 0.5158 | Val Acc: 83.04% | Test Acc: 81.67%
# Epoch 44 | Train Loss: 0.3608 | Val Loss: 0.5304 | Val Acc: 82.94% | Test Acc: 81.89%
# Epoch 45 | Train Loss: 0.3567 | Val Loss: 0.5293 | Val Acc: 82.58% | Test Acc: 82.49%
# Epoch 46 | Train Loss: 0.3556 | Val Loss: 0.4789 | Val Acc: 84.28% | Test Acc: 84.11%
# Epoch 47 | Train Loss: 0.3525 | Val Loss: 0.4407 | Val Acc: 85.42% | Test Acc: 84.94%
# Epoch 48 | Train Loss: 0.3532 | Val Loss: 0.4703 | Val Acc: 84.68% | Test Acc: 83.78%
# Epoch 49 | Train Loss: 0.3542 | Val Loss: 0.4571 | Val Acc: 84.78% | Test Acc: 84.19%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 64.39it/s]
# Epoch 50 | Train Loss: 0.3490 | Val Loss: 0.4198 | Val Acc: 86.10% | Test Acc: 85.28%
# Epoch 51 | Train Loss: 0.3544 | Val Loss: 0.4640 | Val Acc: 84.76% | Test Acc: 83.78%
# Epoch 52 | Train Loss: 0.3489 | Val Loss: 0.5012 | Val Acc: 83.56% | Test Acc: 83.01%
# Epoch 53 | Train Loss: 0.3485 | Val Loss: 0.4888 | Val Acc: 83.90% | Test Acc: 83.72%
# Epoch 54 | Train Loss: 0.3477 | Val Loss: 0.4756 | Val Acc: 84.52% | Test Acc: 83.77%
# Epoch 55 | Train Loss: 0.3463 | Val Loss: 0.5202 | Val Acc: 83.14% | Test Acc: 82.29%
# Epoch 56 | Train Loss: 0.3448 | Val Loss: 0.4698 | Val Acc: 84.60% | Test Acc: 83.78%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3484 | Val Loss: 0.4830 | Val Acc: 84.08% | Test Acc: 83.49%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.3001 | Val Loss: 0.3787 | Val Acc: 87.58% | Test Acc: 86.37%
# Epoch 59 | Train Loss: 0.2875 | Val Loss: 0.3739 | Val Acc: 87.28% | Test Acc: 86.66%
# Epoch 60/86: 100%|██████████| 352/352 [00:06<00:00, 58.67it/s]
# Epoch 60 | Train Loss: 0.2832 | Val Loss: 0.3735 | Val Acc: 87.42% | Test Acc: 86.82%
# Epoch 61 | Train Loss: 0.2786 | Val Loss: 0.3736 | Val Acc: 87.32% | Test Acc: 86.83%
# Epoch 62 | Train Loss: 0.2757 | Val Loss: 0.3699 | Val Acc: 87.60% | Test Acc: 86.92%
# Epoch 63 | Train Loss: 0.2759 | Val Loss: 0.3737 | Val Acc: 87.42% | Test Acc: 86.71%
# Epoch 64 | Train Loss: 0.2747 | Val Loss: 0.3658 | Val Acc: 87.86% | Test Acc: 87.03%
# Epoch 65 | Train Loss: 0.2710 | Val Loss: 0.3712 | Val Acc: 87.56% | Test Acc: 86.94%
# Epoch 66 | Train Loss: 0.2721 | Val Loss: 0.3724 | Val Acc: 87.48% | Test Acc: 86.97%
# Epoch 67 | Train Loss: 0.2698 | Val Loss: 0.3707 | Val Acc: 87.52% | Test Acc: 86.86%
# Epoch 68 | Train Loss: 0.2702 | Val Loss: 0.3682 | Val Acc: 87.92% | Test Acc: 86.91%
# Epoch 69 | Train Loss: 0.2681 | Val Loss: 0.3731 | Val Acc: 87.34% | Test Acc: 86.84%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 61.96it/s]
# Epoch 70 | Train Loss: 0.2701 | Val Loss: 0.3719 | Val Acc: 87.86% | Test Acc: 86.73%
# Epoch 71 | Train Loss: 0.2630 | Val Loss: 0.3756 | Val Acc: 87.76% | Test Acc: 86.84%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.2636 | Val Loss: 0.3722 | Val Acc: 87.56% | Test Acc: 86.90%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.2648 | Val Loss: 0.3724 | Val Acc: 87.70% | Test Acc: 87.05%
#    [Tracker] 🚩 Early Stop Condition at Iter 26048 (Epoch 74, Test Acc: 87.16%)
# Epoch 74 | Train Loss: 0.2626 | Val Loss: 0.3709 | Val Acc: 87.80% | Test Acc: 87.16%
# Epoch 75 | Train Loss: 0.2622 | Val Loss: 0.3722 | Val Acc: 87.74% | Test Acc: 87.04%
# Epoch 76 | Train Loss: 0.2614 | Val Loss: 0.3716 | Val Acc: 87.82% | Test Acc: 87.03%
# Epoch 77 | Train Loss: 0.2639 | Val Loss: 0.3723 | Val Acc: 87.52% | Test Acc: 87.03%
# Epoch 78 | Train Loss: 0.2645 | Val Loss: 0.3699 | Val Acc: 87.70% | Test Acc: 87.21%
# Epoch 79 | Train Loss: 0.2607 | Val Loss: 0.3712 | Val Acc: 87.70% | Test Acc: 87.22%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 63.37it/s]
# Epoch 80 | Train Loss: 0.2627 | Val Loss: 0.3717 | Val Acc: 87.72% | Test Acc: 87.07%
# Epoch 81 | Train Loss: 0.2612 | Val Loss: 0.3710 | Val Acc: 87.60% | Test Acc: 87.08%
# Epoch 82 | Train Loss: 0.2563 | Val Loss: 0.3706 | Val Acc: 87.80% | Test Acc: 87.08%
# Epoch 83 | Train Loss: 0.2610 | Val Loss: 0.3731 | Val Acc: 87.76% | Test Acc: 87.09%
# Epoch 84 | Train Loss: 0.2611 | Val Loss: 0.3699 | Val Acc: 87.76% | Test Acc: 87.09%
# Epoch 85 | Train Loss: 0.2608 | Val Loss: 0.3708 | Val Acc: 87.68% | Test Acc: 86.98%
# Epoch 86 | Train Loss: 0.2605 | Val Loss: 0.3715 | Val Acc: 87.66% | Test Acc: 86.96%
#
# Round 15 Results:
#   Test Accuracy: 86.96%
#   Remaining Parameters: 11,444.0 (4.24%)
#
# ======================================================================
# Iterative Pruning Complete!
# ======================================================================
# Saved Iterative results to: ../../results/resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904/checkpoints/iterative_results_resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904.pth

# %%
# --- Data Aggregation ---
# Assuming all trials have the same number of rounds and pruning rates
n_rounds = len(all_trials_iterative[0])
n_trials = len(all_trials_iterative)

# Initialize lists to store aggregated data
rounds = []
remaining_params_pct = []
remaining_params = []
acc_means = []
acc_stds = []

for r_idx in range(n_rounds):
    # Extract data for this specific round across all trials
    # Structure: [Trial1_RoundX, Trial2_RoundX, Trial3_RoundX]
    round_data = [trial[r_idx] for trial in all_trials_iterative]
    
    # Static data (same for all trials)
    rounds.append(round_data[0]['round'])
    remaining_params_pct.append(round_data[0]['remaining_params_pct'])
    remaining_params.append(round_data[0]['remaining_params'])
    
    # Variable data (Accuracy) - Calculate Mean and Std
    accuracies = [r['test_accuracy'] for r in round_data]
    acc_means.append(np.mean(accuracies))
    acc_stds.append(np.std(accuracies))

# --- Print Summary Table ---
print("\n" + "="*80)
print(f"Pruning Results Summary ({n_trials} Trials Aggregated)")
print("="*80)
print(f"{'Round':<8} {'Params %':<12} {'Params':<15} {'Mean Acc %':<12} {'Std Dev':<10}")
print("-"*80)

for i in range(n_rounds):
    print(f"{rounds[i]:<8} {remaining_params_pct[i]:<12.2f} "
          f"{remaining_params[i]:<15,} {acc_means[i]:<12.2f} ± {acc_stds[i]:<10.2f}")
print("="*80)
# Out:
# ================================================================================
# Pruning Results Summary (3 Trials Aggregated)
# ================================================================================
# Round    Params %     Params          Mean Acc %   Std Dev
# --------------------------------------------------------------------------------
# 1        80.15        216,183.0       88.23        ± 0.10
# 2        64.27        173,351.0       88.89        ± 0.13
# 3        51.57        139,086.0       89.04        ± 0.15
# 4        41.40        111,674.0       89.03        ± 0.06
# 5        33.27        89,744.0        89.20        ± 0.06
# 6        26.77        72,200.0        89.26        ± 0.02
# 7        21.56        58,165.0        89.24        ± 0.12
# 8        17.40        46,937.0        89.17        ± 0.09
# 9        14.07        37,955.0        89.00        ± 0.11
# 10       11.41        30,769.0        88.71        ± 0.05
# 11       9.28         25,020.0        88.71        ± 0.07
# 12       7.57         20,421.0        88.29        ± 0.30
# 13       6.21         16,742.0        87.92        ± 0.20
# 14       5.12         13,799.0        87.47        ± 0.20
# 15       4.24         11,444.0        87.03        ± 0.06
# ================================================================================

# %%
# --- Visualize with Error Bars ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Convert to numpy arrays for plotting
x_pct = np.array(remaining_params_pct)
y_mean = np.array(acc_means)
y_std = np.array(acc_stds)

# Plot 1: Accuracy vs Sparsity (Mean + Std Shadow)
# Plot the mean line
ax1.plot(x_pct, y_mean, 'o-', linewidth=2, markersize=6, label='Mean Accuracy')

# Plot the shadow (Mean +/- Std) 

ax1.fill_between(x_pct, y_mean - y_std, y_mean + y_std, alpha=0.2, color='blue', label='Std Dev range')

# Baseline Handling: Calculate mean baseline from Round 1 (0% pruned)
baseline_mean = y_mean[0] 
ax1.axhline(y=baseline_mean, color='r', linestyle='--', label=f'Mean Baseline ({baseline_mean:.2f}%)', alpha=0.7)

ax1.set_xlabel('Percent of Weights Remaining (%)', fontsize=12)
ax1.set_ylabel('Test Accuracy (%)', fontsize=12)
ax1.set_title(f'Test Accuracy vs Sparsity ({n_trials} Trials)', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)
ax1.invert_xaxis()  # 100% -> 0%

# Plot 2: Params Reduction (Deterministic, no error bars needed)
ax2.plot(rounds, remaining_params, 'o-', linewidth=2, markersize=8, color='orange')
ax2.set_xlabel('Pruning Round', fontsize=12)
ax2.set_ylabel('Parameters Remaining', fontsize=12)
ax2.set_title('Parameters Reduction', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.3)
ax2.set_yscale('log') 

plt.tight_layout()

# Save Pruning Figure
# Ensure fig_dir exists in your context
pruning_fig_path = os.path.join(fig_dir, f"Iterative_pruning_results_multi_trial_{run_id}.png")
plt.savefig(pruning_fig_path, dpi=150)
plt.show()

print(f"Pruning figure saved to: {pruning_fig_path}")
# Out:
# Pruning figure saved to: ../../results/resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904/figures/Iterative_pruning_results_multi_trial_resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904.png

# %%
import matplotlib.pyplot as plt
import os
import numpy as np

# --- Visualize with Error Bars (Vertical Lines) ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Convert to numpy arrays for plotting
x_pct = np.array(remaining_params_pct)
y_mean = np.array(acc_means)
y_std = np.array(acc_stds)

# ==============================================================================
# Plot 1: Accuracy vs Sparsity (Using Error Bars)
# ==============================================================================

# ax1.errorbar 是关键函数
# x, y: 坐标
# yerr: 误差范围 (这里用标准差)
# fmt='o-': 样式 (圆点 + 实线)
# capsize=4: 误差棒顶部和底部的小横杠宽度 (让它看起来更像论文)
# elinewidth=1.5: 误差棒的线条粗细
ax1.errorbar(x_pct, y_mean, yerr=y_std, fmt='o-', 
             linewidth=2, markersize=6, capsize=4, elinewidth=1.5,
             color='tab:blue', ecolor='tab:blue', label='Mean Accuracy')

# Baseline Handling
baseline_mean = y_mean[0] 
ax1.axhline(y=baseline_mean, color='r', linestyle='--', label=f'Mean Baseline ({baseline_mean:.2f}%)', alpha=0.7)

ax1.set_xlabel('Percent of Weights Remaining (%)', fontsize=12)
ax1.set_ylabel('Test Accuracy (%)', fontsize=12)
ax1.set_title(f'Test Accuracy vs Sparsity ({n_trials} Trials)', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)
ax1.invert_xaxis()  # 100% -> 0% (Standard for pruning plots)

# ==============================================================================
# Plot 2: Params Reduction (No changes needed)
# ==============================================================================
ax2.plot(rounds, remaining_params, 'o-', linewidth=2, markersize=8, color='orange')
ax2.set_xlabel('Pruning Round', fontsize=12)
ax2.set_ylabel('Parameters Remaining', fontsize=12)
ax2.set_title('Parameters Reduction', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.3)
ax2.set_yscale('log') 

plt.tight_layout()

# Save Pruning Figure
if 'fig_dir' not in globals(): fig_dir = "." # Fallback if fig_dir is not defined
pruning_fig_path = os.path.join(fig_dir, f"Iterative_pruning_results_multi_trial_errorbars_{run_id}.png")
plt.savefig(pruning_fig_path, dpi=300) # Increased DPI for better quality
plt.show()

print(f"Pruning figure saved to: {pruning_fig_path}")
# Out:
# Pruning figure saved to: ../../results/resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904/figures/Iterative_pruning_results_multi_trial_errorbars_resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904.png

# %%
# --- Identify Winning Tickets (Based on Mean Accuracy) ---

# Define Baseline: Mean accuracy of the unpruned model (Round 1)
baseline_mean_acc = acc_means[0] 

winning_tickets_indices = []

# Loop through aggregated stats
for i in range(n_rounds):
    # Criteria: Mean Accuracy >= 98% of Mean Baseline
    if acc_means[i] >= baseline_mean_acc * 0.98:
        winning_tickets_indices.append(i)

print(f"\n{'='*70}")
print(f"Winning Ticket Analysis (Based on {n_trials} Trials Mean)")
print(f"{'='*70}")
print(f"Mean Baseline Accuracy: {baseline_mean_acc:.2f}%")
print(f"\nWinning Tickets (Mean Acc >= {baseline_mean_acc * 0.98:.2f}%):")
print(f"{'Round':<8} {'Sparsity %':<12} {'Params':<15} {'Mean Acc %':<12}")
print("-"*70)

best_ticket_idx = -1
min_params = float('inf')

for idx in winning_tickets_indices:
    sparsity = 100 - remaining_params_pct[idx]
    print(f"{rounds[idx]:<8} {sparsity:<12.1f} "
          f"{remaining_params[idx]:<15,} {acc_means[idx]:<12.2f}")
    
    # Track the best ticket (most sparse)
    if remaining_params[idx] < min_params:
        min_params = remaining_params[idx]
        best_ticket_idx = idx

if best_ticket_idx != -1:
    print(f"\nBest Winning Ticket (Most Sparse):")
    print(f"  Round: {rounds[best_ticket_idx]}")
    print(f"  Sparsity: {100 - remaining_params_pct[best_ticket_idx]:.1f}%")
    print(f"  Parameters: {remaining_params[best_ticket_idx]:,}")
    print(f"  Mean Accuracy: {acc_means[best_ticket_idx]:.2f}%")
# Out:
# ======================================================================
# Winning Ticket Analysis (Based on 3 Trials Mean)
# ======================================================================
# Mean Baseline Accuracy: 88.23%
#
# Winning Tickets (Mean Acc >= 86.47%):
# Round    Sparsity %   Params          Mean Acc %
# ----------------------------------------------------------------------
# 1        19.8         216,183.0       88.23
# 2        35.7         173,351.0       88.89
# 3        48.4         139,086.0       89.04
# 4        58.6         111,674.0       89.03
# 5        66.7         89,744.0        89.20
# 6        73.2         72,200.0        89.26
# 7        78.4         58,165.0        89.24
# 8        82.6         46,937.0        89.17
# 9        85.9         37,955.0        89.00
# 10       88.6         30,769.0        88.71
# 11       90.7         25,020.0        88.71
# 12       92.4         20,421.0        88.29
# 13       93.8         16,742.0        87.92
# 14       94.9         13,799.0        87.47
# 15       95.8         11,444.0        87.03
#
# Best Winning Ticket (Most Sparse):
#   Round: 15
#   Sparsity: 95.8%
#   Parameters: 11,444.0
#   Mean Accuracy: 87.03%

# %% [markdown]
# ### 5.2 Random Init

# %%
# ============================================================================
# PHASE 2: Random Reinitialization (Control)
# ============================================================================
print(f"\n{'='*40}")
print("PHASE 2: Random Reinitialization Experiments")
print(f"{'='*40}")

all_trials_random = []

for trial_idx, seed in enumerate(SEEDS):
    print(f"\n>>> Starting Random Init Trial {trial_idx + 1}/{len(SEEDS)} | Seed {seed}")
    
    # 1. Set seed (Ensure data shuffle matches Phase 1)
    set_seed(seed)
    
    # 2. Prepare Data
    train_loader, val_loader, test_loader = get_dataloaders(seed)
    
    # 3. Retrieve Masks from Phase 1
    current_iter_results = all_trials_iterative[trial_idx]
    
    trial_random_results = []
    
    # 4. Create a fresh base model for re-init
    base_model_rnd = ResNet20_CIFAR10().to(device)
    
    # 5. Iterate through rounds using Phase 1 masks
    for res in current_iter_results:
        mask = res['mask']
        if mask is None: continue # Skip Round 0 (no pruning)
        
        print(f"   -> Random Reinit for Sparsity: {res['remaining_params_pct']:.2f}%")
        
        # Run Random Reinit Pruning
        # [CRITICAL UPDATE]: Passing 'config' so the correct scheduler is used
        rand_res = random_reinit_pruning(
            model=copy.deepcopy(base_model_rnd),
            train_loader=train_loader,
            test_loader=test_loader,
            val_loader=val_loader,
            optimizer_class=torch.optim.SGD,
            optimizer_kwargs={'lr': lr, 'momentum': 0.9, 'weight_decay': 1e-4},
            device=device,
            mask=mask,
            # Pass the same config structure you used in Phase 1
            config=pruning_config,
            epochs=epochs_per_round,
            verbose=True 
        )
        
        # Add metadata for plotting
        rand_res['remaining_params_pct'] = res['remaining_params_pct']
        rand_res['round'] = res['round']
        trial_random_results.append(rand_res)
        
    all_trials_random.append(trial_random_results)

# 6. Save Random Init Results separately
random_save_path = os.path.join(ckpt_dir, f"random_init_results_{run_id}.pth")
torch.save({
    'trials': all_trials_random,
    'seeds': SEEDS,
    'config': pruning_config,
    'lr': lr
}, random_save_path)
print(f"Saved Random Init results to: {random_save_path}")
# Out:
# ========================================
# PHASE 2: Random Reinitialization Experiments
# ========================================
#
# >>> Starting Random Init Trial 1/3 | Seed 42
#
# Seed set to: 42
#    -> Random Reinit for Sparsity: 80.15%
#
# ======================================================================
# Starting Random Reinit Control Experiment
# Sparsity Level: 80.15% weights remaining
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# Warmup strategy: linear_20k
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.1629 | Val Loss: 1.9541 | Val Acc: 27.96% | Test Acc: 28.68%
# Epoch 02 | Train Loss: 1.8568 | Val Loss: 1.7440 | Val Acc: 35.48% | Test Acc: 36.45%
# Epoch 03 | Train Loss: 1.6992 | Val Loss: 1.6269 | Val Acc: 40.08% | Test Acc: 39.90%
# Epoch 04 | Train Loss: 1.5854 | Val Loss: 1.5259 | Val Acc: 43.72% | Test Acc: 44.15%
# Epoch 05 | Train Loss: 1.4944 | Val Loss: 1.5014 | Val Acc: 45.96% | Test Acc: 46.00%
# Epoch 06 | Train Loss: 1.3969 | Val Loss: 1.3559 | Val Acc: 49.36% | Test Acc: 50.64%
# Epoch 07 | Train Loss: 1.3070 | Val Loss: 1.2623 | Val Acc: 54.48% | Test Acc: 54.56%
# Epoch 08 | Train Loss: 1.2281 | Val Loss: 1.3511 | Val Acc: 53.36% | Test Acc: 54.29%
# Epoch 09 | Train Loss: 1.1543 | Val Loss: 1.1596 | Val Acc: 58.92% | Test Acc: 59.19%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 60.72it/s]
# Epoch 10 | Train Loss: 1.0958 | Val Loss: 1.1150 | Val Acc: 60.50% | Test Acc: 61.12%
# Epoch 11 | Train Loss: 1.0397 | Val Loss: 1.1548 | Val Acc: 59.46% | Test Acc: 59.89%
# Epoch 12 | Train Loss: 0.9837 | Val Loss: 1.1177 | Val Acc: 61.94% | Test Acc: 62.91%
# Epoch 13 | Train Loss: 0.9443 | Val Loss: 0.9993 | Val Acc: 65.24% | Test Acc: 65.84%
# Epoch 14 | Train Loss: 0.8943 | Val Loss: 0.9602 | Val Acc: 66.62% | Test Acc: 66.63%
# Epoch 15 | Train Loss: 0.8507 | Val Loss: 0.8618 | Val Acc: 69.06% | Test Acc: 70.40%
# Epoch 16 | Train Loss: 0.8097 | Val Loss: 0.9878 | Val Acc: 66.80% | Test Acc: 66.89%
# Epoch 17 | Train Loss: 0.7792 | Val Loss: 0.8638 | Val Acc: 71.14% | Test Acc: 70.86%
# Epoch 18 | Train Loss: 0.7482 | Val Loss: 0.8898 | Val Acc: 69.78% | Test Acc: 69.84%
# Epoch 19 | Train Loss: 0.7146 | Val Loss: 0.8245 | Val Acc: 71.88% | Test Acc: 72.45%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 64.89it/s]
# Epoch 20 | Train Loss: 0.6900 | Val Loss: 0.8680 | Val Acc: 71.62% | Test Acc: 71.66%
# Epoch 21 | Train Loss: 0.6627 | Val Loss: 0.9568 | Val Acc: 69.94% | Test Acc: 69.32%
# Epoch 22 | Train Loss: 0.6483 | Val Loss: 0.8057 | Val Acc: 74.08% | Test Acc: 73.44%
# Epoch 23 | Train Loss: 0.6254 | Val Loss: 0.7067 | Val Acc: 75.82% | Test Acc: 75.80%
# Epoch 24 | Train Loss: 0.6054 | Val Loss: 0.7086 | Val Acc: 76.10% | Test Acc: 76.34%
# Epoch 25 | Train Loss: 0.5863 | Val Loss: 0.7525 | Val Acc: 75.24% | Test Acc: 75.96%
# Epoch 26 | Train Loss: 0.5705 | Val Loss: 0.8069 | Val Acc: 73.60% | Test Acc: 73.19%
# Epoch 27 | Train Loss: 0.5499 | Val Loss: 0.7010 | Val Acc: 77.02% | Test Acc: 76.85%
# Epoch 28 | Train Loss: 0.5434 | Val Loss: 0.6179 | Val Acc: 79.02% | Test Acc: 79.11%
# Epoch 29 | Train Loss: 0.5244 | Val Loss: 0.7363 | Val Acc: 75.68% | Test Acc: 75.60%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 64.10it/s]
# Epoch 30 | Train Loss: 0.5120 | Val Loss: 0.7238 | Val Acc: 76.86% | Test Acc: 76.28%
# Epoch 31 | Train Loss: 0.5050 | Val Loss: 0.6495 | Val Acc: 78.74% | Test Acc: 79.16%
# Epoch 32 | Train Loss: 0.4872 | Val Loss: 0.6800 | Val Acc: 77.48% | Test Acc: 77.59%
# Epoch 33 | Train Loss: 0.4799 | Val Loss: 0.6346 | Val Acc: 79.34% | Test Acc: 79.27%
# Epoch 34 | Train Loss: 0.4666 | Val Loss: 0.6441 | Val Acc: 79.32% | Test Acc: 78.98%
# Epoch 35 | Train Loss: 0.4584 | Val Loss: 0.7240 | Val Acc: 77.78% | Test Acc: 77.13%
# Epoch 36 | Train Loss: 0.4500 | Val Loss: 0.6781 | Val Acc: 78.34% | Test Acc: 77.64%
# Epoch 37 | Train Loss: 0.4409 | Val Loss: 0.7828 | Val Acc: 76.02% | Test Acc: 75.65%
# Epoch 38 | Train Loss: 0.4294 | Val Loss: 0.6637 | Val Acc: 78.02% | Test Acc: 78.49%
# Epoch 39 | Train Loss: 0.4250 | Val Loss: 0.5481 | Val Acc: 82.34% | Test Acc: 82.07%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 61.06it/s]
# Epoch 40 | Train Loss: 0.4146 | Val Loss: 0.6440 | Val Acc: 80.22% | Test Acc: 80.21%
# Epoch 41 | Train Loss: 0.4091 | Val Loss: 0.6754 | Val Acc: 79.50% | Test Acc: 79.63%
# Epoch 42 | Train Loss: 0.3966 | Val Loss: 0.5550 | Val Acc: 82.10% | Test Acc: 81.24%
# Epoch 43 | Train Loss: 0.3938 | Val Loss: 0.5664 | Val Acc: 81.40% | Test Acc: 81.32%
# Epoch 44 | Train Loss: 0.3837 | Val Loss: 0.5830 | Val Acc: 80.92% | Test Acc: 81.13%
# Epoch 45 | Train Loss: 0.3779 | Val Loss: 0.5529 | Val Acc: 82.98% | Test Acc: 82.69%
# Epoch 46 | Train Loss: 0.3745 | Val Loss: 0.7360 | Val Acc: 78.60% | Test Acc: 77.67%
# Epoch 47 | Train Loss: 0.3665 | Val Loss: 0.5389 | Val Acc: 82.98% | Test Acc: 82.39%
# Epoch 48 | Train Loss: 0.3548 | Val Loss: 0.5792 | Val Acc: 81.18% | Test Acc: 81.55%
# Epoch 49 | Train Loss: 0.3549 | Val Loss: 0.5809 | Val Acc: 82.02% | Test Acc: 81.30%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 59.55it/s]
# Epoch 50 | Train Loss: 0.3451 | Val Loss: 0.5622 | Val Acc: 82.34% | Test Acc: 81.83%
# Epoch 51 | Train Loss: 0.3431 | Val Loss: 0.6901 | Val Acc: 79.26% | Test Acc: 79.98%
# Epoch 52 | Train Loss: 0.3406 | Val Loss: 0.5078 | Val Acc: 83.90% | Test Acc: 83.24%
# Epoch 53 | Train Loss: 0.3353 | Val Loss: 0.5080 | Val Acc: 83.72% | Test Acc: 83.63%
# Epoch 54 | Train Loss: 0.3238 | Val Loss: 0.5288 | Val Acc: 83.06% | Test Acc: 82.73%
# Epoch 55 | Train Loss: 0.3245 | Val Loss: 0.6906 | Val Acc: 80.48% | Test Acc: 79.34%
# Epoch 56 | Train Loss: 0.3182 | Val Loss: 0.6064 | Val Acc: 81.22% | Test Acc: 81.99%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3100 | Val Loss: 0.5476 | Val Acc: 83.34% | Test Acc: 83.09%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2427 | Val Loss: 0.3869 | Val Acc: 87.84% | Test Acc: 87.24%
# Epoch 59 | Train Loss: 0.2224 | Val Loss: 0.3876 | Val Acc: 87.72% | Test Acc: 87.33%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 62.77it/s]
# Epoch 60 | Train Loss: 0.2153 | Val Loss: 0.3854 | Val Acc: 88.20% | Test Acc: 87.68%
# Epoch 61 | Train Loss: 0.2093 | Val Loss: 0.3823 | Val Acc: 88.16% | Test Acc: 87.61%
# Epoch 62 | Train Loss: 0.2066 | Val Loss: 0.3879 | Val Acc: 87.92% | Test Acc: 87.72%
# Epoch 63 | Train Loss: 0.2032 | Val Loss: 0.3890 | Val Acc: 87.92% | Test Acc: 87.63%
# Epoch 64 | Train Loss: 0.2008 | Val Loss: 0.3815 | Val Acc: 88.38% | Test Acc: 87.70%
# Epoch 65 | Train Loss: 0.1959 | Val Loss: 0.3856 | Val Acc: 88.42% | Test Acc: 87.90%
# Epoch 66 | Train Loss: 0.1947 | Val Loss: 0.3895 | Val Acc: 87.98% | Test Acc: 87.56%
# Epoch 67 | Train Loss: 0.1925 | Val Loss: 0.3882 | Val Acc: 88.40% | Test Acc: 87.82%
# Epoch 68 | Train Loss: 0.1911 | Val Loss: 0.3927 | Val Acc: 88.12% | Test Acc: 87.54%
# Epoch 69 | Train Loss: 0.1898 | Val Loss: 0.3829 | Val Acc: 88.50% | Test Acc: 87.95%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 63.80it/s]
# Epoch 70 | Train Loss: 0.1829 | Val Loss: 0.3858 | Val Acc: 88.20% | Test Acc: 87.76%
#    [Tracker] 🚩 Early Stop Condition at Iter 24992 (Epoch 71, Test Acc: 87.76%)
# Epoch 71 | Train Loss: 0.1875 | Val Loss: 0.3912 | Val Acc: 88.08% | Test Acc: 87.76%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.1778 | Val Loss: 0.3859 | Val Acc: 88.28% | Test Acc: 87.87%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.1748 | Val Loss: 0.3856 | Val Acc: 88.34% | Test Acc: 88.06%
# Epoch 74 | Train Loss: 0.1753 | Val Loss: 0.3869 | Val Acc: 88.26% | Test Acc: 88.04%
# Epoch 75 | Train Loss: 0.1731 | Val Loss: 0.3873 | Val Acc: 88.20% | Test Acc: 88.05%
# Epoch 76 | Train Loss: 0.1779 | Val Loss: 0.3881 | Val Acc: 88.28% | Test Acc: 87.97%
# Epoch 77 | Train Loss: 0.1761 | Val Loss: 0.3881 | Val Acc: 88.22% | Test Acc: 88.12%
# Epoch 78 | Train Loss: 0.1742 | Val Loss: 0.3881 | Val Acc: 88.36% | Test Acc: 88.02%
# Epoch 79 | Train Loss: 0.1746 | Val Loss: 0.3864 | Val Acc: 88.18% | Test Acc: 88.07%
# Epoch 80/86: 100%|██████████| 352/352 [00:06<00:00, 57.21it/s]
# Epoch 80 | Train Loss: 0.1751 | Val Loss: 0.3874 | Val Acc: 88.46% | Test Acc: 88.06%
# Epoch 81 | Train Loss: 0.1751 | Val Loss: 0.3887 | Val Acc: 88.38% | Test Acc: 87.95%
# Epoch 82 | Train Loss: 0.1741 | Val Loss: 0.3878 | Val Acc: 88.18% | Test Acc: 88.04%
# Epoch 83 | Train Loss: 0.1746 | Val Loss: 0.3886 | Val Acc: 88.02% | Test Acc: 88.17%
# Epoch 84 | Train Loss: 0.1702 | Val Loss: 0.3869 | Val Acc: 88.24% | Test Acc: 88.08%
# Epoch 85 | Train Loss: 0.1737 | Val Loss: 0.3873 | Val Acc: 88.24% | Test Acc: 87.99%
# Epoch 86 | Train Loss: 0.1698 | Val Loss: 0.3878 | Val Acc: 88.42% | Test Acc: 88.13%
#
# Random Reinit Result:
#   Test Accuracy: 88.13%
#   Remaining Params: 80.15%
# ======================================================================
#
#    -> Random Reinit for Sparsity: 64.27%
#
# ======================================================================
# Starting Random Reinit Control Experiment
# Sparsity Level: 64.27% weights remaining
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# Warmup strategy: linear_20k
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.2492 | Val Loss: 1.9870 | Val Acc: 25.96% | Test Acc: 25.48%
# Epoch 02 | Train Loss: 1.8740 | Val Loss: 1.7652 | Val Acc: 33.28% | Test Acc: 33.90%
# Epoch 03 | Train Loss: 1.7071 | Val Loss: 1.6279 | Val Acc: 39.18% | Test Acc: 39.39%
# Epoch 04 | Train Loss: 1.5815 | Val Loss: 1.5344 | Val Acc: 43.08% | Test Acc: 43.85%
# Epoch 05 | Train Loss: 1.4676 | Val Loss: 1.4337 | Val Acc: 48.58% | Test Acc: 48.31%
# Epoch 06 | Train Loss: 1.3773 | Val Loss: 1.3470 | Val Acc: 51.30% | Test Acc: 50.98%
# Epoch 07 | Train Loss: 1.2980 | Val Loss: 1.2591 | Val Acc: 53.72% | Test Acc: 54.27%
# Epoch 08 | Train Loss: 1.2281 | Val Loss: 1.2525 | Val Acc: 54.80% | Test Acc: 55.39%
# Epoch 09 | Train Loss: 1.1594 | Val Loss: 1.2517 | Val Acc: 56.90% | Test Acc: 56.87%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 63.51it/s]
# Epoch 10 | Train Loss: 1.0952 | Val Loss: 1.0604 | Val Acc: 61.28% | Test Acc: 62.49%
# Epoch 11 | Train Loss: 1.0398 | Val Loss: 1.1062 | Val Acc: 60.84% | Test Acc: 61.25%
# Epoch 12 | Train Loss: 0.9920 | Val Loss: 1.3384 | Val Acc: 56.12% | Test Acc: 56.08%
# Epoch 13 | Train Loss: 0.9502 | Val Loss: 1.0468 | Val Acc: 64.58% | Test Acc: 64.07%
# Epoch 14 | Train Loss: 0.9071 | Val Loss: 0.9145 | Val Acc: 67.68% | Test Acc: 67.12%
# Epoch 15 | Train Loss: 0.8681 | Val Loss: 0.9440 | Val Acc: 68.04% | Test Acc: 67.98%
# Epoch 16 | Train Loss: 0.8366 | Val Loss: 1.3346 | Val Acc: 59.46% | Test Acc: 58.99%
# Epoch 17 | Train Loss: 0.8002 | Val Loss: 0.8734 | Val Acc: 70.34% | Test Acc: 69.80%
# Epoch 18 | Train Loss: 0.7740 | Val Loss: 1.0164 | Val Acc: 65.94% | Test Acc: 66.21%
# Epoch 19 | Train Loss: 0.7465 | Val Loss: 0.7759 | Val Acc: 73.68% | Test Acc: 72.05%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 61.82it/s]
# Epoch 20 | Train Loss: 0.7199 | Val Loss: 0.8253 | Val Acc: 72.02% | Test Acc: 71.83%
# Epoch 21 | Train Loss: 0.6867 | Val Loss: 1.0845 | Val Acc: 66.78% | Test Acc: 66.29%
# Epoch 22 | Train Loss: 0.6671 | Val Loss: 0.9697 | Val Acc: 69.04% | Test Acc: 69.20%
# Epoch 23 | Train Loss: 0.6424 | Val Loss: 0.8295 | Val Acc: 73.14% | Test Acc: 72.52%
# Epoch 24 | Train Loss: 0.6229 | Val Loss: 0.7297 | Val Acc: 75.68% | Test Acc: 74.78%
# Epoch 25 | Train Loss: 0.6009 | Val Loss: 0.7859 | Val Acc: 74.32% | Test Acc: 74.11%
# Epoch 26 | Train Loss: 0.5831 | Val Loss: 0.8639 | Val Acc: 71.20% | Test Acc: 71.26%
# Epoch 27 | Train Loss: 0.5639 | Val Loss: 0.6414 | Val Acc: 77.94% | Test Acc: 78.05%
# Epoch 28 | Train Loss: 0.5498 | Val Loss: 0.6548 | Val Acc: 78.14% | Test Acc: 78.22%
# Epoch 29 | Train Loss: 0.5370 | Val Loss: 0.6951 | Val Acc: 77.60% | Test Acc: 76.82%
# Epoch 30/86: 100%|██████████| 352/352 [00:06<00:00, 58.19it/s]
# Epoch 30 | Train Loss: 0.5210 | Val Loss: 0.7802 | Val Acc: 75.82% | Test Acc: 76.13%
# Epoch 31 | Train Loss: 0.5055 | Val Loss: 0.6268 | Val Acc: 78.92% | Test Acc: 78.76%
# Epoch 32 | Train Loss: 0.5039 | Val Loss: 0.6032 | Val Acc: 79.56% | Test Acc: 80.25%
# Epoch 33 | Train Loss: 0.4831 | Val Loss: 0.6809 | Val Acc: 77.26% | Test Acc: 77.79%
# Epoch 34 | Train Loss: 0.4752 | Val Loss: 0.7833 | Val Acc: 75.50% | Test Acc: 75.41%
# Epoch 35 | Train Loss: 0.4677 | Val Loss: 0.7772 | Val Acc: 76.14% | Test Acc: 76.48%
# Epoch 36 | Train Loss: 0.4512 | Val Loss: 0.5720 | Val Acc: 81.08% | Test Acc: 80.16%
# Epoch 37 | Train Loss: 0.4534 | Val Loss: 0.5840 | Val Acc: 80.86% | Test Acc: 80.49%
# Epoch 38 | Train Loss: 0.4416 | Val Loss: 0.6888 | Val Acc: 76.94% | Test Acc: 77.69%
# Epoch 39 | Train Loss: 0.4326 | Val Loss: 0.6538 | Val Acc: 78.40% | Test Acc: 78.88%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 65.37it/s]
# Epoch 40 | Train Loss: 0.4233 | Val Loss: 0.6109 | Val Acc: 80.48% | Test Acc: 80.06%
# Epoch 41 | Train Loss: 0.4120 | Val Loss: 0.6607 | Val Acc: 78.68% | Test Acc: 79.54%
# Epoch 42 | Train Loss: 0.4079 | Val Loss: 0.6791 | Val Acc: 78.64% | Test Acc: 78.46%
# Epoch 43 | Train Loss: 0.4011 | Val Loss: 0.6435 | Val Acc: 79.22% | Test Acc: 79.24%
# Epoch 44 | Train Loss: 0.3908 | Val Loss: 0.6493 | Val Acc: 79.92% | Test Acc: 79.49%
# Epoch 45 | Train Loss: 0.3833 | Val Loss: 0.6694 | Val Acc: 80.12% | Test Acc: 80.22%
# Epoch 46 | Train Loss: 0.3797 | Val Loss: 0.6671 | Val Acc: 78.96% | Test Acc: 79.22%
# Epoch 47 | Train Loss: 0.3685 | Val Loss: 0.6158 | Val Acc: 80.56% | Test Acc: 80.32%
# Epoch 48 | Train Loss: 0.3653 | Val Loss: 0.5536 | Val Acc: 82.10% | Test Acc: 82.49%
# Epoch 49 | Train Loss: 0.3584 | Val Loss: 0.5861 | Val Acc: 81.56% | Test Acc: 81.30%
# Epoch 50/86: 100%|██████████| 352/352 [00:06<00:00, 58.28it/s]
# Epoch 50 | Train Loss: 0.3511 | Val Loss: 0.6409 | Val Acc: 80.06% | Test Acc: 80.26%
# Epoch 51 | Train Loss: 0.3496 | Val Loss: 0.6387 | Val Acc: 79.90% | Test Acc: 80.78%
# Epoch 52 | Train Loss: 0.3406 | Val Loss: 0.6226 | Val Acc: 81.62% | Test Acc: 81.02%
# Epoch 53 | Train Loss: 0.3365 | Val Loss: 0.6538 | Val Acc: 79.92% | Test Acc: 80.86%
# Epoch 54 | Train Loss: 0.3358 | Val Loss: 0.5157 | Val Acc: 83.30% | Test Acc: 83.49%
# Epoch 55 | Train Loss: 0.3272 | Val Loss: 0.5920 | Val Acc: 81.90% | Test Acc: 82.16%
# Epoch 56 | Train Loss: 0.3213 | Val Loss: 0.6467 | Val Acc: 80.50% | Test Acc: 80.63%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3218 | Val Loss: 0.4852 | Val Acc: 84.62% | Test Acc: 84.65%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2500 | Val Loss: 0.3943 | Val Acc: 87.66% | Test Acc: 87.80%
# Epoch 59 | Train Loss: 0.2286 | Val Loss: 0.3883 | Val Acc: 87.60% | Test Acc: 87.90%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 66.55it/s]
# Epoch 60 | Train Loss: 0.2213 | Val Loss: 0.3960 | Val Acc: 87.72% | Test Acc: 87.86%
# Epoch 61 | Train Loss: 0.2183 | Val Loss: 0.3954 | Val Acc: 87.70% | Test Acc: 88.17%
# Epoch 62 | Train Loss: 0.2139 | Val Loss: 0.3977 | Val Acc: 87.66% | Test Acc: 87.84%
# Epoch 63 | Train Loss: 0.2091 | Val Loss: 0.3902 | Val Acc: 87.60% | Test Acc: 88.10%
# Epoch 64 | Train Loss: 0.2081 | Val Loss: 0.3958 | Val Acc: 87.68% | Test Acc: 87.89%
# Epoch 65 | Train Loss: 0.2045 | Val Loss: 0.3912 | Val Acc: 87.66% | Test Acc: 88.14%
# Epoch 66 | Train Loss: 0.2013 | Val Loss: 0.3933 | Val Acc: 87.98% | Test Acc: 88.02%
# Epoch 67 | Train Loss: 0.2011 | Val Loss: 0.3960 | Val Acc: 87.46% | Test Acc: 88.19%
# Epoch 68 | Train Loss: 0.2025 | Val Loss: 0.4012 | Val Acc: 87.84% | Test Acc: 87.97%
#    [Tracker] 🚩 Early Stop Condition at Iter 24288 (Epoch 69, Test Acc: 87.99%)
# Epoch 69 | Train Loss: 0.1965 | Val Loss: 0.4011 | Val Acc: 87.50% | Test Acc: 87.99%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 60.18it/s]
# Epoch 70 | Train Loss: 0.1946 | Val Loss: 0.4014 | Val Acc: 87.74% | Test Acc: 88.17%
# Epoch 71 | Train Loss: 0.1940 | Val Loss: 0.3959 | Val Acc: 87.70% | Test Acc: 88.07%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.1868 | Val Loss: 0.3961 | Val Acc: 87.74% | Test Acc: 88.18%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.1852 | Val Loss: 0.3931 | Val Acc: 87.66% | Test Acc: 88.32%
# Epoch 74 | Train Loss: 0.1859 | Val Loss: 0.3931 | Val Acc: 87.72% | Test Acc: 88.29%
# Epoch 75 | Train Loss: 0.1819 | Val Loss: 0.3931 | Val Acc: 87.66% | Test Acc: 88.28%
# Epoch 76 | Train Loss: 0.1810 | Val Loss: 0.3963 | Val Acc: 87.46% | Test Acc: 88.16%
# Epoch 77 | Train Loss: 0.1844 | Val Loss: 0.3932 | Val Acc: 87.70% | Test Acc: 88.28%
# Epoch 78 | Train Loss: 0.1813 | Val Loss: 0.3943 | Val Acc: 87.66% | Test Acc: 88.36%
# Epoch 79 | Train Loss: 0.1805 | Val Loss: 0.3942 | Val Acc: 87.60% | Test Acc: 88.35%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 61.44it/s]
# Epoch 80 | Train Loss: 0.1837 | Val Loss: 0.3976 | Val Acc: 87.54% | Test Acc: 88.26%
# Epoch 81 | Train Loss: 0.1811 | Val Loss: 0.3930 | Val Acc: 87.74% | Test Acc: 88.22%
# Epoch 82 | Train Loss: 0.1809 | Val Loss: 0.3937 | Val Acc: 87.70% | Test Acc: 88.15%
# Epoch 83 | Train Loss: 0.1808 | Val Loss: 0.3949 | Val Acc: 87.62% | Test Acc: 88.13%
# Epoch 84 | Train Loss: 0.1808 | Val Loss: 0.3928 | Val Acc: 87.88% | Test Acc: 88.31%
# Epoch 85 | Train Loss: 0.1810 | Val Loss: 0.3970 | Val Acc: 87.66% | Test Acc: 88.12%
# Epoch 86 | Train Loss: 0.1836 | Val Loss: 0.3941 | Val Acc: 87.62% | Test Acc: 88.10%
#
# Random Reinit Result:
#   Test Accuracy: 88.10%
#   Remaining Params: 64.27%
# ======================================================================
#
#    -> Random Reinit for Sparsity: 51.57%
#
# ======================================================================
# Starting Random Reinit Control Experiment
# Sparsity Level: 51.57% weights remaining
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# Warmup strategy: linear_20k
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.2370 | Val Loss: 1.9091 | Val Acc: 29.26% | Test Acc: 28.60%
# Epoch 02 | Train Loss: 1.8250 | Val Loss: 1.7096 | Val Acc: 37.22% | Test Acc: 37.04%
# Epoch 03 | Train Loss: 1.6751 | Val Loss: 1.6184 | Val Acc: 40.40% | Test Acc: 40.52%
# Epoch 04 | Train Loss: 1.5733 | Val Loss: 1.4997 | Val Acc: 44.88% | Test Acc: 45.43%
# Epoch 05 | Train Loss: 1.4799 | Val Loss: 1.4413 | Val Acc: 47.36% | Test Acc: 48.10%
# Epoch 06 | Train Loss: 1.4001 | Val Loss: 1.4649 | Val Acc: 46.82% | Test Acc: 47.22%
# Epoch 07 | Train Loss: 1.3276 | Val Loss: 1.2995 | Val Acc: 53.06% | Test Acc: 52.98%
# Epoch 08 | Train Loss: 1.2557 | Val Loss: 1.3429 | Val Acc: 53.26% | Test Acc: 52.99%
# Epoch 09 | Train Loss: 1.1831 | Val Loss: 1.1642 | Val Acc: 59.06% | Test Acc: 59.02%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 66.13it/s]
# Epoch 10 | Train Loss: 1.1173 | Val Loss: 1.1380 | Val Acc: 59.80% | Test Acc: 59.32%
# Epoch 11 | Train Loss: 1.0605 | Val Loss: 1.1753 | Val Acc: 58.22% | Test Acc: 58.77%
# Epoch 12 | Train Loss: 1.0117 | Val Loss: 1.0706 | Val Acc: 62.64% | Test Acc: 61.94%
# Epoch 13 | Train Loss: 0.9663 | Val Loss: 0.9556 | Val Acc: 66.30% | Test Acc: 66.43%
# Epoch 14 | Train Loss: 0.9204 | Val Loss: 1.0099 | Val Acc: 64.46% | Test Acc: 64.93%
# Epoch 15 | Train Loss: 0.8808 | Val Loss: 1.0400 | Val Acc: 65.22% | Test Acc: 65.21%
# Epoch 16 | Train Loss: 0.8425 | Val Loss: 1.0152 | Val Acc: 66.08% | Test Acc: 65.85%
# Epoch 17 | Train Loss: 0.8038 | Val Loss: 0.8727 | Val Acc: 69.72% | Test Acc: 70.00%
# Epoch 18 | Train Loss: 0.7693 | Val Loss: 0.9617 | Val Acc: 67.54% | Test Acc: 68.19%
# Epoch 19 | Train Loss: 0.7385 | Val Loss: 0.8806 | Val Acc: 70.12% | Test Acc: 70.33%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 65.38it/s]
# Epoch 20 | Train Loss: 0.7065 | Val Loss: 0.8859 | Val Acc: 70.54% | Test Acc: 70.75%
# Epoch 21 | Train Loss: 0.6802 | Val Loss: 0.8589 | Val Acc: 71.38% | Test Acc: 71.07%
# Epoch 22 | Train Loss: 0.6569 | Val Loss: 0.9225 | Val Acc: 70.26% | Test Acc: 69.88%
# Epoch 23 | Train Loss: 0.6289 | Val Loss: 0.9902 | Val Acc: 68.38% | Test Acc: 68.84%
# Epoch 24 | Train Loss: 0.6132 | Val Loss: 0.6781 | Val Acc: 77.54% | Test Acc: 76.44%
# Epoch 25 | Train Loss: 0.5978 | Val Loss: 0.6954 | Val Acc: 76.32% | Test Acc: 76.89%
# Epoch 26 | Train Loss: 0.5735 | Val Loss: 0.8115 | Val Acc: 73.64% | Test Acc: 73.89%
# Epoch 27 | Train Loss: 0.5605 | Val Loss: 0.6493 | Val Acc: 78.46% | Test Acc: 77.96%
# Epoch 28 | Train Loss: 0.5412 | Val Loss: 0.6357 | Val Acc: 78.86% | Test Acc: 78.81%
# Epoch 29 | Train Loss: 0.5303 | Val Loss: 0.7841 | Val Acc: 75.40% | Test Acc: 74.76%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 65.69it/s]
# Epoch 30 | Train Loss: 0.5202 | Val Loss: 0.6562 | Val Acc: 77.72% | Test Acc: 78.65%
# Epoch 31 | Train Loss: 0.5014 | Val Loss: 0.7187 | Val Acc: 76.72% | Test Acc: 76.85%
# Epoch 32 | Train Loss: 0.4970 | Val Loss: 0.7562 | Val Acc: 76.04% | Test Acc: 75.62%
# Epoch 33 | Train Loss: 0.4858 | Val Loss: 0.7196 | Val Acc: 76.64% | Test Acc: 77.14%
# Epoch 34 | Train Loss: 0.4750 | Val Loss: 0.6290 | Val Acc: 79.22% | Test Acc: 79.11%
# Epoch 35 | Train Loss: 0.4665 | Val Loss: 0.6166 | Val Acc: 79.52% | Test Acc: 80.43%
# Epoch 36 | Train Loss: 0.4602 | Val Loss: 0.7493 | Val Acc: 77.08% | Test Acc: 77.59%
# Epoch 37 | Train Loss: 0.4477 | Val Loss: 0.6073 | Val Acc: 79.54% | Test Acc: 79.94%
# Epoch 38 | Train Loss: 0.4381 | Val Loss: 0.6460 | Val Acc: 79.10% | Test Acc: 79.35%
# Epoch 39 | Train Loss: 0.4303 | Val Loss: 0.5432 | Val Acc: 81.36% | Test Acc: 81.83%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 66.84it/s]
# Epoch 40 | Train Loss: 0.4228 | Val Loss: 0.6710 | Val Acc: 78.78% | Test Acc: 78.87%
# Epoch 41 | Train Loss: 0.4198 | Val Loss: 0.5447 | Val Acc: 81.76% | Test Acc: 82.78%
# Epoch 42 | Train Loss: 0.4080 | Val Loss: 0.5608 | Val Acc: 81.84% | Test Acc: 82.69%
# Epoch 43 | Train Loss: 0.3986 | Val Loss: 0.6726 | Val Acc: 79.48% | Test Acc: 79.91%
# Epoch 44 | Train Loss: 0.3955 | Val Loss: 0.7402 | Val Acc: 77.64% | Test Acc: 78.02%
# Epoch 45 | Train Loss: 0.3890 | Val Loss: 0.5748 | Val Acc: 81.54% | Test Acc: 81.92%
# Epoch 46 | Train Loss: 0.3787 | Val Loss: 0.6028 | Val Acc: 81.12% | Test Acc: 81.67%
# Epoch 47 | Train Loss: 0.3793 | Val Loss: 0.6343 | Val Acc: 80.00% | Test Acc: 80.03%
# Epoch 48 | Train Loss: 0.3718 | Val Loss: 0.5822 | Val Acc: 80.94% | Test Acc: 81.60%
# Epoch 49 | Train Loss: 0.3690 | Val Loss: 0.5803 | Val Acc: 81.62% | Test Acc: 82.16%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 64.17it/s]
# Epoch 50 | Train Loss: 0.3625 | Val Loss: 0.6245 | Val Acc: 80.66% | Test Acc: 81.98%
# Epoch 51 | Train Loss: 0.3534 | Val Loss: 0.6094 | Val Acc: 80.68% | Test Acc: 81.15%
# Epoch 52 | Train Loss: 0.3520 | Val Loss: 0.5386 | Val Acc: 83.08% | Test Acc: 83.28%
# Epoch 53 | Train Loss: 0.3456 | Val Loss: 0.6292 | Val Acc: 80.74% | Test Acc: 81.08%
# Epoch 54 | Train Loss: 0.3452 | Val Loss: 0.5984 | Val Acc: 81.36% | Test Acc: 81.94%
# Epoch 55 | Train Loss: 0.3400 | Val Loss: 0.5496 | Val Acc: 83.08% | Test Acc: 82.86%
# Epoch 56 | Train Loss: 0.3352 | Val Loss: 0.5237 | Val Acc: 84.26% | Test Acc: 84.21%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3294 | Val Loss: 0.5263 | Val Acc: 82.46% | Test Acc: 84.01%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2601 | Val Loss: 0.3980 | Val Acc: 86.54% | Test Acc: 87.72%
# Epoch 59 | Train Loss: 0.2391 | Val Loss: 0.4011 | Val Acc: 86.68% | Test Acc: 87.53%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 64.01it/s]
# Epoch 60 | Train Loss: 0.2349 | Val Loss: 0.4002 | Val Acc: 87.02% | Test Acc: 87.60%
# Epoch 61 | Train Loss: 0.2291 | Val Loss: 0.3930 | Val Acc: 87.14% | Test Acc: 87.61%
# Epoch 62 | Train Loss: 0.2189 | Val Loss: 0.3990 | Val Acc: 87.18% | Test Acc: 87.77%
# Epoch 63 | Train Loss: 0.2227 | Val Loss: 0.3927 | Val Acc: 87.20% | Test Acc: 87.81%
# Epoch 64 | Train Loss: 0.2174 | Val Loss: 0.4022 | Val Acc: 86.92% | Test Acc: 87.33%
# Epoch 65 | Train Loss: 0.2169 | Val Loss: 0.3961 | Val Acc: 87.04% | Test Acc: 87.75%
# Epoch 66 | Train Loss: 0.2153 | Val Loss: 0.4018 | Val Acc: 87.38% | Test Acc: 87.94%
# Epoch 67 | Train Loss: 0.2108 | Val Loss: 0.4016 | Val Acc: 87.28% | Test Acc: 87.61%
# Epoch 68 | Train Loss: 0.2106 | Val Loss: 0.3998 | Val Acc: 87.24% | Test Acc: 87.56%
# Epoch 69 | Train Loss: 0.2092 | Val Loss: 0.4054 | Val Acc: 86.92% | Test Acc: 87.67%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 64.82it/s]
# Epoch 70 | Train Loss: 0.2062 | Val Loss: 0.4095 | Val Acc: 87.30% | Test Acc: 87.55%
#    [Tracker] 🚩 Early Stop Condition at Iter 24992 (Epoch 71, Test Acc: 87.68%)
# Epoch 71 | Train Loss: 0.2070 | Val Loss: 0.4103 | Val Acc: 86.86% | Test Acc: 87.68%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.2004 | Val Loss: 0.4047 | Val Acc: 87.10% | Test Acc: 87.63%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.1981 | Val Loss: 0.4029 | Val Acc: 87.06% | Test Acc: 87.60%
# Epoch 74 | Train Loss: 0.1979 | Val Loss: 0.4012 | Val Acc: 87.32% | Test Acc: 87.63%
# Epoch 75 | Train Loss: 0.1966 | Val Loss: 0.3997 | Val Acc: 87.18% | Test Acc: 87.71%
# Epoch 76 | Train Loss: 0.1959 | Val Loss: 0.3985 | Val Acc: 87.06% | Test Acc: 87.77%
# Epoch 77 | Train Loss: 0.1949 | Val Loss: 0.4017 | Val Acc: 87.34% | Test Acc: 87.77%
# Epoch 78 | Train Loss: 0.1964 | Val Loss: 0.4006 | Val Acc: 87.34% | Test Acc: 87.66%
# Epoch 79 | Train Loss: 0.1951 | Val Loss: 0.4021 | Val Acc: 87.28% | Test Acc: 87.81%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 61.07it/s]
# Epoch 80 | Train Loss: 0.1956 | Val Loss: 0.4011 | Val Acc: 87.16% | Test Acc: 87.77%
# Epoch 81 | Train Loss: 0.1942 | Val Loss: 0.4039 | Val Acc: 87.02% | Test Acc: 87.78%
# Epoch 82 | Train Loss: 0.1948 | Val Loss: 0.4001 | Val Acc: 87.02% | Test Acc: 87.75%
# Epoch 83 | Train Loss: 0.1943 | Val Loss: 0.4010 | Val Acc: 87.38% | Test Acc: 87.85%
# Epoch 84 | Train Loss: 0.1954 | Val Loss: 0.4005 | Val Acc: 87.18% | Test Acc: 87.73%
# Epoch 85 | Train Loss: 0.1940 | Val Loss: 0.4000 | Val Acc: 87.22% | Test Acc: 87.62%
# Epoch 86 | Train Loss: 0.1949 | Val Loss: 0.3992 | Val Acc: 87.34% | Test Acc: 87.86%
#
# Random Reinit Result:
#   Test Accuracy: 87.86%
#   Remaining Params: 51.57%
# ======================================================================
#
#    -> Random Reinit for Sparsity: 41.40%
#
# ======================================================================
# Starting Random Reinit Control Experiment
# Sparsity Level: 41.40% weights remaining
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# Warmup strategy: linear_20k
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.2418 | Val Loss: 2.0214 | Val Acc: 24.38% | Test Acc: 24.49%
# Epoch 02 | Train Loss: 1.8783 | Val Loss: 1.7841 | Val Acc: 33.04% | Test Acc: 33.26%
# Epoch 03 | Train Loss: 1.7179 | Val Loss: 1.6476 | Val Acc: 37.62% | Test Acc: 38.37%
# Epoch 04 | Train Loss: 1.6035 | Val Loss: 1.5489 | Val Acc: 43.08% | Test Acc: 43.36%
# Epoch 05 | Train Loss: 1.4909 | Val Loss: 1.4366 | Val Acc: 47.30% | Test Acc: 47.22%
# Epoch 06 | Train Loss: 1.3828 | Val Loss: 1.3498 | Val Acc: 50.46% | Test Acc: 50.61%
# Epoch 07 | Train Loss: 1.3091 | Val Loss: 1.3236 | Val Acc: 51.48% | Test Acc: 51.24%
# Epoch 08 | Train Loss: 1.2383 | Val Loss: 1.2095 | Val Acc: 56.72% | Test Acc: 56.92%
# Epoch 09 | Train Loss: 1.1830 | Val Loss: 1.2318 | Val Acc: 55.98% | Test Acc: 56.71%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 65.66it/s]
# Epoch 10 | Train Loss: 1.1220 | Val Loss: 1.1462 | Val Acc: 59.32% | Test Acc: 59.50%
# Epoch 11 | Train Loss: 1.0674 | Val Loss: 1.1705 | Val Acc: 59.32% | Test Acc: 60.35%
# Epoch 12 | Train Loss: 1.0091 | Val Loss: 1.0145 | Val Acc: 64.34% | Test Acc: 64.28%
# Epoch 13 | Train Loss: 0.9690 | Val Loss: 1.0497 | Val Acc: 63.00% | Test Acc: 63.76%
# Epoch 14 | Train Loss: 0.9280 | Val Loss: 1.0043 | Val Acc: 65.60% | Test Acc: 65.02%
# Epoch 15 | Train Loss: 0.8818 | Val Loss: 0.9772 | Val Acc: 66.02% | Test Acc: 66.00%
# Epoch 16 | Train Loss: 0.8444 | Val Loss: 0.8563 | Val Acc: 70.24% | Test Acc: 69.69%
# Epoch 17 | Train Loss: 0.8067 | Val Loss: 0.8787 | Val Acc: 70.16% | Test Acc: 69.84%
# Epoch 18 | Train Loss: 0.7736 | Val Loss: 0.8545 | Val Acc: 71.24% | Test Acc: 70.78%
# Epoch 19 | Train Loss: 0.7473 | Val Loss: 0.8571 | Val Acc: 71.82% | Test Acc: 71.04%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 64.93it/s]
# Epoch 20 | Train Loss: 0.7088 | Val Loss: 0.8785 | Val Acc: 71.18% | Test Acc: 70.74%
# Epoch 21 | Train Loss: 0.6919 | Val Loss: 0.7422 | Val Acc: 75.20% | Test Acc: 74.52%
# Epoch 22 | Train Loss: 0.6618 | Val Loss: 0.7222 | Val Acc: 75.48% | Test Acc: 75.34%
# Epoch 23 | Train Loss: 0.6422 | Val Loss: 0.7704 | Val Acc: 75.06% | Test Acc: 74.92%
# Epoch 24 | Train Loss: 0.6256 | Val Loss: 0.7063 | Val Acc: 76.26% | Test Acc: 76.10%
# Epoch 25 | Train Loss: 0.6002 | Val Loss: 0.7630 | Val Acc: 75.10% | Test Acc: 74.58%
# Epoch 26 | Train Loss: 0.5887 | Val Loss: 0.8092 | Val Acc: 73.58% | Test Acc: 74.12%
# Epoch 27 | Train Loss: 0.5780 | Val Loss: 0.6885 | Val Acc: 76.94% | Test Acc: 77.59%
# Epoch 28 | Train Loss: 0.5655 | Val Loss: 0.7798 | Val Acc: 74.70% | Test Acc: 74.49%
# Epoch 29 | Train Loss: 0.5441 | Val Loss: 0.6629 | Val Acc: 77.76% | Test Acc: 78.41%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 66.34it/s]
# Epoch 30 | Train Loss: 0.5354 | Val Loss: 0.6230 | Val Acc: 79.04% | Test Acc: 78.99%
# Epoch 31 | Train Loss: 0.5206 | Val Loss: 0.7725 | Val Acc: 76.06% | Test Acc: 76.37%
# Epoch 32 | Train Loss: 0.5103 | Val Loss: 0.6843 | Val Acc: 78.14% | Test Acc: 78.09%
# Epoch 33 | Train Loss: 0.5028 | Val Loss: 0.6579 | Val Acc: 78.40% | Test Acc: 78.62%
# Epoch 34 | Train Loss: 0.4955 | Val Loss: 0.7705 | Val Acc: 75.44% | Test Acc: 75.83%
# Epoch 35 | Train Loss: 0.4788 | Val Loss: 0.7062 | Val Acc: 76.78% | Test Acc: 76.86%
# Epoch 36 | Train Loss: 0.4772 | Val Loss: 0.6330 | Val Acc: 79.62% | Test Acc: 78.79%
# Epoch 37 | Train Loss: 0.4657 | Val Loss: 0.6220 | Val Acc: 80.32% | Test Acc: 80.19%
# Epoch 38 | Train Loss: 0.4605 | Val Loss: 0.6228 | Val Acc: 80.26% | Test Acc: 79.48%
# Epoch 39 | Train Loss: 0.4525 | Val Loss: 0.5947 | Val Acc: 79.98% | Test Acc: 79.78%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 61.73it/s]
# Epoch 40 | Train Loss: 0.4460 | Val Loss: 0.6410 | Val Acc: 78.92% | Test Acc: 79.03%
# Epoch 41 | Train Loss: 0.4385 | Val Loss: 0.6039 | Val Acc: 80.58% | Test Acc: 80.23%
# Epoch 42 | Train Loss: 0.4325 | Val Loss: 0.5784 | Val Acc: 81.52% | Test Acc: 81.19%
# Epoch 43 | Train Loss: 0.4227 | Val Loss: 0.5718 | Val Acc: 81.52% | Test Acc: 81.11%
# Epoch 44 | Train Loss: 0.4182 | Val Loss: 0.5647 | Val Acc: 81.36% | Test Acc: 81.92%
# Epoch 45 | Train Loss: 0.4125 | Val Loss: 0.7081 | Val Acc: 78.04% | Test Acc: 77.84%
# Epoch 46 | Train Loss: 0.4134 | Val Loss: 0.7680 | Val Acc: 77.36% | Test Acc: 77.73%
# Epoch 47 | Train Loss: 0.4012 | Val Loss: 0.6308 | Val Acc: 79.28% | Test Acc: 79.52%
# Epoch 48 | Train Loss: 0.3983 | Val Loss: 0.5069 | Val Acc: 83.24% | Test Acc: 82.83%
# Epoch 49 | Train Loss: 0.3933 | Val Loss: 0.5533 | Val Acc: 82.68% | Test Acc: 81.92%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 66.47it/s]
# Epoch 50 | Train Loss: 0.3882 | Val Loss: 0.5694 | Val Acc: 81.72% | Test Acc: 81.30%
# Epoch 51 | Train Loss: 0.3826 | Val Loss: 0.5652 | Val Acc: 81.78% | Test Acc: 81.99%
# Epoch 52 | Train Loss: 0.3756 | Val Loss: 0.6190 | Val Acc: 80.42% | Test Acc: 79.93%
# Epoch 53 | Train Loss: 0.3734 | Val Loss: 0.6032 | Val Acc: 80.96% | Test Acc: 81.43%
# Epoch 54 | Train Loss: 0.3661 | Val Loss: 0.7007 | Val Acc: 77.84% | Test Acc: 78.84%
# Epoch 55 | Train Loss: 0.3680 | Val Loss: 0.7514 | Val Acc: 77.84% | Test Acc: 78.58%
# Epoch 56 | Train Loss: 0.3614 | Val Loss: 0.5640 | Val Acc: 82.92% | Test Acc: 82.47%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3536 | Val Loss: 0.5418 | Val Acc: 82.70% | Test Acc: 82.49%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2859 | Val Loss: 0.4129 | Val Acc: 86.26% | Test Acc: 86.27%
# Epoch 59 | Train Loss: 0.2666 | Val Loss: 0.4126 | Val Acc: 86.54% | Test Acc: 86.10%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 61.70it/s]
# Epoch 60 | Train Loss: 0.2607 | Val Loss: 0.4126 | Val Acc: 86.22% | Test Acc: 86.15%
# Epoch 61 | Train Loss: 0.2552 | Val Loss: 0.4114 | Val Acc: 86.30% | Test Acc: 86.59%
# Epoch 62 | Train Loss: 0.2517 | Val Loss: 0.4164 | Val Acc: 86.42% | Test Acc: 86.65%
# Epoch 63 | Train Loss: 0.2468 | Val Loss: 0.4203 | Val Acc: 86.40% | Test Acc: 86.21%
# Epoch 64 | Train Loss: 0.2430 | Val Loss: 0.4198 | Val Acc: 86.22% | Test Acc: 86.51%
# Epoch 65 | Train Loss: 0.2460 | Val Loss: 0.4134 | Val Acc: 86.48% | Test Acc: 86.69%
# Epoch 66 | Train Loss: 0.2431 | Val Loss: 0.4154 | Val Acc: 86.64% | Test Acc: 86.27%
# Epoch 67 | Train Loss: 0.2408 | Val Loss: 0.4120 | Val Acc: 86.52% | Test Acc: 86.55%
# Epoch 68 | Train Loss: 0.2358 | Val Loss: 0.4145 | Val Acc: 86.72% | Test Acc: 86.72%
# Epoch 69 | Train Loss: 0.2382 | Val Loss: 0.4163 | Val Acc: 86.84% | Test Acc: 86.56%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 63.75it/s]
# Epoch 70 | Train Loss: 0.2340 | Val Loss: 0.4129 | Val Acc: 86.66% | Test Acc: 86.62%
#    [Tracker] 🚩 Early Stop Condition at Iter 24992 (Epoch 71, Test Acc: 86.53%)
# Epoch 71 | Train Loss: 0.2335 | Val Loss: 0.4184 | Val Acc: 86.62% | Test Acc: 86.53%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.2259 | Val Loss: 0.4124 | Val Acc: 86.82% | Test Acc: 86.75%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.2275 | Val Loss: 0.4131 | Val Acc: 86.76% | Test Acc: 86.63%
# Epoch 74 | Train Loss: 0.2281 | Val Loss: 0.4135 | Val Acc: 86.80% | Test Acc: 86.68%
# Epoch 75 | Train Loss: 0.2232 | Val Loss: 0.4151 | Val Acc: 86.80% | Test Acc: 86.64%
# Epoch 76 | Train Loss: 0.2232 | Val Loss: 0.4105 | Val Acc: 87.00% | Test Acc: 86.79%
# Epoch 77 | Train Loss: 0.2206 | Val Loss: 0.4102 | Val Acc: 86.88% | Test Acc: 86.57%
# Epoch 78 | Train Loss: 0.2212 | Val Loss: 0.4124 | Val Acc: 87.06% | Test Acc: 86.53%
# Epoch 79 | Train Loss: 0.2210 | Val Loss: 0.4087 | Val Acc: 86.86% | Test Acc: 86.65%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 59.20it/s]
# Epoch 80 | Train Loss: 0.2204 | Val Loss: 0.4103 | Val Acc: 87.18% | Test Acc: 86.81%
# Epoch 81 | Train Loss: 0.2201 | Val Loss: 0.4074 | Val Acc: 87.02% | Test Acc: 86.86%
# Epoch 82 | Train Loss: 0.2196 | Val Loss: 0.4123 | Val Acc: 87.02% | Test Acc: 86.59%
# Epoch 83 | Train Loss: 0.2202 | Val Loss: 0.4127 | Val Acc: 86.98% | Test Acc: 86.66%
# Epoch 84 | Train Loss: 0.2224 | Val Loss: 0.4138 | Val Acc: 87.00% | Test Acc: 86.60%
# Epoch 85 | Train Loss: 0.2206 | Val Loss: 0.4131 | Val Acc: 86.98% | Test Acc: 86.69%
# Epoch 86 | Train Loss: 0.2214 | Val Loss: 0.4132 | Val Acc: 86.88% | Test Acc: 86.64%
#
# Random Reinit Result:
#   Test Accuracy: 86.64%
#   Remaining Params: 41.40%
# ======================================================================
#
#    -> Random Reinit for Sparsity: 33.27%
#
# ======================================================================
# Starting Random Reinit Control Experiment
# Sparsity Level: 33.27% weights remaining
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# Warmup strategy: linear_20k
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.2782 | Val Loss: 1.9518 | Val Acc: 26.76% | Test Acc: 26.21%
# Epoch 02 | Train Loss: 1.8481 | Val Loss: 1.7533 | Val Acc: 33.60% | Test Acc: 33.50%
# Epoch 03 | Train Loss: 1.6940 | Val Loss: 1.6189 | Val Acc: 38.18% | Test Acc: 39.10%
# Epoch 04 | Train Loss: 1.5827 | Val Loss: 1.5215 | Val Acc: 43.70% | Test Acc: 43.83%
# Epoch 05 | Train Loss: 1.4911 | Val Loss: 1.4826 | Val Acc: 44.70% | Test Acc: 45.43%
# Epoch 06 | Train Loss: 1.3989 | Val Loss: 1.3672 | Val Acc: 50.28% | Test Acc: 50.07%
# Epoch 07 | Train Loss: 1.3080 | Val Loss: 1.3054 | Val Acc: 52.20% | Test Acc: 52.82%
# Epoch 08 | Train Loss: 1.2110 | Val Loss: 1.2133 | Val Acc: 56.30% | Test Acc: 57.05%
# Epoch 09 | Train Loss: 1.1341 | Val Loss: 1.1676 | Val Acc: 58.38% | Test Acc: 58.47%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 61.36it/s]
# Epoch 10 | Train Loss: 1.0681 | Val Loss: 1.1067 | Val Acc: 61.12% | Test Acc: 60.81%
# Epoch 11 | Train Loss: 1.0163 | Val Loss: 1.0673 | Val Acc: 62.56% | Test Acc: 62.91%
# Epoch 12 | Train Loss: 0.9692 | Val Loss: 0.9468 | Val Acc: 65.90% | Test Acc: 66.73%
# Epoch 13 | Train Loss: 0.9261 | Val Loss: 1.0178 | Val Acc: 64.64% | Test Acc: 65.00%
# Epoch 14 | Train Loss: 0.8825 | Val Loss: 0.9459 | Val Acc: 66.76% | Test Acc: 66.36%
# Epoch 15 | Train Loss: 0.8545 | Val Loss: 0.8607 | Val Acc: 69.80% | Test Acc: 70.28%
# Epoch 16 | Train Loss: 0.8171 | Val Loss: 0.8524 | Val Acc: 70.02% | Test Acc: 70.19%
# Epoch 17 | Train Loss: 0.7783 | Val Loss: 0.8904 | Val Acc: 70.16% | Test Acc: 69.67%
# Epoch 18 | Train Loss: 0.7507 | Val Loss: 0.9134 | Val Acc: 69.68% | Test Acc: 69.68%
# Epoch 19 | Train Loss: 0.7229 | Val Loss: 0.7951 | Val Acc: 72.82% | Test Acc: 73.62%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 62.22it/s]
# Epoch 20 | Train Loss: 0.6947 | Val Loss: 0.7855 | Val Acc: 73.24% | Test Acc: 73.38%
# Epoch 21 | Train Loss: 0.6795 | Val Loss: 0.8737 | Val Acc: 70.88% | Test Acc: 70.62%
# Epoch 22 | Train Loss: 0.6587 | Val Loss: 0.9338 | Val Acc: 69.68% | Test Acc: 70.64%
# Epoch 23 | Train Loss: 0.6345 | Val Loss: 0.7806 | Val Acc: 73.92% | Test Acc: 73.60%
# Epoch 24 | Train Loss: 0.6176 | Val Loss: 0.7082 | Val Acc: 75.58% | Test Acc: 75.27%
# Epoch 25 | Train Loss: 0.6039 | Val Loss: 0.8317 | Val Acc: 73.64% | Test Acc: 72.87%
# Epoch 26 | Train Loss: 0.5890 | Val Loss: 0.6603 | Val Acc: 78.02% | Test Acc: 77.95%
# Epoch 27 | Train Loss: 0.5809 | Val Loss: 0.7257 | Val Acc: 75.32% | Test Acc: 75.21%
# Epoch 28 | Train Loss: 0.5609 | Val Loss: 0.7027 | Val Acc: 76.74% | Test Acc: 76.49%
# Epoch 29 | Train Loss: 0.5492 | Val Loss: 0.6219 | Val Acc: 78.92% | Test Acc: 78.85%
# Epoch 30/86: 100%|██████████| 352/352 [00:06<00:00, 56.15it/s]
# Epoch 30 | Train Loss: 0.5361 | Val Loss: 0.6401 | Val Acc: 78.76% | Test Acc: 79.32%
# Epoch 31 | Train Loss: 0.5289 | Val Loss: 0.6550 | Val Acc: 78.54% | Test Acc: 78.60%
# Epoch 32 | Train Loss: 0.5190 | Val Loss: 0.6428 | Val Acc: 78.86% | Test Acc: 79.05%
# Epoch 33 | Train Loss: 0.5092 | Val Loss: 0.6774 | Val Acc: 78.54% | Test Acc: 77.51%
# Epoch 34 | Train Loss: 0.4992 | Val Loss: 0.6768 | Val Acc: 78.06% | Test Acc: 78.81%
# Epoch 35 | Train Loss: 0.4832 | Val Loss: 0.6045 | Val Acc: 80.06% | Test Acc: 79.64%
# Epoch 36 | Train Loss: 0.4770 | Val Loss: 0.6664 | Val Acc: 78.76% | Test Acc: 78.49%
# Epoch 37 | Train Loss: 0.4761 | Val Loss: 0.6449 | Val Acc: 78.58% | Test Acc: 79.61%
# Epoch 38 | Train Loss: 0.4627 | Val Loss: 0.6517 | Val Acc: 80.08% | Test Acc: 79.94%
# Epoch 39 | Train Loss: 0.4553 | Val Loss: 0.5875 | Val Acc: 80.96% | Test Acc: 81.31%
# Epoch 40/86: 100%|██████████| 352/352 [00:06<00:00, 54.29it/s]
# Epoch 40 | Train Loss: 0.4495 | Val Loss: 0.6846 | Val Acc: 78.06% | Test Acc: 78.78%
# Epoch 41 | Train Loss: 0.4443 | Val Loss: 0.7797 | Val Acc: 76.18% | Test Acc: 76.07%
# Epoch 42 | Train Loss: 0.4352 | Val Loss: 0.7364 | Val Acc: 76.56% | Test Acc: 77.60%
# Epoch 43 | Train Loss: 0.4297 | Val Loss: 0.5898 | Val Acc: 80.80% | Test Acc: 80.95%
# Epoch 44 | Train Loss: 0.4255 | Val Loss: 0.5923 | Val Acc: 81.58% | Test Acc: 81.28%
# Epoch 45 | Train Loss: 0.4188 | Val Loss: 0.5569 | Val Acc: 81.92% | Test Acc: 82.66%
# Epoch 46 | Train Loss: 0.4171 | Val Loss: 0.5741 | Val Acc: 81.64% | Test Acc: 81.27%
# Epoch 47 | Train Loss: 0.4125 | Val Loss: 0.5495 | Val Acc: 82.68% | Test Acc: 82.19%
# Epoch 48 | Train Loss: 0.4022 | Val Loss: 0.6066 | Val Acc: 80.84% | Test Acc: 81.92%
# Epoch 49 | Train Loss: 0.3977 | Val Loss: 0.6324 | Val Acc: 79.78% | Test Acc: 79.33%
# Epoch 50/86: 100%|██████████| 352/352 [00:06<00:00, 58.32it/s]
# Epoch 50 | Train Loss: 0.3965 | Val Loss: 0.7050 | Val Acc: 78.32% | Test Acc: 78.82%
# Epoch 51 | Train Loss: 0.3866 | Val Loss: 0.5877 | Val Acc: 81.80% | Test Acc: 81.57%
# Epoch 52 | Train Loss: 0.3815 | Val Loss: 0.5835 | Val Acc: 82.00% | Test Acc: 81.11%
# Epoch 53 | Train Loss: 0.3780 | Val Loss: 0.5866 | Val Acc: 81.14% | Test Acc: 81.56%
# Epoch 54 | Train Loss: 0.3756 | Val Loss: 0.5476 | Val Acc: 82.48% | Test Acc: 82.69%
# Epoch 55 | Train Loss: 0.3690 | Val Loss: 0.6273 | Val Acc: 81.18% | Test Acc: 81.09%
# Epoch 56 | Train Loss: 0.3626 | Val Loss: 0.5816 | Val Acc: 81.90% | Test Acc: 81.84%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.3614 | Val Loss: 0.5402 | Val Acc: 82.82% | Test Acc: 83.23%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.2961 | Val Loss: 0.4048 | Val Acc: 86.88% | Test Acc: 86.55%
# Epoch 59 | Train Loss: 0.2724 | Val Loss: 0.4008 | Val Acc: 86.70% | Test Acc: 86.61%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 59.36it/s]
# Epoch 60 | Train Loss: 0.2682 | Val Loss: 0.4063 | Val Acc: 86.88% | Test Acc: 86.74%
# Epoch 61 | Train Loss: 0.2623 | Val Loss: 0.4038 | Val Acc: 87.22% | Test Acc: 86.93%
# Epoch 62 | Train Loss: 0.2623 | Val Loss: 0.4036 | Val Acc: 87.06% | Test Acc: 86.85%
# Epoch 63 | Train Loss: 0.2600 | Val Loss: 0.4038 | Val Acc: 86.96% | Test Acc: 86.96%
# Epoch 64 | Train Loss: 0.2564 | Val Loss: 0.4017 | Val Acc: 87.16% | Test Acc: 86.98%
# Epoch 65 | Train Loss: 0.2536 | Val Loss: 0.4032 | Val Acc: 86.98% | Test Acc: 87.08%
# Epoch 66 | Train Loss: 0.2498 | Val Loss: 0.4043 | Val Acc: 87.20% | Test Acc: 87.22%
# Epoch 67 | Train Loss: 0.2459 | Val Loss: 0.4074 | Val Acc: 87.16% | Test Acc: 86.95%
# Epoch 68 | Train Loss: 0.2478 | Val Loss: 0.4056 | Val Acc: 87.20% | Test Acc: 87.01%
#    [Tracker] 🚩 Early Stop Condition at Iter 24288 (Epoch 69, Test Acc: 87.01%)
# Epoch 69 | Train Loss: 0.2445 | Val Loss: 0.4093 | Val Acc: 87.22% | Test Acc: 87.01%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 64.31it/s]
# Epoch 70 | Train Loss: 0.2420 | Val Loss: 0.4116 | Val Acc: 86.64% | Test Acc: 87.02%
# Epoch 71 | Train Loss: 0.2388 | Val Loss: 0.4064 | Val Acc: 87.02% | Test Acc: 87.00%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.2398 | Val Loss: 0.4017 | Val Acc: 87.38% | Test Acc: 87.11%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.2362 | Val Loss: 0.4029 | Val Acc: 87.16% | Test Acc: 87.15%
# Epoch 74 | Train Loss: 0.2323 | Val Loss: 0.3995 | Val Acc: 87.28% | Test Acc: 87.20%
# Epoch 75 | Train Loss: 0.2313 | Val Loss: 0.4028 | Val Acc: 87.24% | Test Acc: 87.27%
# Epoch 76 | Train Loss: 0.2315 | Val Loss: 0.4028 | Val Acc: 87.44% | Test Acc: 87.28%
# Epoch 77 | Train Loss: 0.2318 | Val Loss: 0.4040 | Val Acc: 87.38% | Test Acc: 87.17%
# Epoch 78 | Train Loss: 0.2326 | Val Loss: 0.4018 | Val Acc: 87.30% | Test Acc: 87.14%
# Epoch 79 | Train Loss: 0.2332 | Val Loss: 0.4025 | Val Acc: 87.24% | Test Acc: 87.08%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 62.96it/s]
# Epoch 80 | Train Loss: 0.2298 | Val Loss: 0.4046 | Val Acc: 87.38% | Test Acc: 87.11%
# Epoch 81 | Train Loss: 0.2319 | Val Loss: 0.4007 | Val Acc: 87.46% | Test Acc: 87.25%
# Epoch 82 | Train Loss: 0.2305 | Val Loss: 0.4014 | Val Acc: 87.38% | Test Acc: 87.32%
# Epoch 83 | Train Loss: 0.2296 | Val Loss: 0.4014 | Val Acc: 87.20% | Test Acc: 87.25%
# Epoch 84 | Train Loss: 0.2301 | Val Loss: 0.4019 | Val Acc: 87.52% | Test Acc: 87.24%
# Epoch 85 | Train Loss: 0.2289 | Val Loss: 0.3995 | Val Acc: 87.60% | Test Acc: 87.35%
# Epoch 86 | Train Loss: 0.2306 | Val Loss: 0.4029 | Val Acc: 87.28% | Test Acc: 87.29%
#
# Random Reinit Result:
#   Test Accuracy: 87.29%
#   Remaining Params: 33.27%
# ======================================================================
#
#    -> Random Reinit for Sparsity: 26.77%
#
# ======================================================================
# Starting Random Reinit Control Experiment
# Sparsity Level: 26.77% weights remaining
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# Warmup strategy: linear_20k
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.1611 | Val Loss: 1.9457 | Val Acc: 27.24% | Test Acc: 27.30%
# Epoch 02 | Train Loss: 1.8362 | Val Loss: 1.7325 | Val Acc: 34.82% | Test Acc: 34.94%
# Epoch 03 | Train Loss: 1.6711 | Val Loss: 1.6450 | Val Acc: 38.22% | Test Acc: 38.91%
# Epoch 04 | Train Loss: 1.5641 | Val Loss: 1.5275 | Val Acc: 43.52% | Test Acc: 43.99%
# Epoch 05 | Train Loss: 1.4709 | Val Loss: 1.4442 | Val Acc: 47.66% | Test Acc: 48.06%
# Epoch 06 | Train Loss: 1.3880 | Val Loss: 1.4305 | Val Acc: 48.62% | Test Acc: 49.02%
# Epoch 07 | Train Loss: 1.2975 | Val Loss: 1.2643 | Val Acc: 54.22% | Test Acc: 55.01%
# Epoch 08 | Train Loss: 1.2194 | Val Loss: 1.3184 | Val Acc: 53.42% | Test Acc: 53.45%
# Epoch 09 | Train Loss: 1.1459 | Val Loss: 1.1511 | Val Acc: 59.66% | Test Acc: 59.33%
# Epoch 10/86: 100%|██████████| 352/352 [00:05<00:00, 59.54it/s]
# Epoch 10 | Train Loss: 1.0861 | Val Loss: 1.1028 | Val Acc: 60.92% | Test Acc: 61.65%
# Epoch 11 | Train Loss: 1.0288 | Val Loss: 1.0365 | Val Acc: 63.88% | Test Acc: 63.59%
# Epoch 12 | Train Loss: 0.9860 | Val Loss: 1.0477 | Val Acc: 63.36% | Test Acc: 63.77%
# Epoch 13 | Train Loss: 0.9443 | Val Loss: 1.0278 | Val Acc: 63.76% | Test Acc: 64.50%
# Epoch 14 | Train Loss: 0.9078 | Val Loss: 0.9272 | Val Acc: 67.32% | Test Acc: 68.49%
# Epoch 15 | Train Loss: 0.8727 | Val Loss: 1.0038 | Val Acc: 65.92% | Test Acc: 66.39%
# Epoch 16 | Train Loss: 0.8385 | Val Loss: 1.0753 | Val Acc: 62.44% | Test Acc: 63.11%
# Epoch 17 | Train Loss: 0.8104 | Val Loss: 0.9393 | Val Acc: 66.90% | Test Acc: 68.26%
# Epoch 18 | Train Loss: 0.7708 | Val Loss: 0.9117 | Val Acc: 69.20% | Test Acc: 69.01%
# Epoch 19 | Train Loss: 0.7409 | Val Loss: 0.8230 | Val Acc: 71.78% | Test Acc: 72.39%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 63.53it/s]
# Epoch 20 | Train Loss: 0.7162 | Val Loss: 0.9151 | Val Acc: 69.58% | Test Acc: 70.73%
# Epoch 21 | Train Loss: 0.6967 | Val Loss: 0.7980 | Val Acc: 73.42% | Test Acc: 73.96%
# Epoch 22 | Train Loss: 0.6709 | Val Loss: 0.8321 | Val Acc: 72.00% | Test Acc: 73.13%
# Epoch 23 | Train Loss: 0.6490 | Val Loss: 0.7892 | Val Acc: 73.24% | Test Acc: 73.93%
# Epoch 24 | Train Loss: 0.6296 | Val Loss: 0.7031 | Val Acc: 76.60% | Test Acc: 76.31%
# Epoch 25 | Train Loss: 0.6151 | Val Loss: 0.7542 | Val Acc: 74.80% | Test Acc: 74.63%
# Epoch 26 | Train Loss: 0.6056 | Val Loss: 0.8322 | Val Acc: 74.14% | Test Acc: 73.34%
# Epoch 27 | Train Loss: 0.5952 | Val Loss: 0.6769 | Val Acc: 77.08% | Test Acc: 77.41%
# Epoch 28 | Train Loss: 0.5781 | Val Loss: 0.7244 | Val Acc: 76.38% | Test Acc: 76.51%
# Epoch 29 | Train Loss: 0.5646 | Val Loss: 0.8139 | Val Acc: 72.66% | Test Acc: 72.77%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 63.95it/s]
# Epoch 30 | Train Loss: 0.5529 | Val Loss: 0.7252 | Val Acc: 76.66% | Test Acc: 76.73%
# Epoch 31 | Train Loss: 0.5428 | Val Loss: 0.6243 | Val Acc: 79.30% | Test Acc: 78.94%
# Epoch 32 | Train Loss: 0.5351 | Val Loss: 0.7800 | Val Acc: 74.42% | Test Acc: 74.07%
# Epoch 33 | Train Loss: 0.5262 | Val Loss: 0.6816 | Val Acc: 77.78% | Test Acc: 77.83%
# Epoch 34 | Train Loss: 0.5130 | Val Loss: 0.6432 | Val Acc: 78.40% | Test Acc: 78.55%
# Epoch 35 | Train Loss: 0.5028 | Val Loss: 0.7579 | Val Acc: 77.58% | Test Acc: 77.24%
# Epoch 36 | Train Loss: 0.4989 | Val Loss: 0.5903 | Val Acc: 79.96% | Test Acc: 80.60%
# Epoch 37 | Train Loss: 0.4914 | Val Loss: 0.7057 | Val Acc: 76.80% | Test Acc: 77.29%
# Epoch 38 | Train Loss: 0.4855 | Val Loss: 0.6787 | Val Acc: 77.90% | Test Acc: 78.01%
# Epoch 39 | Train Loss: 0.4776 | Val Loss: 0.7636 | Val Acc: 76.46% | Test Acc: 76.26%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 64.44it/s]
# Epoch 40 | Train Loss: 0.4732 | Val Loss: 0.5774 | Val Acc: 80.68% | Test Acc: 80.26%
# Epoch 41 | Train Loss: 0.4653 | Val Loss: 0.6521 | Val Acc: 79.22% | Test Acc: 79.54%
# Epoch 42 | Train Loss: 0.4591 | Val Loss: 0.5939 | Val Acc: 79.86% | Test Acc: 80.24%
# ...
# Epoch 14 | Train Loss: 1.0068 | Val Loss: 1.0458 | Val Acc: 63.78% | Test Acc: 62.79%
# Epoch 15 | Train Loss: 0.9829 | Val Loss: 0.9838 | Val Acc: 65.18% | Test Acc: 64.63%
# Epoch 16 | Train Loss: 0.9643 | Val Loss: 1.1547 | Val Acc: 61.94% | Test Acc: 60.71%
# Epoch 17 | Train Loss: 0.9439 | Val Loss: 0.9242 | Val Acc: 67.42% | Test Acc: 65.63%
# Epoch 18 | Train Loss: 0.9242 | Val Loss: 0.9875 | Val Acc: 66.48% | Test Acc: 65.05%
# Epoch 19 | Train Loss: 0.9037 | Val Loss: 0.9940 | Val Acc: 66.24% | Test Acc: 64.19%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 62.43it/s]
# Epoch 20 | Train Loss: 0.8872 | Val Loss: 0.9887 | Val Acc: 67.64% | Test Acc: 66.22%
# Epoch 21 | Train Loss: 0.8815 | Val Loss: 1.0704 | Val Acc: 62.48% | Test Acc: 60.94%
# Epoch 22 | Train Loss: 0.8587 | Val Loss: 0.8929 | Val Acc: 68.64% | Test Acc: 67.27%
# Epoch 23 | Train Loss: 0.8463 | Val Loss: 0.8686 | Val Acc: 70.14% | Test Acc: 68.47%
# Epoch 24 | Train Loss: 0.8296 | Val Loss: 0.9225 | Val Acc: 68.12% | Test Acc: 67.07%
# Epoch 25 | Train Loss: 0.8149 | Val Loss: 0.9131 | Val Acc: 69.34% | Test Acc: 68.55%
# Epoch 26 | Train Loss: 0.8036 | Val Loss: 0.8365 | Val Acc: 70.78% | Test Acc: 69.91%
# Epoch 27 | Train Loss: 0.7864 | Val Loss: 0.9594 | Val Acc: 68.72% | Test Acc: 67.59%
# Epoch 28 | Train Loss: 0.7812 | Val Loss: 0.7930 | Val Acc: 72.30% | Test Acc: 71.07%
# Epoch 29 | Train Loss: 0.7692 | Val Loss: 1.3571 | Val Acc: 59.94% | Test Acc: 59.17%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 59.92it/s]
# Epoch 30 | Train Loss: 0.7603 | Val Loss: 0.8997 | Val Acc: 69.68% | Test Acc: 68.97%
# Epoch 31 | Train Loss: 0.7451 | Val Loss: 0.7644 | Val Acc: 73.42% | Test Acc: 72.26%
# Epoch 32 | Train Loss: 0.7378 | Val Loss: 0.7789 | Val Acc: 73.92% | Test Acc: 72.54%
# Epoch 33 | Train Loss: 0.7355 | Val Loss: 0.9014 | Val Acc: 69.54% | Test Acc: 69.04%
# Epoch 34 | Train Loss: 0.7277 | Val Loss: 0.7941 | Val Acc: 73.34% | Test Acc: 71.93%
# Epoch 35 | Train Loss: 0.7203 | Val Loss: 0.8553 | Val Acc: 71.72% | Test Acc: 70.23%
# Epoch 36 | Train Loss: 0.7104 | Val Loss: 0.7673 | Val Acc: 73.68% | Test Acc: 73.27%
# Epoch 37 | Train Loss: 0.7036 | Val Loss: 0.8089 | Val Acc: 72.82% | Test Acc: 72.27%
# Epoch 38 | Train Loss: 0.6979 | Val Loss: 0.7896 | Val Acc: 73.54% | Test Acc: 72.98%
# Epoch 39 | Train Loss: 0.6921 | Val Loss: 0.8576 | Val Acc: 72.56% | Test Acc: 70.92%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 64.39it/s]
# Epoch 40 | Train Loss: 0.6910 | Val Loss: 0.9536 | Val Acc: 69.98% | Test Acc: 69.13%
# Epoch 41 | Train Loss: 0.6799 | Val Loss: 0.7122 | Val Acc: 75.52% | Test Acc: 74.19%
# Epoch 42 | Train Loss: 0.6760 | Val Loss: 0.7202 | Val Acc: 75.74% | Test Acc: 74.44%
# Epoch 43 | Train Loss: 0.6723 | Val Loss: 0.7547 | Val Acc: 74.96% | Test Acc: 73.46%
# Epoch 44 | Train Loss: 0.6681 | Val Loss: 0.8381 | Val Acc: 72.60% | Test Acc: 71.06%
# Epoch 45 | Train Loss: 0.6597 | Val Loss: 0.7608 | Val Acc: 74.02% | Test Acc: 73.23%
# Epoch 46 | Train Loss: 0.6612 | Val Loss: 0.7991 | Val Acc: 74.18% | Test Acc: 73.72%
# Epoch 47 | Train Loss: 0.6536 | Val Loss: 0.7357 | Val Acc: 76.06% | Test Acc: 75.04%
# Epoch 48 | Train Loss: 0.6547 | Val Loss: 0.7210 | Val Acc: 75.10% | Test Acc: 74.00%
# Epoch 49 | Train Loss: 0.6486 | Val Loss: 0.8044 | Val Acc: 74.32% | Test Acc: 72.46%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 63.48it/s]
# Epoch 50 | Train Loss: 0.6415 | Val Loss: 0.6479 | Val Acc: 77.90% | Test Acc: 76.72%
# Epoch 51 | Train Loss: 0.6480 | Val Loss: 0.7542 | Val Acc: 75.06% | Test Acc: 73.84%
# Epoch 52 | Train Loss: 0.6412 | Val Loss: 0.7048 | Val Acc: 76.20% | Test Acc: 75.74%
# Epoch 53 | Train Loss: 0.6359 | Val Loss: 0.6359 | Val Acc: 77.90% | Test Acc: 77.56%
# Epoch 54 | Train Loss: 0.6271 | Val Loss: 0.7364 | Val Acc: 75.36% | Test Acc: 74.26%
# Epoch 55 | Train Loss: 0.6248 | Val Loss: 0.9055 | Val Acc: 71.16% | Test Acc: 70.93%
# Epoch 56 | Train Loss: 0.6239 | Val Loss: 0.6656 | Val Acc: 78.02% | Test Acc: 76.88%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.6240 | Val Loss: 0.6730 | Val Acc: 77.80% | Test Acc: 75.83%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.5693 | Val Loss: 0.5663 | Val Acc: 80.60% | Test Acc: 79.81%
# Epoch 59 | Train Loss: 0.5520 | Val Loss: 0.5669 | Val Acc: 80.38% | Test Acc: 80.07%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 63.72it/s]
# Epoch 60 | Train Loss: 0.5486 | Val Loss: 0.5641 | Val Acc: 80.88% | Test Acc: 79.97%
# Epoch 61 | Train Loss: 0.5478 | Val Loss: 0.5679 | Val Acc: 80.76% | Test Acc: 80.08%
# Epoch 62 | Train Loss: 0.5434 | Val Loss: 0.5651 | Val Acc: 80.62% | Test Acc: 80.06%
# Epoch 63 | Train Loss: 0.5373 | Val Loss: 0.5599 | Val Acc: 80.76% | Test Acc: 80.12%
# Epoch 64 | Train Loss: 0.5355 | Val Loss: 0.5615 | Val Acc: 80.80% | Test Acc: 80.21%
# Epoch 65 | Train Loss: 0.5355 | Val Loss: 0.5541 | Val Acc: 80.90% | Test Acc: 80.45%
# Epoch 66 | Train Loss: 0.5363 | Val Loss: 0.5595 | Val Acc: 80.74% | Test Acc: 80.29%
# Epoch 67 | Train Loss: 0.5373 | Val Loss: 0.5612 | Val Acc: 80.50% | Test Acc: 80.39%
# Epoch 68 | Train Loss: 0.5308 | Val Loss: 0.5608 | Val Acc: 80.80% | Test Acc: 80.25%
# Epoch 69 | Train Loss: 0.5288 | Val Loss: 0.5603 | Val Acc: 80.92% | Test Acc: 80.01%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 62.31it/s]
# Epoch 70 | Train Loss: 0.5311 | Val Loss: 0.5536 | Val Acc: 81.04% | Test Acc: 80.28%
# Epoch 71 | Train Loss: 0.5306 | Val Loss: 0.5512 | Val Acc: 81.40% | Test Acc: 80.10%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.5238 | Val Loss: 0.5507 | Val Acc: 81.44% | Test Acc: 80.13%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.5246 | Val Loss: 0.5516 | Val Acc: 81.22% | Test Acc: 80.26%
# Epoch 74 | Train Loss: 0.5243 | Val Loss: 0.5502 | Val Acc: 81.04% | Test Acc: 80.25%
# Epoch 75 | Train Loss: 0.5227 | Val Loss: 0.5498 | Val Acc: 81.52% | Test Acc: 80.30%
# Epoch 76 | Train Loss: 0.5200 | Val Loss: 0.5505 | Val Acc: 81.12% | Test Acc: 80.51%
# Epoch 77 | Train Loss: 0.5179 | Val Loss: 0.5544 | Val Acc: 81.12% | Test Acc: 80.24%
# Epoch 78 | Train Loss: 0.5200 | Val Loss: 0.5522 | Val Acc: 81.14% | Test Acc: 80.27%
# Epoch 79 | Train Loss: 0.5213 | Val Loss: 0.5479 | Val Acc: 81.28% | Test Acc: 80.32%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 65.36it/s]
# Epoch 80 | Train Loss: 0.5199 | Val Loss: 0.5490 | Val Acc: 81.26% | Test Acc: 80.28%
# Epoch 81 | Train Loss: 0.5189 | Val Loss: 0.5465 | Val Acc: 81.44% | Test Acc: 80.30%
# Epoch 82 | Train Loss: 0.5177 | Val Loss: 0.5481 | Val Acc: 81.20% | Test Acc: 80.34%
# Epoch 83 | Train Loss: 0.5200 | Val Loss: 0.5513 | Val Acc: 81.08% | Test Acc: 80.29%
# Epoch 84 | Train Loss: 0.5194 | Val Loss: 0.5496 | Val Acc: 81.32% | Test Acc: 80.40%
# Epoch 85 | Train Loss: 0.5166 | Val Loss: 0.5474 | Val Acc: 81.34% | Test Acc: 80.45%
# Epoch 86 | Train Loss: 0.5181 | Val Loss: 0.5521 | Val Acc: 81.20% | Test Acc: 80.37%
#
# Random Reinit Result:
#   Test Accuracy: 80.37%
#   Remaining Params: 5.12%
# ======================================================================
#
#    -> Random Reinit for Sparsity: 4.24%
#
# ======================================================================
# Starting Random Reinit Control Experiment
# Sparsity Level: 4.24% weights remaining
# Pruning strategy: global
# Conv prune rate: 20.0%
# FC prune rate: 0.0%
# Warmup strategy: linear_20k
# ======================================================================
# Scheduler enabled: Linear Warmup to epoch 57, then decay.
# Epoch 01 | Train Loss: 2.3644 | Val Loss: 2.0307 | Val Acc: 23.70% | Test Acc: 24.29%
# Epoch 02 | Train Loss: 1.9090 | Val Loss: 1.8205 | Val Acc: 32.14% | Test Acc: 31.29%
# Epoch 03 | Train Loss: 1.7303 | Val Loss: 1.6543 | Val Acc: 37.70% | Test Acc: 37.21%
# Epoch 04 | Train Loss: 1.6091 | Val Loss: 1.5448 | Val Acc: 43.24% | Test Acc: 42.83%
# Epoch 05 | Train Loss: 1.5072 | Val Loss: 1.4240 | Val Acc: 47.68% | Test Acc: 47.49%
# Epoch 06 | Train Loss: 1.4002 | Val Loss: 1.3651 | Val Acc: 50.46% | Test Acc: 50.38%
# Epoch 07 | Train Loss: 1.3233 | Val Loss: 1.2686 | Val Acc: 54.64% | Test Acc: 55.20%
# Epoch 08 | Train Loss: 1.2605 | Val Loss: 1.2441 | Val Acc: 54.82% | Test Acc: 55.31%
# Epoch 09 | Train Loss: 1.2041 | Val Loss: 1.2530 | Val Acc: 55.84% | Test Acc: 55.50%
# Epoch 10/86: 100%|██████████| 352/352 [00:06<00:00, 56.03it/s]
# Epoch 10 | Train Loss: 1.1597 | Val Loss: 1.1146 | Val Acc: 60.36% | Test Acc: 59.77%
# Epoch 11 | Train Loss: 1.1171 | Val Loss: 1.0994 | Val Acc: 61.20% | Test Acc: 59.93%
# Epoch 12 | Train Loss: 1.0726 | Val Loss: 1.1527 | Val Acc: 60.24% | Test Acc: 59.20%
# Epoch 13 | Train Loss: 1.0387 | Val Loss: 1.0996 | Val Acc: 61.84% | Test Acc: 60.96%
# Epoch 14 | Train Loss: 1.0128 | Val Loss: 1.0769 | Val Acc: 61.52% | Test Acc: 60.67%
# Epoch 15 | Train Loss: 0.9859 | Val Loss: 1.0271 | Val Acc: 63.82% | Test Acc: 63.57%
# Epoch 16 | Train Loss: 0.9630 | Val Loss: 0.9664 | Val Acc: 65.92% | Test Acc: 64.58%
# Epoch 17 | Train Loss: 0.9429 | Val Loss: 0.9778 | Val Acc: 65.22% | Test Acc: 64.26%
# Epoch 18 | Train Loss: 0.9246 | Val Loss: 0.9902 | Val Acc: 65.56% | Test Acc: 63.98%
# Epoch 19 | Train Loss: 0.9109 | Val Loss: 1.1382 | Val Acc: 61.72% | Test Acc: 60.05%
# Epoch 20/86: 100%|██████████| 352/352 [00:05<00:00, 64.89it/s]
# Epoch 20 | Train Loss: 0.8983 | Val Loss: 0.9206 | Val Acc: 66.98% | Test Acc: 66.72%
# Epoch 21 | Train Loss: 0.8826 | Val Loss: 0.9259 | Val Acc: 67.56% | Test Acc: 66.58%
# Epoch 22 | Train Loss: 0.8707 | Val Loss: 0.8750 | Val Acc: 68.40% | Test Acc: 67.66%
# Epoch 23 | Train Loss: 0.8610 | Val Loss: 0.9229 | Val Acc: 67.86% | Test Acc: 66.92%
# Epoch 24 | Train Loss: 0.8494 | Val Loss: 0.8851 | Val Acc: 68.66% | Test Acc: 67.37%
# Epoch 25 | Train Loss: 0.8410 | Val Loss: 0.9724 | Val Acc: 68.16% | Test Acc: 66.61%
# Epoch 26 | Train Loss: 0.8278 | Val Loss: 0.8345 | Val Acc: 71.10% | Test Acc: 70.02%
# Epoch 27 | Train Loss: 0.8163 | Val Loss: 0.7957 | Val Acc: 71.84% | Test Acc: 70.23%
# Epoch 28 | Train Loss: 0.8083 | Val Loss: 0.8906 | Val Acc: 69.12% | Test Acc: 68.57%
# Epoch 29 | Train Loss: 0.8027 | Val Loss: 0.9468 | Val Acc: 68.38% | Test Acc: 67.18%
# Epoch 30/86: 100%|██████████| 352/352 [00:05<00:00, 62.59it/s]
# Epoch 30 | Train Loss: 0.7920 | Val Loss: 0.8895 | Val Acc: 69.64% | Test Acc: 68.85%
# Epoch 31 | Train Loss: 0.7869 | Val Loss: 0.8526 | Val Acc: 72.48% | Test Acc: 69.96%
# Epoch 32 | Train Loss: 0.7769 | Val Loss: 0.7941 | Val Acc: 72.60% | Test Acc: 71.19%
# Epoch 33 | Train Loss: 0.7704 | Val Loss: 0.8463 | Val Acc: 70.56% | Test Acc: 69.09%
# Epoch 34 | Train Loss: 0.7615 | Val Loss: 0.8418 | Val Acc: 71.48% | Test Acc: 70.72%
# Epoch 35 | Train Loss: 0.7518 | Val Loss: 0.8479 | Val Acc: 70.84% | Test Acc: 69.54%
# Epoch 36 | Train Loss: 0.7442 | Val Loss: 0.8296 | Val Acc: 71.50% | Test Acc: 70.08%
# Epoch 37 | Train Loss: 0.7355 | Val Loss: 0.7833 | Val Acc: 72.82% | Test Acc: 71.29%
# Epoch 38 | Train Loss: 0.7320 | Val Loss: 0.7705 | Val Acc: 73.70% | Test Acc: 72.93%
# Epoch 39 | Train Loss: 0.7301 | Val Loss: 0.7552 | Val Acc: 74.04% | Test Acc: 72.35%
# Epoch 40/86: 100%|██████████| 352/352 [00:05<00:00, 63.25it/s]
# Epoch 40 | Train Loss: 0.7197 | Val Loss: 0.8141 | Val Acc: 71.68% | Test Acc: 71.31%
# Epoch 41 | Train Loss: 0.7164 | Val Loss: 0.7540 | Val Acc: 73.78% | Test Acc: 72.67%
# Epoch 42 | Train Loss: 0.7131 | Val Loss: 0.7369 | Val Acc: 75.00% | Test Acc: 73.14%
# Epoch 43 | Train Loss: 0.7012 | Val Loss: 0.8020 | Val Acc: 72.68% | Test Acc: 70.96%
# Epoch 44 | Train Loss: 0.7021 | Val Loss: 0.7479 | Val Acc: 74.30% | Test Acc: 72.56%
# Epoch 45 | Train Loss: 0.7028 | Val Loss: 0.7095 | Val Acc: 74.92% | Test Acc: 73.59%
# Epoch 46 | Train Loss: 0.6939 | Val Loss: 0.7502 | Val Acc: 74.80% | Test Acc: 73.39%
# Epoch 47 | Train Loss: 0.6871 | Val Loss: 0.6980 | Val Acc: 76.20% | Test Acc: 73.86%
# Epoch 48 | Train Loss: 0.6843 | Val Loss: 0.7388 | Val Acc: 75.00% | Test Acc: 73.88%
# Epoch 49 | Train Loss: 0.6827 | Val Loss: 0.8324 | Val Acc: 73.02% | Test Acc: 70.96%
# Epoch 50/86: 100%|██████████| 352/352 [00:05<00:00, 66.76it/s]
# Epoch 50 | Train Loss: 0.6724 | Val Loss: 0.6999 | Val Acc: 76.00% | Test Acc: 75.22%
# Epoch 51 | Train Loss: 0.6763 | Val Loss: 0.7742 | Val Acc: 73.66% | Test Acc: 71.66%
# Epoch 52 | Train Loss: 0.6733 | Val Loss: 0.6471 | Val Acc: 77.36% | Test Acc: 75.69%
# Epoch 53 | Train Loss: 0.6679 | Val Loss: 0.7167 | Val Acc: 75.24% | Test Acc: 73.82%
# Epoch 54 | Train Loss: 0.6663 | Val Loss: 0.7695 | Val Acc: 74.28% | Test Acc: 73.15%
# Epoch 55 | Train Loss: 0.6608 | Val Loss: 0.7165 | Val Acc: 75.32% | Test Acc: 74.42%
# Epoch 56 | Train Loss: 0.6601 | Val Loss: 0.6928 | Val Acc: 76.36% | Test Acc: 75.15%
#  -> Scheduler Step! Current LR: 0.01
# Epoch 57 | Train Loss: 0.6525 | Val Loss: 0.7351 | Val Acc: 75.44% | Test Acc: 73.66%
#  -> Scheduler Step! Current LR: 0.001
# Epoch 58 | Train Loss: 0.6026 | Val Loss: 0.5749 | Val Acc: 80.32% | Test Acc: 78.30%
# Epoch 59 | Train Loss: 0.5879 | Val Loss: 0.5697 | Val Acc: 80.40% | Test Acc: 78.65%
# Epoch 60/86: 100%|██████████| 352/352 [00:05<00:00, 64.75it/s]
# Epoch 60 | Train Loss: 0.5857 | Val Loss: 0.5656 | Val Acc: 80.14% | Test Acc: 78.53%
# Epoch 61 | Train Loss: 0.5832 | Val Loss: 0.5673 | Val Acc: 80.68% | Test Acc: 78.60%
# Epoch 62 | Train Loss: 0.5796 | Val Loss: 0.5642 | Val Acc: 80.76% | Test Acc: 78.68%
# Epoch 63 | Train Loss: 0.5794 | Val Loss: 0.5675 | Val Acc: 80.34% | Test Acc: 78.63%
# Epoch 64 | Train Loss: 0.5779 | Val Loss: 0.5667 | Val Acc: 80.48% | Test Acc: 78.66%
# Epoch 65 | Train Loss: 0.5782 | Val Loss: 0.5650 | Val Acc: 80.66% | Test Acc: 78.56%
# Epoch 66 | Train Loss: 0.5737 | Val Loss: 0.5642 | Val Acc: 80.98% | Test Acc: 78.62%
# Epoch 67 | Train Loss: 0.5695 | Val Loss: 0.5611 | Val Acc: 80.82% | Test Acc: 78.47%
# Epoch 68 | Train Loss: 0.5735 | Val Loss: 0.5555 | Val Acc: 81.04% | Test Acc: 78.63%
# Epoch 69 | Train Loss: 0.5688 | Val Loss: 0.5607 | Val Acc: 80.36% | Test Acc: 78.76%
# Epoch 70/86: 100%|██████████| 352/352 [00:05<00:00, 63.37it/s]
# Epoch 70 | Train Loss: 0.5678 | Val Loss: 0.5607 | Val Acc: 80.96% | Test Acc: 78.87%
# Epoch 71 | Train Loss: 0.5665 | Val Loss: 0.5585 | Val Acc: 81.20% | Test Acc: 78.94%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 72 | Train Loss: 0.5664 | Val Loss: 0.5572 | Val Acc: 80.78% | Test Acc: 79.01%
#  -> Scheduler Step! Current LR: 0.0001
# Epoch 73 | Train Loss: 0.5601 | Val Loss: 0.5551 | Val Acc: 80.92% | Test Acc: 79.07%
# Epoch 74 | Train Loss: 0.5599 | Val Loss: 0.5549 | Val Acc: 80.90% | Test Acc: 79.11%
# Epoch 75 | Train Loss: 0.5587 | Val Loss: 0.5552 | Val Acc: 80.86% | Test Acc: 78.92%
# Epoch 76 | Train Loss: 0.5625 | Val Loss: 0.5529 | Val Acc: 80.88% | Test Acc: 79.14%
# Epoch 77 | Train Loss: 0.5565 | Val Loss: 0.5548 | Val Acc: 80.88% | Test Acc: 79.12%
# Epoch 78 | Train Loss: 0.5636 | Val Loss: 0.5524 | Val Acc: 80.92% | Test Acc: 78.99%
# Epoch 79 | Train Loss: 0.5570 | Val Loss: 0.5542 | Val Acc: 80.96% | Test Acc: 79.02%
# Epoch 80/86: 100%|██████████| 352/352 [00:05<00:00, 66.28it/s]
# Epoch 80 | Train Loss: 0.5614 | Val Loss: 0.5555 | Val Acc: 81.06% | Test Acc: 79.06%
# Epoch 81 | Train Loss: 0.5577 | Val Loss: 0.5541 | Val Acc: 80.96% | Test Acc: 79.06%
# Epoch 82 | Train Loss: 0.5600 | Val Loss: 0.5525 | Val Acc: 81.20% | Test Acc: 78.96%
# Epoch 83 | Train Loss: 0.5610 | Val Loss: 0.5547 | Val Acc: 81.04% | Test Acc: 79.10%
# Epoch 84 | Train Loss: 0.5593 | Val Loss: 0.5542 | Val Acc: 81.12% | Test Acc: 79.17%
# Epoch 85 | Train Loss: 0.5585 | Val Loss: 0.5545 | Val Acc: 80.96% | Test Acc: 79.14%
#    [Tracker] 🚩 Early Stop Condition at Iter 30272 (Epoch 86, Test Acc: 79.00%)
# Epoch 86 | Train Loss: 0.5618 | Val Loss: 0.5551 | Val Acc: 81.28% | Test Acc: 79.00%
#
# Random Reinit Result:
#   Test Accuracy: 79.00%
#   Remaining Params: 4.24%
# ======================================================================
#
# Saved Random Init results to: ../../results/resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904/checkpoints/random_init_results_resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904.pth

# %%
# --- Data Aggregation (Random Init) ---
# Assuming all_trials_random is a List[List[Dict]] populated from your Phase 2 loop
n_rounds_rnd = len(all_trials_random[0])
n_trials_rnd = len(all_trials_random)

# Initialize lists to store aggregated data
rounds_rnd = []
remaining_params_pct_rnd = []
remaining_params_rnd = []
acc_means_rnd = []
acc_stds_rnd = []

for r_idx in range(n_rounds_rnd):
    # Extract data for this specific round across all random trials
    # Structure: [Trial1_RoundX, Trial2_RoundX, Trial3_RoundX]
    round_data = [trial[r_idx] for trial in all_trials_random]
    
    # Static data (same structure as iterative)
    rounds_rnd.append(round_data[0]['round'])
    remaining_params_pct_rnd.append(round_data[0]['remaining_params_pct'])
    remaining_params_rnd.append(round_data[0]['remaining_params']) # Assuming this key exists, else compute
    
    # Variable data (Accuracy) - Calculate Mean and Std
    accuracies = [r['test_accuracy'] for r in round_data]
    acc_means_rnd.append(np.mean(accuracies))
    acc_stds_rnd.append(np.std(accuracies))

# --- Print Summary Table ---
print("\n" + "="*80)
print(f"Random Reinit Results Summary ({n_trials_rnd} Trials Aggregated)")
print("="*80)
print(f"{'Round':<8} {'Params %':<12} {'Mean Acc %':<12} {'Std Dev':<10}")
print("-"*80)

for i in range(n_rounds_rnd):
    print(f"{rounds_rnd[i]:<8} {remaining_params_pct_rnd[i]:<12.2f} "
          f"{acc_means_rnd[i]:<12.2f} ± {acc_stds_rnd[i]:<10.2f}")
print("="*80)
# Out:
# ================================================================================
# Random Reinit Results Summary (3 Trials Aggregated)
# ================================================================================
# Round    Params %     Mean Acc %   Std Dev
# --------------------------------------------------------------------------------
# 1        80.15        87.99        ± 0.11
# 2        64.27        88.00        ± 0.10
# 3        51.57        87.68        ± 0.13
# 4        41.40        87.10        ± 0.35
# 5        33.27        87.19        ± 0.19
# 6        26.77        86.68        ± 0.22
# 7        21.56        86.12        ± 0.23
# 8        17.40        85.68        ± 0.18
# 9        14.07        85.09        ± 0.15
# 10       11.41        84.70        ± 0.23
# 11       9.28         83.63        ± 0.16
# 12       7.57         82.62        ± 0.20
# 13       6.21         81.86        ± 0.17
# 14       5.12         80.22        ± 0.12
# 15       4.24         79.34        ± 0.50
# ================================================================================

# %%
# --- Visualize Random Init with Error Bars ---
fig, ax1 = plt.subplots(1, 1, figsize=(8, 6))

# Convert to numpy arrays
x_pct_rnd = np.array(remaining_params_pct_rnd)
y_mean_rnd = np.array(acc_means_rnd)
y_std_rnd = np.array(acc_stds_rnd)

# ==============================================================================
# Plot: Accuracy vs Sparsity (Random Init)
# ==============================================================================

# Error bar plot
ax1.errorbar(x_pct_rnd, y_mean_rnd, yerr=y_std_rnd, fmt='s--', 
             linewidth=2, markersize=6, capsize=4, elinewidth=1.5,
             color='tab:orange', ecolor='tab:orange', label='Mean Accuracy (Random Reinit)')

# Baseline Handling (Optional: Compare against Iterative Baseline)
# If 'baseline_mean' exists from the previous iterative block, we can use it.
if 'baseline_mean' in globals():
    ax1.axhline(y=baseline_mean, color='r', linestyle='--', label=f'Iterative Baseline ({baseline_mean:.2f}%)', alpha=0.5)

ax1.set_xlabel('Percent of Weights Remaining (%)', fontsize=12)
ax1.set_ylabel('Test Accuracy (%)', fontsize=12)
ax1.set_title(f'Random Reinit Accuracy vs Sparsity ({n_trials_rnd} Trials)', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)
ax1.invert_xaxis()  # 100% -> 0%

plt.tight_layout()

# Save Figure
if 'fig_dir' not in globals(): fig_dir = "." 
random_fig_path = os.path.join(fig_dir, f"Random_init_results_multi_trial_errorbars_{run_id}.png")
plt.savefig(random_fig_path, dpi=300)
plt.show()

print(f"Random init figure saved to: {random_fig_path}")
# Out:
# Random init figure saved to: ../../results/resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904/figures/Random_init_results_multi_trial_errorbars_resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904.png

# %%
# --- Analyze Random Init Performance (Control) ---

# Use the same baseline as Iterative Pruning if available
if 'baseline_mean_acc' not in globals():
    # Fallback if iterative block wasn't run
    baseline_mean_acc = acc_means_rnd[0]

random_matching_tickets = []

# Loop through aggregated stats
for i in range(n_rounds_rnd):
    # Criteria: Mean Accuracy >= 98% of Baseline
    # This checks if Random Init can essentially "get lucky" and match the original network
    if acc_means_rnd[i] >= baseline_mean_acc * 0.98:
        random_matching_tickets.append(i)

print(f"\n{'='*70}")
print(f"Random Reinit Analysis (Control Experiment)")
print(f"{'='*70}")
print(f"Target Baseline Accuracy: {baseline_mean_acc:.2f}%")
print(f"\nRandom Configurations Matching Baseline (>= {baseline_mean_acc * 0.98:.2f}%):")

if not random_matching_tickets:
    print("None found. (As expected, random reinitialization usually fails at high sparsity)")
else:
    print(f"{'Round':<8} {'Sparsity %':<12} {'Mean Acc %':<12}")
    print("-"*40)
    for idx in random_matching_tickets:
        sparsity = 100 - remaining_params_pct_rnd[idx]
        print(f"{rounds_rnd[idx]:<8} {sparsity:<12.1f} "
              f"{acc_means_rnd[idx]:<12.2f}")

print("="*70)
# Out:
# ======================================================================
# Random Reinit Analysis (Control Experiment)
# ======================================================================
# Target Baseline Accuracy: 88.23%
#
# Random Configurations Matching Baseline (>= 86.47%):
# Round    Sparsity %   Mean Acc %
# ----------------------------------------
# 1        19.8         87.99
# 2        35.7         88.00
# 3        48.4         87.68
# 4        58.6         87.10
# 5        66.7         87.19
# 6        73.2         86.68
# ======================================================================

# %%
# --- Configuration ---
# Ensure these variables exist from your previous cells
# Iterative Data (Winning Ticket)
x_iter = np.array(remaining_params_pct)
y_iter_mean = np.array(acc_means)
y_iter_std = np.array(acc_stds)

# Random Init Data (Control)
x_rnd = np.array(remaining_params_pct_rnd)
y_rnd_mean = np.array(acc_means_rnd)
y_rnd_std = np.array(acc_stds_rnd)

# --- Visualize: Winning Ticket vs Random Reinit (Combined) ---
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

# ==============================================================================
# 1. Plot Winning Ticket (Iterative Pruning) -> Solid Line
# ==============================================================================
ax.errorbar(x_iter, y_iter_mean, yerr=y_iter_std, fmt='o-', 
             linewidth=2, markersize=6, capsize=4, elinewidth=1.5,
             color='tab:blue', ecolor='tab:blue', label='Winning Ticket (Iterative)')

# ==============================================================================
# 2. Plot Random Reinit (Control) -> Dashed Line
# ==============================================================================
ax.errorbar(x_rnd, y_rnd_mean, yerr=y_rnd_std, fmt='s--', 
             linewidth=2, markersize=6, capsize=4, elinewidth=1.5,
             color='tab:orange', ecolor='tab:orange', label='Random Reinit (Control)')

# ==============================================================================
# 3. Baseline Handling
# ==============================================================================
# Use the Mean Baseline from the Iterative Pruning (Round 1)
baseline_val = y_iter_mean[0]
ax.axhline(y=baseline_val, color='grey', linestyle=':', linewidth=2, 
           label=f'Unpruned Baseline ({baseline_val:.2f}%)', alpha=0.8)

# ==============================================================================
# 4. Styling (Match Paper Style)
# ==============================================================================
ax.set_xlabel('Percent of Weights Remaining (%)', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', fontsize=12)
ax.set_title(f'Winning Ticket vs Random Reinit ({n_trials} Trials)', fontsize=14, fontweight='bold')

ax.grid(True, which="both", linestyle='--', alpha=0.4)
ax.legend(fontsize=11, loc='best')

# Use Log Scale for X-axis to match Figure 8 style (better visibility for high sparsity)
ax.set_xscale('log')
ax.invert_xaxis()  # 100% -> 0%

# Set Custom Ticks for Log Scale (100, 50, 20, 10, 5, 2, 1)
ticks = [100, 50, 20, 10, 5, 2, 1]
ax.set_xticks(ticks)
ax.set_xticklabels([str(t) for t in ticks])
ax.minorticks_off() # Turn off minor ticks to look cleaner

plt.tight_layout()

# ==============================================================================
# 5. Save Figure
# ==============================================================================
if 'fig_dir' not in globals(): fig_dir = "."
combined_fig_path = os.path.join(fig_dir, f"Winning_Ticket_vs_Random_MultiTrial_Final_{run_id}.png")
plt.savefig(combined_fig_path, dpi=300)
plt.show()

print(f"Combined figure saved to: {combined_fig_path}")
# Out:
# Combined figure saved to: ../../results/resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904/figures/Winning_Ticket_vs_Random_MultiTrial_Final_resnet20_iterative_random_init_LR_0.03_warmup_3_trials_20260114_183904.png

# %% [markdown]
# ## 6. Analyze Results

# %% [markdown]
# ### 6.1 Iterative Pruning
#
# Visualize and analyze the pruning results.

# %% [markdown]
# ## 7. Identify Winning Tickets
#
# Find which pruned networks are "winning tickets" (match or exceed baseline accuracy).

# %% [markdown]
# ## 8. Save Results

# %% [markdown]
# ## 9. Next Steps
#
# ### Experiment Ideas:
#
# 1. **Compare pruning strategies**
#    - Try different `prune_rate_conv` and `prune_rate_fc`
#    - Compare `layerwise` vs `global` pruning
#
# 2. **Random reinitialization baseline**
#    - Use `random_reinit_pruning()` to show winning tickets need original initialization
#
# 3. **One-shot pruning**
#    - Compare `one_shot_pruning()` vs iterative pruning
#
# 4. **Visualize weight distributions**
#    - Plot weight magnitude histograms before/after pruning
#
# 5. **Learning rate experiments**
#    - Test different learning rates (paper shows this matters!)

# %% [markdown]
# ## Notes and Observations
#
# **TODO: Add your observations here**
#
# - What worked well?
# - What surprised you?
# - Any implementation challenges?
# - Ideas for the final report?
